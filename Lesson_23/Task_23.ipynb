# %% [markdown]
# # Домашнее задание к лекции "Основы веб-скрапинга и работы с API"

# %%
import requests
import time
time.sleep(0.2)
from bs4 import BeautifulSoup
import re
from pymystem3 import Mystem
import datetime
from datetime import datetime, timedelta
import pandas as pd
import json

# %% [markdown]
# ## Задание 1.
#
# ### Обязательная часть

# %% [markdown]
# Будем парсить страницу со свежеми новостям на [habr.com/ru/all/](https://habr.com/ru/all/).
#
# Вам необходимо собирать только те статьи, в которых встречается хотя бы одно требуемое ключевое слово. Эти слова определяем в начале кода в переменной, например:
#
# `KEYWORDS = ['python', 'парсинг']`
#
#  Поиск вести по всей доступной preview-информации (это информация, доступная непосредственно с текущей страницы).
#
# В итоге должен формироваться датафрейм со столбцами: <дата> - <заголовок> - <ссылка>.

# %%
# определяем список хабов, которые нам интересны
KEYWORDS = ['python', 'парсинг', 'бизнес']

# %%
# получаем страницу с самыми свежими постами
req = requests.get('https://habr.com/ru/all/')
soup = BeautifulSoup(req.text, 'html.parser')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="no-js" lang="ru">
#  <head>
#   <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
#   <meta content="width=1024" name="viewport"/>
#   <title>
#    Все публикации подряд / Хабр
#   </title>
#   <meta content="444736788986613" property="fb:app_id">
#    <meta content="website" property="og:type"/>
#    <meta content="472597926099084" property="fb:pages"/>
#    <meta content="Хабр" property="og:site_name"/>
#    <link href="https://habr.com/images/habr_ru.png" rel="image_src"/>
#    <meta content="https://habr.com/images/habr_ru.png" property="og:image"/>
#    <meta content="1200" property="og:image:width"/>
#    <meta content="628" property="og:image:height"/>
#    <meta content="Все публикации подряд / Хабр" property="og:title"/>
#    <meta content="Хабр — крупнейший в Европе ресурс для IT-специалистов. Сюда приходят обсудить новости индустрии и поделиться опытом." property="og:description"/>
#    <meta content="71593b225aeafc4e" name="yandex-verification"/>
#    <meta content="unsafe-url" name="referrer"/>
#    <meta content="ed24b2b9721edf0a282c5b4a3232c4" name="pocket-site-verification"/>
#    <meta content="https://dr.habracdn.net/habr/5f324012/images/" name="biu"/>
#    <style type="text/css">
#     @font-face{font-family:'Fira Sans';font-style:normal;font-weight:500;src:url(https://dr.habracdn.net/habr/5f324012/fonts/FiraSans/firaSans-medium.eot);src:local("Fira Sans Medium"),local("FiraSans-Medium"),url(https://dr.habracdn.net/habr/5f324012/fonts/FiraSans/firaSans-medium.eot?#iefix) format("embedded-opentype"),url(https://dr.habracdn.net/habr/5f324012/fonts/FiraSans/firaSans-medium.woff2) format("woff2"),url(https://dr.habracdn.net/habr/5f324012/fonts/FiraSans/firaSans-medium.woff) format("woff"),url(https://dr.habracdn.net/habr/5f324012/fonts/FiraSans/firaSans-medium.ttf) format("truetype")}
#    </style>
#    <link href="https://dr.habracdn.net/habr/5f324012/styles/main.bundle.css" media="all" rel="stylesheet"/>
#    <meta content="67d46b975fa41645" name="yandex-verification">
#     <link href="https://dr.habracdn.net/habr/5f324012/images/apple-touch-icon.png" rel="apple-touch-icon" sizes="180x180"/>
#     <link href="https://dr.habracdn.net/habr/5f324012/images/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
#     <link href="https://dr.habracdn.net/habr/5f324012/images/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
#     <link href="https://dr.habracdn.net/habr/5f324012/site.webmanifest" rel="manifest"/>
#     <link color="#77a2b6" href="https://dr.habracdn.net/habr/5f324012/images/safari-pinned-tab.svg" rel="mask-icon"/>
#     <meta content="Хабр" name="application-name"/>
#     <meta content="#77a2b6" name="msapplication-TileColor"/>
#     <meta content="#77a2b6" name="theme-color"/>
#     <link href="https://habr.com/ru/rss/all/all/?fl=ru" rel="alternate" title="Все публикации подряд" type="application/rss+xml">
#      <script>
#       /* Font Face Observer v2.0.13 - © Bram Stein. License: BSD-3-Clause */(function(){'use strict';var f,g=[];function l(a){g.push(a);1==g.length&&f()}function m(){for(;g.length;)g[0](),g.shift()}f=function(){setTimeout(m)};function n(a){this.a=p;this.b=void 0;this.f=[];var b=this;try{a(function(a){q(b,a)},function(a){r(b,a)})}catch(c){r(b,c)}}var p=2;function t(a){return new n(function(b,c){c(a)})}function u(a){return new n(function(b){b(a)})}function q(a,b){if(a.a==p){if(b==a)throw new TypeError;var c=!1;try{var d=b&&b.then;if(null!=b&&"object"==typeof b&&"function"==typeof d){d.call(b,function(b){c||q(a,b);c=!0},function(b){c||r(a,b);c=!0});return}}catch(e){c||r(a,e);return}a.a=0;a.b=b;v(a)}}
# function r(a,b){if(a.a==p){if(b==a)throw new TypeError;a.a=1;a.b=b;v(a)}}function v(a){l(function(){if(a.a!=p)for(;a.f.length;){var b=a.f.shift(),c=b[0],d=b[1],e=b[2],b=b[3];try{0==a.a?"function"==typeof c?e(c.call(void 0,a.b)):e(a.b):1==a.a&&("function"==typeof d?e(d.call(void 0,a.b)):b(a.b))}catch(h){b(h)}}})}n.prototype.g=function(a){return this.c(void 0,a)};n.prototype.c=function(a,b){var c=this;return new n(function(d,e){c.f.push([a,b,d,e]);v(c)})};
# function w(a){return new n(function(b,c){function d(c){return function(d){h[c]=d;e+=1;e==a.length&&b(h)}}var e=0,h=[];0==a.length&&b(h);for(var k=0;k<a.length;k+=1)u(a[k]).c(d(k),c)})}function x(a){return new n(function(b,c){for(var d=0;d<a.length;d+=1)u(a[d]).c(b,c)})};window.Promise||(window.Promise=n,window.Promise.resolve=u,window.Promise.reject=t,window.Promise.race=x,window.Promise.all=w,window.Promise.prototype.then=n.prototype.c,window.Promise.prototype["catch"]=n.prototype.g);}());
#
# (function(){function l(a,b){document.addEventListener?a.addEventListener("scroll",b,!1):a.attachEvent("scroll",b)}function m(a){document.body?a():document.addEventListener?document.addEventListener("DOMContentLoaded",function c(){document.removeEventListener("DOMContentLoaded",c);a()}):document.attachEvent("onreadystatechange",function k(){if("interactive"==document.readyState||"complete"==document.readyState)document.detachEvent("onreadystatechange",k),a()})};function r(a){this.a=document.createElement("div");this.a.setAttribute("aria-hidden","true");this.a.appendChild(document.createTextNode(a));this.b=document.createElement("span");this.c=document.createElement("span");this.h=document.createElement("span");this.f=document.createElement("span");this.g=-1;this.b.style.cssText="max-width:none;display:inline-block;position:absolute;height:100%;width:100%;overflow:scroll;font-size:16px;";this.c.style.cssText="max-width:none;display:inline-block;position:absolute;height:100%;width:100%;overflow:scroll;font-size:16px;";
# this.f.style.cssText="max-width:none;display:inline-block;position:absolute;height:100%;width:100%;overflow:scroll;font-size:16px;";this.h.style.cssText="display:inline-block;width:200%;height:200%;font-size:16px;max-width:none;";this.b.appendChild(this.h);this.c.appendChild(this.f);this.a.appendChild(this.b);this.a.appendChild(this.c)}
# function t(a,b){a.a.style.cssText="max-width:none;min-width:20px;min-height:20px;display:inline-block;overflow:hidden;position:absolute;width:auto;margin:0;padding:0;top:-999px;white-space:nowrap;font-synthesis:none;font:"+b+";"}function y(a){var b=a.a.offsetWidth,c=b+100;a.f.style.width=c+"px";a.c.scrollLeft=c;a.b.scrollLeft=a.b.scrollWidth+100;return a.g!==b?(a.g=b,!0):!1}function z(a,b){function c(){var a=k;y(a)&&a.a.parentNode&&b(a.g)}var k=a;l(a.b,c);l(a.c,c);y(a)};function A(a,b){var c=b||{};this.family=a;this.style=c.style||"normal";this.weight=c.weight||"normal";this.stretch=c.stretch||"normal"}var B=null,C=null,E=null,F=null;function G(){if(null===C)if(J()&&/Apple/.test(window.navigator.vendor)){var a=/AppleWebKit\/([0-9]+)(?:\.([0-9]+))(?:\.([0-9]+))/.exec(window.navigator.userAgent);C=!!a&&603>parseInt(a[1],10)}else C=!1;return C}function J(){null===F&&(F=!!document.fonts);return F}
# function K(){if(null===E){var a=document.createElement("div");try{a.style.font="condensed 100px sans-serif"}catch(b){}E=""!==a.style.font}return E}function L(a,b){return[a.style,a.weight,K()?a.stretch:"","100px",b].join(" ")}
# A.prototype.load=function(a,b){var c=this,k=a||"BESbswy",q=0,D=b||3E3,H=(new Date).getTime();return new Promise(function(a,b){if(J()&&!G()){var M=new Promise(function(a,b){function e(){(new Date).getTime()-H>=D?b():document.fonts.load(L(c,'"'+c.family+'"'),k).then(function(c){1<=c.length?a():setTimeout(e,25)},function(){b()})}e()}),N=new Promise(function(a,c){q=setTimeout(c,D)});Promise.race([N,M]).then(function(){clearTimeout(q);a(c)},function(){b(c)})}else m(function(){function u(){var b;if(b=-1!=
# f&&-1!=g||-1!=f&&-1!=h||-1!=g&&-1!=h)(b=f!=g&&f!=h&&g!=h)||(null===B&&(b=/AppleWebKit\/([0-9]+)(?:\.([0-9]+))/.exec(window.navigator.userAgent),B=!!b&&(536>parseInt(b[1],10)||536===parseInt(b[1],10)&&11>=parseInt(b[2],10))),b=B&&(f==v&&g==v&&h==v||f==w&&g==w&&h==w||f==x&&g==x&&h==x)),b=!b;b&&(d.parentNode&&d.parentNode.removeChild(d),clearTimeout(q),a(c))}function I(){if((new Date).getTime()-H>=D)d.parentNode&&d.parentNode.removeChild(d),b(c);else{var a=document.hidden;if(!0===a||void 0===a)f=e.a.offsetWidth,
# g=n.a.offsetWidth,h=p.a.offsetWidth,u();q=setTimeout(I,50)}}var e=new r(k),n=new r(k),p=new r(k),f=-1,g=-1,h=-1,v=-1,w=-1,x=-1,d=document.createElement("div");d.dir="ltr";t(e,L(c,"sans-serif"));t(n,L(c,"serif"));t(p,L(c,"monospace"));d.appendChild(e.a);d.appendChild(n.a);d.appendChild(p.a);document.body.appendChild(d);v=e.a.offsetWidth;w=n.a.offsetWidth;x=p.a.offsetWidth;I();z(e,function(a){f=a;u()});t(e,L(c,'"'+c.family+'",sans-serif'));z(n,function(a){g=a;u()});t(n,L(c,'"'+c.family+'",serif'));
# z(p,function(a){h=a;u()});t(p,L(c,'"'+c.family+'",monospace'))})})};"object"===typeof module?module.exports=A:(window.FontFaceObserver=A,window.FontFaceObserver.prototype.load=A.prototype.load);}());
#
# (function( w ){
# if( w.document.documentElement.className.indexOf( "fonts-loaded" ) > -1 ){ return; }
#
# var html = document.documentElement;
# var FS500 = new w.FontFaceObserver("Fira Sans", { weight: 500 });
#
# FS500.load().then(function() {
# html.classList.add('fonts-loaded');
# sessionStorage.fontsLoaded = true;
# console.log('FS500-loaded');
# }).catch(function () {
# sessionStorage.fontsLoaded = false;
# console.log('FS500-unloaded');
# });
#
# if (sessionStorage.fontsLoaded) {
# html.classList.add('fonts-loaded');
# }
# }(this));
#      </script>
#      <script src="https://dr.habracdn.net/habr/5f324012/javascripts/libs/jquery-1.8.3.min.js">
#      </script>
#      <script src="https://dr.habracdn.net/habr/5f324012/javascripts/libs/chance.min.js">
#      </script>
#      <script src="https://dr.habracdn.net/habr/5f324012/javascripts/libs/html2canvas.min.js">
#      </script>
#      <script src="https://unpkg.com/pure-md5@latest/lib/index.js">
#      </script>
#      <script async="" src="https://cdn.onthe.io/io.js/Tn4LrERWU1qX">
#      </script>
#      <script>
#       window._io_config = window._io_config || {};
#     window._io_config["0.2.0"] = window._io_config["0.2.0"] || [];
#     window._io_config["0.2.0"].push({
#     "page_url": "https:\/\/habr.com\/ru\/all\/",
#     "page_url_canonical": "https:\/\/habr.com\/ru\/all\/",
#     "page_title": "Все публикации подряд",
#     "page_type": "main",
#     "page_language": "ru"
# });
#      </script>
#      <script>
#       window.create_callback_for_blocked = function(key) {
#     return function() {
#       googletag.cmd.push(function () {
#         googletag.display(key);
#       });
#     }
#   }
#
#   window.habr_blockers_checker = new function() {
#     var result;
#     var callbacksQueue = [];
#     var calledOnce = false;
#
#     function fireCallbacks() {
#       callbacksQueue.forEach(function(callback) {
#         callback(result);
#       });
#       callbacksQueue = [];
#     }
#
#     this.detect = function(imgUrl, callback) {
#       var checksRemain = 2;
#       var detected = false;
#       var error1 = false;
#       var error2 = false;
#
#       if (typeof callback !== 'function') {
#         return;
#       };
#
#       callbacksQueue.push(callback);
#
#       if (typeof result !== 'undefined') {
#         fireCallbacks();
#       };
#
#       if (calledOnce) {
#         return;
#       }
#       calledOnce = true;
#
#       imgUrl += '?ch=*&rn=*';
#
#       function beforeCheck(timeout) {
#         if (checksRemain === 0 || timeout > 1E3) {
#           result = checksRemain === 0 && detected;
#           fireCallbacks();
#         } else {
#           setTimeout(function() {
#             beforeCheck(timeout * 2)
#           }, timeout * 2);
#         }
#       }
#
#       function checkImages() {
#         if (--checksRemain) {
#           return;
#         };
#         detected = !error1 && error2;
#       }
#
#       var random = Math.random() * 11;
#
#       var img1 = new Image;
#       img1.onload = checkImages;
#       img1.onerror = function() {
#         error1 = true;
#         checkImages()
#       };
#       img1.src = imgUrl.replace(/\*/, 1).replace(/\*/, random);
#
#       var img2 = new Image;
#       img2.onload = checkImages;
#       img2.onerror = function() {
#         error2 = true;
#         checkImages()
#       };
#       img2.src = imgUrl.replace(/\*/, 2).replace(/\*/, random);
#
#       beforeCheck(250, callback)
#     };
#
#     this.detectWrapper = function(callback) {
#       return this.detect('/images/px.gif', callback);
#     };
#   };
#
#   window.display_dfp_slot = function(key) {
#     if (window.habr_blockers_checker) {
#       window.habr_blockers_checker.detectWrapper(window.create_callback_for_blocked(key));
#     } else {
#       window.create_callback_for_blocked(key)();
#     }
#   };
#      </script>
#      <script src="https://dr.habracdn.net/habr/5f324012/javascripts/libs/raven.min.js">
#      </script>
#      <script>
#       Raven.config('https://830576edd4b7478086093f693a5a0df5@s.tmtm.ru/37', {
#   maxBreadcrumbs: 50,
#   sampleRate: 0.5,
#   whitelistUrls: [/https?:\/\/((www)\.)?(m\.)?habr\.com/],
# }).install()
#      </script>
#      <script src="https://dr.habracdn.net/habr/5f324012/javascripts/_parts/advertise.js">
#      </script>
#      <script src="https://dr.habracdn.net/habr/5f324012/javascripts/_parts/adriver.js">
#      </script>
#      <script async="" src="https://www.googletagservices.com/tag/js/gpt.js">
#      </script>
#      <script async="" src="https://static.criteo.net/js/ld/publishertag.js">
#      </script>
#      <script>
#       var googletag = googletag || {};
#   googletag.cmd = googletag.cmd || [];
#      </script>
#      <script>
#       // TODO: move this code to module
#   //       move dot in chains to start of line and use one indent level:
#   //               ```
#   //                  start()
#   //                    .chainEnd()
#   //               ```
#
#   var ENABLE_YANDEX_ADS = false;
#
#   function display_yandex_rtb(yandexId, divId) {
#     $('#' + divId).show();
#     (function(w, d, n, s, t) {
#       w[n] = w[n] || [];
#       w[n].push(function() {
#         Ya.Context.AdvManager.render({
#           blockId: yandexId,
#           renderTo: divId,
#           async: true
#         });
#       });
#       t = d.getElementsByTagName('script')[0];
#       s = d.createElement('script');
#       s.type = 'text/javascript';
#       s.src = '//an.yandex.ru/system/context.js';
#       s.async = true;
#       t.parentNode.insertBefore(s, t);
#     })(this, this.document, 'yandexContextAsyncCallbacks');
#   }
#
#   function listen_googletag_and_render_yandex(yandexId, targetDivId) {
#     if (!window.googletag || !window.googletag.cmd) {
#       return;
#     }
#     window.googletag.cmd.push(function() {
#       if (!window.googletag.pubads) {
#         return;
#       }
#       if (ENABLE_YANDEX_ADS) {
#         window.googletag.pubads()
#           .addEventListener('slotRenderEnded', function(event) {
#             var divId = event.slot.getSlotElementId();
#             if (divId === targetDivId && event.isEmpty) {
#               window.display_yandex_rtb(yandexId, divId);
#             }
#           });
#       }
#     });
#   }
#
#   function getRoxotItem(storageKey, config) {
#     if (config) {
#       var { randomVal, returnCode } = config;
#     } else {
#       var randomVal = 100,
#           returnCode = '101';
#     }
#     try {
#       var groupId = localStorage.getItem(storageKey);
#       if (groupId === null) {
#         groupId = 1 + Math.floor(Math.random() * randomVal);
#         localStorage.setItem(storageKey, groupId);
#       }
#       return '' + groupId;
#     }
#     catch (e) {
#       return returnCode;
#     }
#   }
#
#   function getRoxotEvent() {
#     return '' + (1 + Math.floor(Math.random() * 100));
#   }
#
#   function leftpad(str, len, ch) {
#     str = String(str);
#
#     var i = -1;
#
#     if (!ch && ch !== 0) {
#       ch = ' ';
#     };
#
#     len = len - str.length;
#
#     while (++i < len) {
#       str = ch + str;
#     }
#
#     return str;
#   }
#
#   var WEEK_DAYS = ['su', 'mo', 'tu', 'we', 'th', 'fr', 'sa'];
#
#   function initializeDFP(usesABP) {
#     var currentDate = new Date();
#     var hours = currentDate.getHours();
#     var hoursStr = leftpad(hours, 2, '0');
#     var weekDayCode = WEEK_DAYS[currentDate.getDay()];
#     googletag.cmd.push(function() {
#       if (usesABP) {
#   googletag.defineSlot('/235032688/HH/HH02_inpage_wide', [[1, 1], [780, 130], [780, 200], [780, 180], [780, 110], [728, 90]], 'div-gpt-hh-inpage-wide').addService(googletag.pubads());
#   window.listen_googletag_and_render_yandex('R-A-149298-32', 'div-gpt-hh-inpage-wide');
# } else {
#   googletag.defineSlot('/235032688/HH/HH02_inpage_wide', [[1, 1], [780, 200], [780, 130], [780, 180], [780, 110], [728, 90], [780, 195], [780, 210], [780, 260]], 'div-gpt-hh-inpage-wide').addService(googletag.pubads());
#   window.listen_googletag_and_render_yandex('R-A-149298-36', 'div-gpt-hh-inpage-wide');
# }
#       if (usesABP) {
#   googletag.defineSlot('/235032688/HH/HH01_ATF_Poster', [[1, 1], [300, 500], [300, 250], [300, 300], [300, 400], [300, 200], [300, 100], [240, 400]], 'div-gpt-hh-atf').addService(googletag.pubads());
#   window.listen_googletag_and_render_yandex('R-A-149298-31', 'div-gpt-hh-atf');
# } else {
#   googletag.defineSlot('/235032688/HH/HH01_ATF_Poster', [[1, 1], [300, 500], [300, 600], [300, 250], [300, 300], [300, 400], [300, 200], [300, 150], [300, 100], [240, 400]], 'div-gpt-hh-atf').addService(googletag.pubads());
#   window.listen_googletag_and_render_yandex('R-A-149298-35', 'div-gpt-hh-atf');
# }
#
#       googletag.pubads().enableSingleRequest();
#       if (!usesABP) {
#         googletag.pubads().disableInitialLoad(); //We will wait for the Criteo Bidder Call before calling the adserver
#       }
#       googletag.pubads().collapseEmptyDivs();
#       googletag.pubads().
#       setTargeting('roxot-group-id', getRoxotItem('roxot-gid', { randomVal: 10000, returnCode: '10001'})).
#       setTargeting('roxot-sector-id', getRoxotItem('roxot-sid')).
#       setTargeting('roxot-deep', getRoxotItem('roxot-deep')).
#       setTargeting('roxot-event-group-id', getRoxotEvent()).
#       setTargeting('roxot-event', getRoxotEvent()).
#       setTargeting('roxot-event-deep', getRoxotEvent()).
#       setTargeting('roxot-minutes', (new Date).getUTCMinutes().toString()).
#       setTargeting('roxot-hours', (new Date).getUTCHours().toString()).
#       setTargeting('roxot-day', (new Date).getUTCDay().toString()).
#       setTargeting('chr', hoursStr).
#       setTargeting('cwd', weekDayCode).
#       setTargeting('aa', (usesABP) ? 'yes' : 'no').
#       setTargeting('path', window.location.pathname + window.location.search).
#       setTargeting('feedtype', ["all_all","posts"]).
#       setTargeting('dev', [0]).
#       setTargeting('user', ["guest"]).
#       setTargeting('pagetype', ["feed"]);
#       googletag.enableServices();
#
#       if (!usesABP) {
#         window.Criteo = window.Criteo || {};
#         window.Criteo.events = window.Criteo.events || [];
#         var launchAdServer = function () {
#           googletag.cmd.push(function () {
#             Criteo.SetDFPKeyValueTargeting(); //This will append Criteo keywords to the adserver call
#             googletag.pubads().refresh(); //This will trigger the adserver call
#           });
#         };
#         Criteo.events.push(function () {
#           var adUnits = {
#             'placements': [
#               {'slotid': 'div-gpt-hh-inpage-wide', 'zoneid': 1173491}, // TMTM - RU - CDB - SA - Habr - 780x180
#               {'slotid': 'div-gpt-hh-atf', 'zoneid': 1173489}, // TMTM - RU - CDB - SA - Habr - 300x600
#             ]
#           };
#           // Define the price band range
#           Criteo.SetLineItemRanges('0..599:1;600..1398:2;1400..3000:5');
#           // Call Criteo and execute the callback function for a given timeout
#           Criteo.RequestBids(adUnits, launchAdServer, 750);
#         });
#       }
#     });
#   }
#   if (window.habr_blockers_checker) {
#     window.habr_blockers_checker.detectWrapper(initializeDFP);
#   } else {
#     initializeDFP(false);
#   }
#      </script>
#      <script type="text/javascript">
#       $(document).ready(function () {
#     if (!$.cookie('split201901')) {
#       $.cookie(
#         'split201901',
#         'A',
#         {
#           expires: 3 * 7,
#           domain: 'habr.com',
#           path: '/',
#           secure: true
#         }
#       );
#     }
#   });
#      </script>
#     </link>
#    </meta>
#   </meta>
#  </head>
#  <body class="nl">
#   <div class="layout">
#    <div class="layout__row layout__row_services">
#     <div id="TMpanel">
#      <div class="container">
#       <div class="logo-wrapper">
#        <a class="logo" href="https://habr.com/ru/" title="">
#         <svg height="24" viewbox="0 0 62 24" width="62" xmlns="http://www.w3.org/2000/svg">
#          <path d="M16.875 19L11.075 10.225L16.825 1.4H12.6L8.75 7.4L4.94999 1.4H0.574994L6.32499 10.15L0.524994 19H4.79999L8.64999 12.975L12.525 19H16.875Z">
#          </path>
#          <path d="M24.2607 5.775C20.8857 5.775 18.9607 7.625 18.6107 9.85H22.0107C22.2107 9.175 22.8607 8.6 24.1107 8.6C25.3357 8.6 26.2357 9.225 26.2357 10.425V11.025H23.4107C20.1107 11.025 18.1107 12.55 18.1107 15.2C18.1107 17.8 20.1107 19.3 22.6107 19.3C24.2857 19.3 25.6357 18.65 26.4357 17.6V19H29.8107V10.55C29.8107 7.4 27.5857 5.775 24.2607 5.775ZM23.6107 16.475C22.4857 16.475 21.7607 15.925 21.7607 15.025C21.7607 14.1 22.5607 13.55 23.6857 13.55H26.2357V14.125C26.2357 15.625 25.0107 16.475 23.6107 16.475Z">
#          </path>
#          <path d="M39.925 6.3C38.125 6.3 36.65 6.95 35.7 8.275C35.95 5.85 36.925 4.65 39.375 4.275L44.3 3.55V0.375L39.025 1.25C33.925 2.1 32.35 5.5 32.35 11.175C32.35 16.275 34.825 19.3 39.2 19.3C43.125 19.3 45.55 16.3 45.55 12.7C45.55 8.825 43.3 6.3 39.925 6.3ZM39.025 16.25C37.125 16.25 36.075 14.725 36.075 12.675C36.075 10.7 37.175 9.275 39.05 9.275C40.875 9.275 41.9 10.75 41.9 12.7C41.9 14.65 40.9 16.25 39.025 16.25Z">
#          </path>
#          <path d="M55.2855 5.775C53.3855 5.775 52.1605 6.6 51.5105 7.575V6.075H48.0105V23.775H51.6605V17.75C52.3105 18.65 53.5355 19.3 55.1855 19.3C58.3605 19.3 60.8855 16.8 60.8855 12.55C60.8855 8.225 58.3605 5.775 55.2855 5.775ZM54.4105 16.15C52.7105 16.15 51.5855 14.775 51.5855 12.6V12.5C51.5855 10.325 52.7105 8.925 54.4105 8.925C56.1105 8.925 57.2105 10.35 57.2105 12.55C57.2105 14.75 56.1105 16.15 54.4105 16.15Z">
#          </path>
#         </svg>
#        </a>
#        <span class="projects-dropdown" id="dropdown-control">
#         <svg fill="none" height="6" viewbox="0 0 10 6" width="10" xmlns="http://www.w3.org/2000/svg">
#          <path clip-rule="evenodd" d="M5.70711 5.70711C5.31658 6.09763 4.68342 6.09763 4.29289 5.70711L0.292892 1.70711C-0.097632 1.31658 -0.0976319 0.683417 0.292892 0.292893C0.683417 -0.0976308 1.31658 -0.0976308 1.70711 0.292893L5 3.58579L8.29289 0.292894C8.68342 -0.0976301 9.31658 -0.0976301 9.70711 0.292894C10.0976 0.683418 10.0976 1.31658 9.70711 1.70711L5.70711 5.70711Z" fill-rule="evenodd">
#          </path>
#         </svg>
#        </span>
#        <div class="dropdown hidden" id="dropdown">
#         <div class="dropdown-heading">
#          Все сервисы Хабра
#         </div>
#         <a class="service" href="/">
#          <div class="service-title">
#           <svg fill="none" height="22" viewbox="0 0 52 22" width="52" xmlns="http://www.w3.org/2000/svg">
#            <path d="M13.86 17.0001L8.514 9.23405L13.816 1.51205H11.528L7.26 7.76005L2.97 1.51205H0.659997L5.984 9.19005L0.615997 17.0001H2.926L7.194 10.6861L11.528 17.0001H13.86Z" fill="#333333">
#            </path>
#            <path d="M20.181 5.67005C17.651 5.67005 16.111 7.10005 15.759 8.81605H17.585C17.893 8.00205 18.685 7.34205 20.137 7.34205C21.567 7.34205 22.645 8.11205 22.645 9.65205V10.4001H19.697C16.991 10.4001 15.341 11.6981 15.341 13.8321C15.341 15.9441 17.013 17.2421 19.169 17.2421C20.577 17.2421 21.897 16.7141 22.733 15.6801V17.0001H24.515V9.65205C24.515 7.16605 22.777 5.67005 20.181 5.67005ZM19.411 15.5921C18.179 15.5921 17.255 14.9761 17.255 13.8101C17.255 12.6221 18.289 12.0061 19.807 12.0061H22.645V12.8201C22.645 14.5141 21.171 15.5921 19.411 15.5921Z" fill="#333333">
#            </path>
#            <path d="M32.9685 5.91205C31.2965 5.91205 29.9545 6.55005 29.1185 7.78205C29.3825 5.27405 30.3945 3.88805 32.9025 3.42605L36.9505 2.67805V0.852051L32.5065 1.75405C28.7665 2.52405 27.2045 4.96605 27.2045 10.5101C27.2045 14.8001 29.4045 17.2421 32.7925 17.2421C36.0265 17.2421 38.0505 14.7121 38.0505 11.5441C38.0505 7.91405 35.8285 5.91205 32.9685 5.91205ZM32.7045 15.5261C30.6145 15.5261 29.2065 13.9641 29.2065 11.4561C29.2065 8.97005 30.7685 7.60605 32.7265 7.60605C34.7725 7.60605 36.1145 9.23405 36.1145 11.5441C36.1145 13.8541 34.7945 15.5261 32.7045 15.5261Z" fill="#333333">
#            </path>
#            <path d="M46.1431 5.67005C44.2291 5.67005 43.0631 6.55005 42.5131 7.49605V5.91205H40.6871V21.2021H42.5791V15.6361C43.1071 16.4501 44.2951 17.2421 46.0771 17.2421C48.6291 17.2421 51.1371 15.3721 51.1371 11.4561C51.1371 7.56205 48.6511 5.67005 46.1431 5.67005ZM45.9011 15.5261C43.8551 15.5261 42.5131 13.9641 42.5131 11.5001V11.4121C42.5131 8.94805 43.8551 7.38605 45.9011 7.38605C47.8811 7.38605 49.2011 9.03605 49.2011 11.4561C49.2011 13.8761 47.8811 15.5261 45.9011 15.5261Z" fill="#333333">
#            </path>
#           </svg>
#          </div>
#          <p class="service-description">
#           Сообщество IT-специалистов
#          </p>
#         </a>
#         <a class="service" href="https://qna.habr.com?utm_source=habr&amp;utm_medium=habr_top_panel">
#          <h4 class="service-title">
#           <svg fill="none" height="18" viewbox="0 0 46 18" width="46" xmlns="http://www.w3.org/2000/svg">
#            <path d="M14.4 8.25602C14.4 3.65802 11.606 0.27002 7.27201 0.27002C2.93801 0.27002 0.144012 3.65802 0.144012 8.25602C0.144012 12.854 2.93801 16.242 7.27201 16.242C8.41601 16.242 9.45001 16.022 10.352 15.604L11.518 17.342H13.696L11.848 14.614C13.476 13.184 14.4 10.918 14.4 8.25602ZM7.27201 14.416C4.10401 14.416 2.14601 11.864 2.14601 8.25602C2.14601 4.64802 4.10401 2.09602 7.27201 2.09602C10.44 2.09602 12.398 4.64802 12.398 8.25602C12.398 10.236 11.826 11.908 10.77 12.986L9.64801 11.314H7.47001L9.29601 14.02C8.70201 14.284 8.02001 14.416 7.27201 14.416Z" fill="#333333">
#            </path>
#            <path d="M30.965 16L27.973 12.766L30.921 9.11402H28.699L26.829 11.534L23.331 7.77202C25.377 6.80402 26.455 5.59402 26.455 3.85602C26.455 1.78802 24.871 0.27002 22.583 0.27002C20.207 0.27002 18.535 1.89802 18.535 3.87802C18.535 5.19802 19.305 6.12202 20.163 7.00202L20.427 7.26602C17.985 8.25602 16.753 9.73002 16.753 11.732C16.753 14.196 18.667 16.242 21.835 16.242C23.749 16.242 25.311 15.494 26.565 14.24L26.763 14.042L28.567 16H30.965ZM22.539 1.92002C23.705 1.92002 24.629 2.62402 24.629 3.83402C24.629 5.00002 23.793 5.90202 22.187 6.62802L21.571 6.01202C21.109 5.55002 20.405 4.82402 20.405 3.81202C20.405 2.66802 21.329 1.92002 22.539 1.92002ZM21.945 14.504C19.877 14.504 18.755 13.316 18.755 11.666C18.755 10.258 19.591 9.20202 21.593 8.43202L25.641 12.832L25.509 12.964C24.541 13.976 23.309 14.504 21.945 14.504Z" fill="#333333">
#            </path>
#            <path d="M43.5619 16H45.6739L39.8219 0.512019H37.7979L31.9459 16H34.0579L35.5539 11.908H42.0439L43.5619 16ZM38.7879 2.97602L41.3839 10.104H36.2139L38.7879 2.97602Z" fill="#333333">
#            </path>
#           </svg>
#          </h4>
#          <p class="service-description">
#           Ответы на любые вопросы об IT
#          </p>
#         </a>
#         <a class="service" href="https://career.habr.com?utm_source=habr&amp;utm_medium=habr_top_panel">
#          <div class="service-title">
#           <svg fill="none" height="21" viewbox="0 0 84 21" width="84" xmlns="http://www.w3.org/2000/svg">
#            <path d="M12.442 16L4.96201 7.92596L12.31 0.511963H9.78001L2.894 7.41996V0.511963H0.936005V16H2.894V8.60796L9.84601 16H12.442Z" fill="#333333">
#            </path>
#            <path d="M18.3646 4.66996C15.8346 4.66996 14.2946 6.09996 13.9426 7.81596H15.7686C16.0766 7.00196 16.8686 6.34196 18.3206 6.34196C19.7506 6.34196 20.8286 7.11196 20.8286 8.65196V9.39996H17.8806C15.1746 9.39996 13.5246 10.698 13.5246 12.832C13.5246 14.944 15.1966 16.242 17.3526 16.242C18.7606 16.242 20.0806 15.714 20.9166 14.68V16H22.6986V8.65196C22.6986 6.16596 20.9606 4.66996 18.3646 4.66996ZM17.5946 14.592C16.3626 14.592 15.4386 13.976 15.4386 12.81C15.4386 11.622 16.4726 11.006 17.9906 11.006H20.8286V11.82C20.8286 13.514 19.3546 14.592 17.5946 14.592Z" fill="#333333">
#            </path>
#            <path d="M31.3501 4.66996C29.4361 4.66996 28.2701 5.54996 27.7201 6.49596V4.91196H25.8941V20.202H27.7861V14.636C28.3141 15.45 29.5021 16.242 31.2841 16.242C33.8361 16.242 36.3441 14.372 36.3441 10.456C36.3441 6.56196 33.8581 4.66996 31.3501 4.66996ZM31.1081 14.526C29.0621 14.526 27.7201 12.964 27.7201 10.5V10.412C27.7201 7.94796 29.0621 6.38596 31.1081 6.38596C33.0881 6.38596 34.4081 8.03596 34.4081 10.456C34.4081 12.876 33.0881 14.526 31.1081 14.526Z" fill="#333333">
#            </path>
#            <path d="M43.3561 8.49796H40.8701V4.91196H38.9781V16H43.3341C45.7101 16 47.2501 14.372 47.2501 12.216C47.2501 10.06 45.7101 8.49796 43.3561 8.49796ZM43.1141 14.328H40.8701V10.17H43.1141C44.5661 10.17 45.3581 11.028 45.3581 12.216C45.3581 13.404 44.5661 14.328 43.1141 14.328Z" fill="#333333">
#            </path>
#            <path d="M59.1788 11.028V10.06C59.1788 6.75996 57.2868 4.66996 54.3388 4.66996C51.3028 4.66996 49.1248 6.86996 49.1248 10.456C49.1248 14.02 51.2808 16.242 54.4928 16.242C57.3748 16.242 58.7608 14.438 59.0468 13.14H57.1328C56.9348 13.712 56.0548 14.548 54.5148 14.548C52.4688 14.548 51.1048 13.052 51.1048 11.072V11.028H59.1788ZM54.2948 6.36396C56.0768 6.36396 57.1768 7.50796 57.2648 9.42196H51.1268C51.2808 7.59596 52.4468 6.36396 54.2948 6.36396Z" fill="#333333">
#            </path>
#            <path d="M67.272 4.66996C65.358 4.66996 64.192 5.54996 63.642 6.49596V4.91196H61.816V20.202H63.708V14.636C64.236 15.45 65.424 16.242 67.206 16.242C69.758 16.242 72.266 14.372 72.266 10.456C72.266 6.56196 69.78 4.66996 67.272 4.66996ZM67.03 14.526C64.984 14.526 63.642 12.964 63.642 10.5V10.412C63.642 7.94796 64.984 6.38596 67.03 6.38596C69.01 6.38596 70.33 8.03596 70.33 10.456C70.33 12.876 69.01 14.526 67.03 14.526Z" fill="#333333">
#            </path>
#            <path d="M79.058 4.66996C76.528 4.66996 74.988 6.09996 74.636 7.81596H76.462C76.77 7.00196 77.562 6.34196 79.014 6.34196C80.444 6.34196 81.522 7.11196 81.522 8.65196V9.39996H78.574C75.868 9.39996 74.218 10.698 74.218 12.832C74.218 14.944 75.89 16.242 78.046 16.242C79.454 16.242 80.774 15.714 81.61 14.68V16H83.392V8.65196C83.392 6.16596 81.654 4.66996 79.058 4.66996ZM78.288 14.592C77.056 14.592 76.132 13.976 76.132 12.81C76.132 11.622 77.166 11.006 78.684 11.006H81.522V11.82C81.522 13.514 80.048 14.592 78.288 14.592Z" fill="#333333">
#            </path>
#           </svg>
#          </div>
#          <p class="service-description">
#           Профессиональное развитие в IT
#          </p>
#         </a>
#         <a class="service" href="https://freelance.habr.com?utm_source=habr&amp;utm_medium=habr_top_panel">
#          <div class="service-title">
#           <svg fill="none" height="21" viewbox="0 0 91 21" width="91" xmlns="http://www.w3.org/2000/svg">
#            <path d="M9.032 1.65602V0.0720215H7.118V1.65602C3.268 1.72202 0.0339966 4.01002 0.0339966 8.16802C0.0339966 12.304 3.268 14.592 7.118 14.658V16.242H9.032V14.658C12.882 14.592 16.116 12.304 16.116 8.16802C16.116 4.01002 12.882 1.72202 9.032 1.65602ZM7.118 12.898C4.082 12.832 2.014 11.05 2.014 8.16802C2.014 5.26402 4.082 3.48202 7.118 3.41602V12.898ZM9.032 12.898V3.41602C12.068 3.48202 14.136 5.26402 14.136 8.16802C14.136 11.05 12.068 12.832 9.032 12.898Z" fill="#333333">
#            </path>
#            <path d="M24.2603 4.67002C22.3463 4.67002 21.1803 5.55002 20.6303 6.49602V4.91202H18.8043V20.202H20.6963V14.636C21.2243 15.45 22.4123 16.242 24.1943 16.242C26.7463 16.242 29.2543 14.372 29.2543 10.456C29.2543 6.56202 26.7683 4.67002 24.2603 4.67002ZM24.0183 14.526C21.9723 14.526 20.6303 12.964 20.6303 10.5V10.412C20.6303 7.94802 21.9723 6.38602 24.0183 6.38602C25.9983 6.38602 27.3183 8.03602 27.3183 10.456C27.3183 12.876 25.9983 14.526 24.0183 14.526Z" fill="#333333">
#            </path>
#            <path d="M39.4123 4.91202L33.7583 13.074V4.91202H31.8883V16H33.7583L39.4123 7.83802V16H41.2823V4.91202H39.4123Z" fill="#333333">
#            </path>
#            <path d="M46.0815 4.91202L45.5095 11.71C45.3555 13.624 44.9595 14.328 43.5735 14.328H43.2655V16.044H43.7935C46.0595 16.044 47.0935 14.856 47.3355 11.842L47.7755 6.60602H51.8455V16H53.7375V4.91202H46.0815Z" fill="#333333">
#            </path>
#            <path d="M61.2045 4.67002C58.6745 4.67002 57.1345 6.10002 56.7825 7.81602H58.6085C58.9165 7.00202 59.7085 6.34202 61.1605 6.34202C62.5905 6.34202 63.6685 7.11202 63.6685 8.65202V9.40002H60.7205C58.0145 9.40002 56.3645 10.698 56.3645 12.832C56.3645 14.944 58.0365 16.242 60.1925 16.242C61.6005 16.242 62.9205 15.714 63.7565 14.68V16H65.5385V8.65202C65.5385 6.16602 63.8005 4.67002 61.2045 4.67002ZM60.4345 14.592C59.2025 14.592 58.2785 13.976 58.2785 12.81C58.2785 11.622 59.3125 11.006 60.8305 11.006H63.6685V11.82C63.6685 13.514 62.1945 14.592 60.4345 14.592Z" fill="#333333">
#            </path>
#            <path d="M76.104 4.91202V9.37802H70.626V4.91202H68.734V16H70.626V11.094H76.104V16H77.996V4.91202H76.104Z" fill="#333333">
#            </path>
#            <path d="M85.9003 14.526C83.8983 14.526 82.5783 12.876 82.5783 10.456C82.5783 8.05802 83.8543 6.38602 85.8783 6.38602C87.6383 6.38602 88.4523 7.53002 88.7383 8.45402H90.6303C90.3443 6.69402 88.8263 4.67002 85.8783 4.67002C82.6883 4.67002 80.6423 7.13402 80.6423 10.456C80.6423 13.844 82.7323 16.242 85.8783 16.242C88.6283 16.242 90.3883 14.394 90.6303 12.414H88.7383C88.4963 13.36 87.7483 14.526 85.9003 14.526Z" fill="#333333">
#            </path>
#           </svg>
#          </div>
#          <p class="service-description">
#           Удаленная работа для IT-специалистов
#          </p>
#         </a>
#        </div>
#       </div>
#       <div class="bmenu">
#        <a class="bmenu__conversion" href="https://habr.com/sandbox/start/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'habr_top_panel', 'become_an_author'); }">
#         Как стать автором
#        </a>
#       </div>
#       <div class="bmenu_inner" style="display:flex!important;visibility:visible!important;">
#        <span class="bmenu slink">
#         <a href="https://u.tmtm.ru/huawei_ag_top" onclick="if (typeof ga === 'function') { ga('send', 'event', 'habr_top_panel', 'megapost', 'https://u.tmtm.ru/huawei_ag_top'); }" rel="noopener" style="color: #E37979" target="_blank">
#          Как я нашёл точку роста для своего проекта
#         </a>
#        </span>
#       </div>
#      </div>
#     </div>
#     <script>
#      var dropdown = document.querySelector('#dropdown');
#   var dropdownControl = document.querySelector('#dropdown-control');
#   var logoWrapper = document.querySelector('.logo-wrapper');
#
#   document.addEventListener('click', function(e) {
#       if (dropdown) {
#         var isClickInside = logoWrapper.contains(e.target);
#         var dropdownClosed = dropdown.classList.contains('hidden');
#         if (!isClickInside && !dropdownClosed) {
#           dropdown.classList.add('hidden');
#           dropdownControl.classList.remove('reverted');
#         }
#       }
#   });
#   if (dropdownControl) {
#     dropdownControl.onclick = function () {
#       dropdown.classList.toggle('hidden');
#       dropdownControl.classList.toggle('reverted');
#     }
#   }
#     </script>
#    </div>
#    <div class="layout__row layout__row_navbar">
#     <div class="layout__cell">
#      <div class="main-navbar">
#       <div class="main-navbar__section main-navbar__section_left">
#        <ul class="nav-links" id="navbar-links">
#         <li class="nav-links__item">
#          <a class="nav-links__item-link nav-links__item-link_current" href="https://habr.com/ru/top/">
#           Все потоки
#          </a>
#         </li>
#         <li class="nav-links__item">
#          <a class="nav-links__item-link" href="https://habr.com/ru/flows/develop/">
#           Разработка
#          </a>
#         </li>
#         <li class="nav-links__item">
#          <a class="nav-links__item-link" href="https://habr.com/ru/flows/admin/">
#           Администрирование
#          </a>
#         </li>
#         <li class="nav-links__item">
#          <a class="nav-links__item-link" href="https://habr.com/ru/flows/design/">
#           Дизайн
#          </a>
#         </li>
#         <li class="nav-links__item">
#          <a class="nav-links__item-link" href="https://habr.com/ru/flows/management/">
#           Менеджмент
#          </a>
#         </li>
#         <li class="nav-links__item">
#          <a class="nav-links__item-link" href="https://habr.com/ru/flows/marketing/">
#           Маркетинг
#          </a>
#         </li>
#         <li class="nav-links__item">
#          <a class="nav-links__item-link" href="https://habr.com/ru/flows/popsci/">
#           Научпоп
#          </a>
#         </li>
#        </ul>
#        <form action="https://habr.com/ru/search/#h" class="search-form" id="search-form" method="get">
#         <button class="btn btn_navbar_search icon-svg_search" id="search-form-btn" title="Поиск по сайту" type="button">
#          <svg class="icon-svg" fill="none" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#           <path clip-rule="evenodd" d="M17 11C17 14.3137 14.3137 17 11 17C7.68629 17 5 14.3137 5 11C5 7.68629 7.68629 5 11 5C14.3137 5 17 7.68629 17 11ZM15.5838 17.5574C14.2857 18.4665 12.7051 19 11 19C6.58172 19 3 15.4183 3 11C3 6.58172 6.58172 3 11 3C15.4183 3 19 6.58172 19 11C19 12.9998 18.2662 14.8282 17.0533 16.2307C17.0767 16.2502 17.0994 16.2709 17.1214 16.2929L20.4143 19.5858C20.8048 19.9763 20.8048 20.6095 20.4143 21C20.0238 21.3905 19.3906 21.3905 19.0001 21L15.7072 17.7071C15.6605 17.6604 15.6194 17.6102 15.5838 17.5574Z" fill-rule="evenodd">
#           </path>
#          </svg>
#         </button>
#         <label class="search-form__field-wrapper">
#          <input class="search-form__field" id="search-form-field" name="q" placeholder="Поиск" tabindex="-1" type="text"/>
#          <button class="btn btn_search-close" id="search-form-clear" title="Закрыть" type="button">
#           <svg aria-hidden="true" class="icon-svg icon-svg_navbar-close-search" height="32" role="img" version="1.1" viewbox="0 0 31 32" width="31">
#            <path d="M26.67 0L15.217 11.448 3.77 0 0 3.77l11.447 11.45L0 26.666l3.77 3.77L15.218 18.99l11.45 11.448 3.772-3.77-11.448-11.45L30.44 3.772z">
#            </path>
#           </svg>
#          </button>
#         </label>
#        </form>
#       </div>
#       <div class="main-navbar__section main-navbar__section_right">
#        <button class="btn btn_medium btn_navbar_lang js-show_lang_settings" type="button">
#         <svg class="icon-svg" height="18" width="18">
#          <use xlink:href="https://habr.com/5f324012/images/common-svg-sprite.svg#globus-v2">
#          </use>
#         </svg>
#        </button>
#        <a class="btn btn_medium btn_navbar_login" href="https://habr.com/ru/auth/login/" id="login">
#         Войти
#        </a>
#        <a class="btn btn_medium btn_navbar_registration" href="https://habr.com/ru/auth/register/">
#         Регистрация
#        </a>
#       </div>
#      </div>
#     </div>
#    </div>
#    <div class="layout__row layout__row_body">
#     <div class="layout__cell layout__cell_body">
#      <section class="column-wrapper column-wrapper_lists js-sticky-wrapper">
#       <div class="content_left js-content_left">
#        <div class="page-header page-header_110">
#         Все потоки
#        </div>
#        <div class="tabs">
#         <div class="tabs__level tabs-level_top tabs-menu">
#          <a class="tabs-menu__item tabs-menu__item_link" href="https://habr.com/ru/top/" rel="nofollow">
#           <h3 class="tabs-menu__item-text tabs-menu__item-text_active">
#            Статьи
#           </h3>
#          </a>
#          <a class="tabs-menu__item tabs-menu__item_link" href="https://habr.com/ru/news/" rel="nofollow">
#           <h3 class="tabs-menu__item-text">
#            Новости
#           </h3>
#          </a>
#          <a class="tabs-menu__item tabs-menu__item_link" href="https://habr.com/ru/hubs/" rel="nofollow">
#           <h3 class="tabs-menu__item-text">
#            Хабы
#           </h3>
#          </a>
#          <a class="tabs-menu__item tabs-menu__item_link" href="https://habr.com/ru/users/" rel="nofollow">
#           <h3 class="tabs-menu__item-text">
#            Авторы
#           </h3>
#          </a>
#          <a class="tabs-menu__item tabs-menu__item_link" href="https://habr.com/ru/companies/" rel="nofollow">
#           <h3 class="tabs-menu__item-text">
#            Компании
#           </h3>
#          </a>
#         </div>
#         <div class="tabs__level tabs__level_bottom">
#          <ul class="toggle-menu">
#           <li class="toggle-menu__item">
#            <a class="toggle-menu__item-link toggle-menu__item-link_active" href="https://habr.com/ru/all/" rel="nofollow">
#             Все подряд
#             <sup class="toggle-menu__item-counter toggle-menu__item-counter_new">
#              75
#             </sup>
#            </a>
#           </li>
#           <li class="toggle-menu__item">
#            <a class="toggle-menu__item-link" href="https://habr.com/ru/top/" rel="nofollow">
#             Лучшие
#            </a>
#           </li>
#          </ul>
#         </div>
#         <div class="tabs__level tabs__level_bottom">
#          <ul class="toggle-menu">
#           <li class="toggle-menu__item">
#            <a class="toggle-menu__item-link toggle-menu__item-link_active" href="https://habr.com/ru/all/all/" rel="nofollow" title="Все публикации в хронологическом порядке">
#             Без порога
#            </a>
#           </li>
#           <li class="toggle-menu__item">
#            <a class="toggle-menu__item-link" href="https://habr.com/ru/all/top10/" rel="nofollow" title="Все публикации с рейтингом 10 и выше">
#             ≥10
#            </a>
#           </li>
#           <li class="toggle-menu__item">
#            <a class="toggle-menu__item-link" href="https://habr.com/ru/all/top25/" rel="nofollow" title="Все публикации с рейтингом 25 и выше">
#             ≥25
#            </a>
#           </li>
#           <li class="toggle-menu__item">
#            <a class="toggle-menu__item-link" href="https://habr.com/ru/all/top50/" rel="nofollow" title="Все публикации с рейтингом 50 и выше">
#             ≥50
#            </a>
#           </li>
#           <li class="toggle-menu__item">
#            <a class="toggle-menu__item-link" href="https://habr.com/ru/all/top100/" rel="nofollow" title="Все публикации с рейтингом 100 и выше">
#             ≥100
#            </a>
#           </li>
#          </ul>
#         </div>
#        </div>
#        <div class="posts_list">
#         <ul class="content-list content-list_posts shortcuts_items">
#          <li class="content-list__item content-list__item_post shortcuts_item" id="post_514686">
#           <article class="post post_preview" lang="ru">
#            <header class="post__meta">
#             <a class="post__user-info user-info" href="https://habr.com/ru/users/naychenko/" title="Автор публикации">
#              <img class="user-info__image-pic user-info__image-pic_small" height="24" src="//habrastorage.org/getpro/habr/avatars/be8/03b/2e2/be803b2e23969442ac082d77b5824bb8.png" width="24"/>
#              <span class="user-info__nickname user-info__nickname_small">
#               naychenko
#              </span>
#             </a>
#             <span class="post__time">
#              сегодня в 11:42
#             </span>
#            </header>
#            <h2 class="post__title">
#             <a class="post__title_link" href="https://habr.com/ru/post/514686/">
#              Бизнес-ландшафт будущего
#             </a>
#            </h2>
#            <ul class="post__hubs inline-list">
#             <li class="inline-list__item inline-list__item_hub">
#              <a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/business_models/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Бизнес-модели'); }" rel="nofollow" title="Вы не подписаны на этот хаб">
#               Бизнес-модели
#              </a>
#              ,
#             </li>
#             <li class="inline-list__item inline-list__item_hub">
#              <a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/futurenow/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Будущее здесь'); }" rel="nofollow" title="Вы не подписаны на этот хаб">
#               Будущее здесь
#              </a>
#             </li>
#            </ul>
#            <ul class="post__marks inline-list">
#             <li class="inline-list__item inline-list__item_post-type">
#              <a class="post__type-label" href="https://habr.com/ru/sandbox/" title="Перейти в песочницу">
#               Из песочницы
#              </a>
#             </li>
#            </ul>
#            <div class="post__body post__body_crop">
#             <div class="post__text post__text-html post__text_v1">
#              В этой статье я хочу поделиться видением развития бизнеса в ближайшие 20 лет, ведь мы находимся в начале трансформации бизнес-ландшафта в новое равновесное состояние.
#              <br/>
#              <br/>
#              Пока эти изменения нечувствительны для многих, но вскоре это коснется абсолютно всех.
#              <br/>
#              <br/>
#              Данная работа стала результатом анализа большого объема источников, с которыми мне посчастливилось познакомится в рамках работы над проектированием нескольких платформ. В конце статьи я даю ссылки на наиболее важные из этих источников. Так что, эта работа не столько мое творение, сколько обзор и анализ работ других авторов, а также моя трактовка и попытка визуализировать предстоящие трансформации в бизнесе.
#              <br/>
#              <br/>
#              Для начала, давайте разберемся в бизнес-ландшафте настоящего. Упрощенно, текущий бизнес-ландшафт можно отобразить на следующей схеме:
#              <br/>
#              <br/>
#              <img alt="image" src="https://avatars.mds.yandex.net/get-zen_doc/3437146/pub_5f2fb0ce05d37277463d7ce6_5f2fb100f8aa134f8017d55e/scale_600">
#               <br/>
#               <br/>
#               <b>
#                (Н) Компании хитов
#               </b>
#               , ориентированные на удовлетворение массовых потребностей клиентов.
#               <br/>
#               <br/>
#               <b>
#                (LT) Нишевые компании «Длинного хвоста»
#               </b>
#               , ориентированные на удовлетворение персональных потребностей клиентов.
#               <br/>
#               <br/>
#               <b>
#                (A) Инфо-агенты
#               </b>
#               — компании-посредники между потребителями и поставщиками, сфокусированные на интересах потребителей, снижающие их издержки на поиск продуктов и услуг. Их пока практически нет.
#               <br/>
#               <br/>
#               <b>
#                (P) Платформы
#               </b>
#               — операторы масштаба, стимулирующие развитие компаний «длинного хвоста», снижающие затраты цепочки формирования ценностей за счет экономии на масштабе и коммодитизации зрелых компонентов.
#               <br/>
#               <br/>
#               <b>
#                (IN) Инфраструктура
#               </b>
#               — компании, занятые производством коммодитизированных продуктов и услуг, обеспечивающих деятельность компаний «длинного хвоста» под курированием и поддержкой платформ.
#               <br/>
#              </img>
#             </div>
#             <a class="btn btn_x-large btn_outline_blue post__habracut-btn" href="https://habr.com/ru/post/514686/#habracut">
#              Читать дальше →
#             </a>
#            </div>
#            <footer class="post__footer">
#             <ul class="post-stats js-user_" data-post-type="publish_ugc_ru,h_20752,h_22014,f_management,f_popsci" id="infopanel_post_514686">
#              <li class="post-stats__item">
#               <div class="post-stats__result">
#                <span class="post-stats__result-icon">
#                 <svg class="icon-svg_votes" height="16" width="10">
#                  <use xlink:href="https://habr.com/5f324012/images/common-svg-sprite.svg#counter-rating">
#                  </use>
#                 </svg>
#                </span>
#                <span class="post-stats__result-counter" title="Всего голосов 0: ↑0 и ↓0">
#                 0
#                </span>
#               </div>
#              </li>
# ...
#     PreProcess: function (element) {
#       var hasMath = false;
#       var images = element.querySelectorAll('[data-tex]');
#       for (var i = images.length - 1; i >= 0; i--) {
#         var img = images[i];
#         var tex = img.alt.replace(/(\r\n|\n|\r)/gm, " ");
#         if (tex && tex[0] === '$'){
#           var script = document.createElement("script"); script.type = "math/tex";
#           hasMath = true;
#           if (img.getAttribute('data-tex') == "display"){script.type += ";mode=display"}
#           MathJax.HTML.setScript(script, tex.substring(1,tex.length-1));
#           img.parentNode.replaceChild(script,img);
#         }
#       }
#     }
#   };
#
#   MathJax.Hub.Register.PreProcessor(["PreProcess", MathJax.Extension.Img2jax]);
# }
#
# function mathjaxInit() {
#  if (typeof MathJax === 'undefined') {
#     var url = 'https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.1/MathJax.js?config=TeX-AMS_SVG-full&locale=ru';
#     var mathScript = document.createElement("script");
#     mathScript.src = url;
#     mathScript.type = 'text/javascript';
#     document.body.appendChild(mathScript)
#
#     mathScript.onload = function() {
#       mathJaxConfig();
#     }
#   } else {
#     mathJaxConfig();
#   }
# }
#
# if (mathElements.length) {
#   mathjaxInit();
# }
#      </script>
#      <div class="footer-grid footer">
#       <div class="footer-grid__item footer-grid__item_copyright">
#        <span class="footer__copyright">
#         © 2006 – 2020 «
#         <a class="footer__link" href="https://company.habr.com/">
#          Habr
#         </a>
#         »
#        </span>
#       </div>
#       <div class="footer-grid__item footer-grid__item_link footer-grid__item_lang">
#        <svg class="icon-svg icon-svg_lang-footer" height="16" width="16">
#         <use xlink:href="https://habr.com/5f324012/images/common-svg-sprite.svg#globus-v2">
#         </use>
#        </svg>
#        <a class="footer__link js-show_lang_settings" href="#">
#         Настройка языка
#        </a>
#       </div>
#       <div class="footer-grid__item footer-grid__item_link">
#        <a class="footer__link" href="https://habr.com/ru/about/">
#         О сайте
#        </a>
#       </div>
#       <div class="footer-grid__item footer-grid__item_link">
#        <a class="footer__link" href="https://habr.com/ru/feedback/">
#         Служба поддержки
#        </a>
#       </div>
#       <div class="footer-grid__item footer-grid__item_link">
#        <a class="footer__link" href="https://m.habr.com/ru?mobile=yes">
#         Мобильная версия
#        </a>
#       </div>
#       <div class="footer-grid__item footer-grid__item_social">
#        <ul class="social-icons">
#         <li class="social-icons__item">
#          <a class="social-icons__item-link social-icons__item-link_normal social-icons__item-link_twitter" href="https://twitter.com/habr_com" onclick="if (typeof ga === 'function') { ga('send', 'event', 'footer', 'Social_icons', 'twitter'); }" target="_blank">
#           <svg aria-hidden="true" aria-labelledby="title" class="icon-svg" height="24" role="img" version="1.1" viewbox="0 0 24 24" width="24">
#            <path d="M17.414 8.642c-.398.177-.826.296-1.276.35.459-.275.811-.71.977-1.229-.43.254-.905.439-1.41.539-.405-.432-.982-.702-1.621-.702-1.227 0-2.222.994-2.222 2.222 0 .174.019.344.058.506-1.846-.093-3.484-.978-4.579-2.322-.191.328-.301.71-.301 1.117 0 .77.392 1.45.988 1.849-.363-.011-.706-.111-1.006-.278v.028c0 1.077.766 1.974 1.782 2.178-.187.051-.383.078-.586.078-.143 0-.282-.014-.418-.04.282.882 1.103 1.525 2.075 1.542-.76.596-1.718.951-2.759.951-.179 0-.356-.01-.53-.031.983.63 2.15.998 3.406.998 4.086 0 6.321-3.386 6.321-6.321l-.006-.287c.433-.314.81-.705 1.107-1.15z">
#            </path>
#           </svg>
#          </a>
#         </li>
#         <li class="social-icons__item">
#          <a class="social-icons__item-link social-icons__item-link_normal social-icons__item-link_facebook" href="https://www.facebook.com/habrahabr.ru" onclick="if (typeof ga === 'function') { ga('send', 'event', 'footer', 'Social_icons', 'facebook'); }" target="_blank">
#           <svg aria-hidden="true" aria-labelledby="title" class="icon-svg" height="24" role="img" version="1.1" viewbox="0 0 24 24" width="24">
#            <path d="M14.889 8.608h-1.65c-.195 0-.413.257-.413.6v1.192h2.063v1.698h-2.063v5.102h-1.948v-5.102h-1.766v-1.698h1.766v-1c0-1.434.995-2.6 2.361-2.6h1.65v1.808z">
#            </path>
#           </svg>
#          </a>
#         </li>
#         <li class="social-icons__item">
#          <a class="social-icons__item-link social-icons__item-link_normal social-icons__item-link_vkontakte" href="https://vk.com/habr" onclick="if (typeof ga === 'function') { ga('send', 'event', 'footer', 'Social_icons', 'vkontakte'); }" target="_blank">
#           <svg aria-hidden="true" aria-labelledby="title" class="icon-svg" height="24" role="img" version="1.1" viewbox="0 0 24 24" width="24">
#            <path d="M16.066 11.93s1.62-2.286 1.782-3.037c.054-.268-.064-.418-.343-.418h-1.406c-.322 0-.44.139-.537.343 0 0-.76 1.619-1.685 2.64-.297.33-.448.429-.612.429-.132 0-.193-.11-.193-.408v-2.607c0-.365-.043-.472-.343-.472h-2.254c-.172 0-.279.1-.279.236 0 .343.526.421.526 1.352v1.921c0 .386-.022.537-.204.537-.483 0-1.631-1.663-2.274-3.552-.129-.386-.268-.494-.633-.494h-1.406c-.204 0-.354.139-.354.343 0 .375.44 2.114 2.167 4.442 1.159 1.566 2.683 2.414 4.056 2.414.838 0 1.041-.139 1.041-.494v-1.202c0-.301.118-.429.29-.429.193 0 .534.062 1.33.848.945.901 1.01 1.276 1.525 1.276h1.578c.161 0 .311-.075.311-.343 0-.354-.462-.987-1.17-1.738-.29-.386-.762-.805-.912-.998-.215-.226-.151-.354-.001-.59z">
#            </path>
#           </svg>
#          </a>
#         </li>
#         <li class="social-icons__item">
#          <a class="social-icons__item-link social-icons__item-link_normal social-icons__item-link_telegram" href="https://telegram.me/habr_com" onclick="if (typeof ga === 'function') { ga('send', 'event', 'footer', 'Social_icons', 'telegram'); }" target="_blank">
#           <svg aria-hidden="true" aria-labelledby="title" class="icon-svg" height="24" role="img" version="1.1" viewbox="0 0 24 24" width="24">
#            <path d="M17.17 7.621l-10.498 3.699c-.169.059-.206.205-.006.286l2.257.904 1.338.536 6.531-4.796s.189.057.125.126l-4.68 5.062-.27.299.356.192 2.962 1.594c.173.093.397.016.447-.199.058-.254 1.691-7.29 1.728-7.447.047-.204-.087-.328-.291-.256zm-6.922 8.637c0 .147.082.188.197.084l1.694-1.522-1.891-.978v2.416z">
#            </path>
#           </svg>
#          </a>
#         </li>
#         <li class="social-icons__item">
#          <a class="social-icons__item-link social-icons__item-link_normal social-icons__item-link_youtube" href="https://www.youtube.com/channel/UCd_sTwKqVrweTt4oAKY5y4w" onclick="if (typeof ga === 'function') { ga('send', 'event', 'footer', 'Social_icons', 'youtube'); }" target="_blank">
#           <svg aria-hidden="true" aria-labelledby="title" class="icon-svg" height="32" role="img" version="1.1" viewbox="0 0 32 32" width="32">
#            <path d="M3.2 0h25.6c1.767 0 3.2 1.433 3.2 3.2v25.6c0 1.767-1.433 3.2-3.2 3.2h-25.6c-1.767 0-3.2-1.433-3.2-3.2v-25.6c0-1.767 1.433-3.2 3.2-3.2zm18.133 16l-10.667-5.333v10.667l10.667-5.333z">
#            </path>
#           </svg>
#          </a>
#         </li>
#         <li class="social-icons__item">
#          <a class="social-icons__item-link social-icons__item-link_normal social-icons__item-link_zen" href="https://zen.yandex.ru/habr" onclick="if (typeof ga === 'function') { ga('send', 'event', 'footer', 'Social_icons', 'zen'); }" target="_blank">
#           <svg fill="none" height="30" viewbox="0 0 30 30" width="30" xmlns="http://www.w3.org/2000/svg">
#            <rect fill="#2C3036" height="30" rx="3" width="30">
#            </rect>
#            <path clip-rule="evenodd" d="M26.25 15.1241V14.9998V14.8759C21.2684 14.7252 18.9904 14.6009 17.1735 12.8263C15.3994 11.0098 15.2747 8.73179 15.1243 3.75H15H14.8757C14.7253 8.73179 14.6006 11.0098 12.8264 12.8263C11.0095 14.6009 8.73151 14.7252 3.75 14.8759V14.9998V15.1241C8.73151 15.2748 11.0095 15.3991 12.8264 17.1733C14.6006 18.9903 14.7253 21.2682 14.8757 26.25H15H15.1243C15.2747 21.2682 15.3994 18.9903 17.1735 17.1733C18.9904 15.3991 21.2684 15.2748 26.25 15.1241Z" fill="white" fill-rule="evenodd">
#            </path>
#           </svg>
#          </a>
#         </li>
#        </ul>
#       </div>
#      </div>
#     </div>
#    </div>
#    <a class="layout__elevator hidden" href="#" id="scroll_to_top" onclick="if (typeof ga === 'function') { ga('send', 'event', 'navigation_button', 'down'); }" title="Наверх">
#     <svg aria-hidden="true" class="icon-svg icon-svg_scroll-up" height="32" role="img" version="1.1" viewbox="0 0 32 32" width="32">
#      <path d="M16 0C7.164 0 0 7.164 0 16s7.164 16 16 16 16-7.164 16-16S24.836 0 16 0zm8.412 19.523c-.517.512-1.355.512-1.872 0L16 13.516l-6.54 6.01c-.518.51-1.356.51-1.873 0-.516-.513-.517-1.343 0-1.855l7.476-7.326c.517-.512 1.356-.512 1.873 0l7.476 7.327c.516.513.516 1.342 0 1.854z">
#      </path>
#     </svg>
#    </a>
#   </div>
#   <div class="overlay hidden" id="js-lang_settings">
#    <div class="popup">
#     <div class="popup__head popup__head_lang-settings">
#      <span class="popup__head-title js-popup_title" data-section="1">
#       Настройка языка
#      </span>
#      <button class="btn btn_small btn_popup-close js-hide_lang_settings" type="button">
#       <svg class="icon-svg" height="12" width="12">
#        <use xlink:href="https://habr.com/5f324012/images/common-svg-sprite.svg#close">
#        </use>
#       </svg>
#      </button>
#     </div>
#     <div class="popup__body">
#      <form action="/json/settings/i18n/" class="form form_lang-settings" id="lang-settings-form" method="post">
#       <fieldset class="form__fieldset form__fieldset_thin" data-section="2">
#        <legend class="form__legend form__legend_lang-settings js-popup_hl_legend">
#         Интерфейс
#        </legend>
#        <div class="form-field form-field_lang-settings">
#         <span class="radio radio_custom">
#          <input checked="" class="radio__input js-hl_langs" id="hl_langs_ru" name="hl" type="radio" value="ru"/>
#          <label class="radio__label radio__label_another" for="hl_langs_ru">
#           Русский
#          </label>
#         </span>
#        </div>
#        <div class="form-field form-field_lang-settings">
#         <span class="radio radio_custom">
#          <input class="radio__input js-hl_langs" id="hl_langs_en" name="hl" type="radio" value="en"/>
#          <label class="radio__label radio__label_another" for="hl_langs_en">
#           English
#          </label>
#         </span>
#        </div>
#       </fieldset>
#       <fieldset class="form__fieldset form__fieldset_thin">
#        <legend class="form__legend form__legend_lang-settings js-popup_fl_legend" data-section="3">
#         Язык публикаций
#        </legend>
#        <div class="form-field form-field_lang-settings">
#         <span class="checkbox checkbox_custom">
#          <input checked="" class="checkbox__input js-fl_langs" id="fl_langs_ru" name="fl[]" type="checkbox" value="ru"/>
#          <label class="checkbox__label checkbox__label_another js-popup_feed_ru" for="fl_langs_ru">
#           Русский
#          </label>
#         </span>
#        </div>
#        <div class="form-field form-field_lang-settings">
#         <span class="checkbox checkbox_custom">
#          <input class="checkbox__input js-fl_langs" id="fl_langs_en" name="fl[]" type="checkbox" value="en"/>
#          <label class="checkbox__label checkbox__label_another js-popup_feed_en" for="fl_langs_en">
#           Английский
#          </label>
#         </span>
#        </div>
#       </fieldset>
#       <div class="form__footer form__footer_lang-settings">
#        <button class="btn btn_blue btn_huge btn_full-width js-popup_save_btn" type="submit">
#         Сохранить настройки
#        </button>
#       </div>
#      </form>
#     </div>
#    </div>
#   </div>
#   <script type="text/javascript">
#    // global vars
#   var g_base_url = 'habr.com/ru';
#   var g_base_fullurl = 'https://habr.com/ru/';
#   var g_tmid_fullurl = 'https://account.habr.com/';
#   var g_is_guest = false;
#   var g_show_xpanel = false;
#   var g_is_enableShortcuts = '1';
#   var g_is_ugc_post = '';
#   var g_is_company_post = '';
#     var g_current_hl = 'ru';
#     var g_current_fl = 'ru';
#   </script>
#   <script src="https://dr.habracdn.net/habr/5f324012/javascripts/vendors.bundle.js">
#   </script>
#   <script src="https://dr.habracdn.net/habr/5f324012/javascripts/main.bundle.js">
#   </script>
#   <script src="https://dr.habracdn.net/habr/5f324012/javascripts/check-login.js">
#   </script>
#   <!-- Yandex.Metrika counter -->
#   <script type="text/javascript">
#    (function(m,e,t,r,i,k,a){
#   m[i]=m[i]||function(){(m[i].a=m[i].a||[]).push(arguments)};
#   m[i].l=1*new Date();
#   k=e.createElement(t),a=e.getElementsByTagName(t)[0],k.async=1,k.src=r,a.parentNode.insertBefore(k,a)
# })(window, document, "script", "https://mc.yandex.ru/metrika/tag.js", "ym");
#
#     ym(24049213, "init", {
#       clickmap:true,
#       trackLinks:true,
#       accurateTrackBounce:true,
#       webvisor:true
#     });
#   </script>
#   <noscript>
#    <div>
#     <img alt="" src="https://mc.yandex.ru/watch/24049213" style="position:absolute; left:-9999px;">
#     </img>
#    </div>
#   </noscript>
#   <!-- /Yandex.Metrika counter -->
#   <script type="text/javascript">
#    function stripUrl(currentUrl, queryParam) {
#    return currentUrl.replace(/\?([^#]*)/, function(_, search) {
#       var result = search.split('&').map(function(param) {
#         var regexp = new RegExp(`^${queryParam}`);
#         if (regexp.test(param)) {
#           return '';
#         }
#         return param;
#       }).filter(Boolean).join('&');
#       return result ? '?' + result : '';
#     });
#   }
#
#   (function() {
#     if (location.search.indexOf('cv') != -1 && history.replaceState) {
#       var currentUrl = location.toString();
#       var strippedUrl = stripUrl(currentUrl, 'cv');
#       history.replaceState({}, '', strippedUrl);
#     }
#   })();
#
#   function callGA(usesABP) {
#     if (typeof window.adb1 === 'undefined') { window.adb1 = 'yes';}
#     if (usesABP) { window.adb1 = 'aa'; }
#
#     var user_type = 'guest';
#
#     var page_type = "other";
#
#     (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#       (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#       m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#     })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
#         ga('create', 'UA-726094-1',  'auto');
#         ga('create', 'UA-726094-24', 'auto', {'name': 'HGM', 'allowLinker': true});
#
#     ga('HGM.require', 'linker');
#     ga('HGM.linker:autoLink', ['toster.ru', 'habr.com', 'account.habr.com', 'm.habr.com']);
#
#     ga('require', 'displayfeatures');
#     ga('set', 'dimension1', user_type); // user type - guest/readonly/habrauser
#     ga('set', 'dimension2', page_type);
#     ga('set', 'dimension3', 'na');
#     ga('set', 'dimension4', window.adb1);
#     ga('set', 'dimension6', 'ru');
#     ga('set', 'dimension7', 'A');
#
#
#     (function() {
#       var removeUtms = function(){
#         var location = window.location;
#         if (location.search.indexOf('utm_') != -1 && history.replaceState) {
#           var currentUrl = location.toString();
#           var strippedUrl = stripUrl(currentUrl, 'utm_');
#           history.replaceState({}, '', strippedUrl);
#         }
#       };
#       ga('require', 'GTM-559GVC8');
#       ga('send', 'pageview', { 'hitCallback': removeUtms });
#     })();
#
#     ga('HGM.set', 'dimension1', user_type);
#     ga('HGM.set', 'dimension2', "habrahabr");
#     ga('HGM.set', 'dimension4', window.adb1);
#
#     ga('HGM.send', 'pageview');
#   }
#
#
#   if (window.habr_blockers_checker) {
#     window.habr_blockers_checker.detectWrapper(callGA);
#   } else {
#     callGA(false)
#   }
#   </script>
#   <!-- Facebook Pixel Code -->
#   <img height="1" src="https://www.facebook.com/tr?id=317458588730613&amp;ev=PageView&amp;noscript=1" style="display:none" width="1">
#    <!-- End Facebook Pixel Code -->
#    <img alt="" src="https://vk.com/rtrg?p=VK-RTRG-421343-57vKE" style="position:fixed; left:-999px;">
#    </img>
#   </img>
#  </body>
# </html>

# %%
# извлекаем посты
posts = soup.find_all('article', class_='post')
posts
# Out:
# [<article class="post post_preview" lang="ru">
#  <header class="post__meta">
#  <a class="post__user-info user-info" href="https://habr.com/ru/users/naychenko/" title="Автор публикации">
#  <img class="user-info__image-pic user-info__image-pic_small" height="24" src="//habrastorage.org/getpro/habr/avatars/be8/03b/2e2/be803b2e23969442ac082d77b5824bb8.png" width="24"/>
#  <span class="user-info__nickname user-info__nickname_small">naychenko</span>
#  </a>
#  <span class="post__time">сегодня в 11:42</span>
#  </header>
#  <h2 class="post__title">
#  <a class="post__title_link" href="https://habr.com/ru/post/514686/">Бизнес-ландшафт будущего</a>
#  </h2>
#  <ul class="post__hubs inline-list">
#  <li class="inline-list__item inline-list__item_hub">
#  <a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/business_models/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Бизнес-модели'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Бизнес-модели</a>,
#          </li>
#  <li class="inline-list__item inline-list__item_hub">
#  <a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/futurenow/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Будущее здесь'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Будущее здесь</a>
#  </li>
#  </ul>
#  <ul class="post__marks inline-list"><li class="inline-list__item inline-list__item_post-type"><a class="post__type-label" href="https://habr.com/ru/sandbox/" title="Перейти в песочницу">Из песочницы</a></li></ul>
#  <div class="post__body post__body_crop">
#  <div class="post__text post__text-html post__text_v1">
#        В этой статье я хочу поделиться видением развития бизнеса в ближайшие 20 лет, ведь мы находимся в начале трансформации бизнес-ландшафта в новое равновесное состояние.<br/>
#  <br/>
#  Пока эти изменения нечувствительны для многих, но вскоре это коснется абсолютно всех.<br/>
#  <br/>
#  Данная работа стала результатом анализа большого объема источников, с которыми мне посчастливилось познакомится в рамках работы над проектированием нескольких платформ. В конце статьи я даю ссылки на наиболее важные из этих источников. Так что, эта работа не столько мое творение, сколько обзор и анализ работ других авторов, а также моя трактовка и попытка визуализировать предстоящие трансформации в бизнесе.<br/>
#  <br/>
#  Для начала, давайте разберемся в бизнес-ландшафте настоящего. Упрощенно, текущий бизнес-ландшафт можно отобразить на следующей схеме:<br/>
#  <br/>
#  <img alt="image" src="https://avatars.mds.yandex.net/get-zen_doc/3437146/pub_5f2fb0ce05d37277463d7ce6_5f2fb100f8aa134f8017d55e/scale_600"><br/>
#  <br/>
#  <b>(Н) Компании хитов</b>, ориентированные на удовлетворение массовых потребностей клиентов.<br/>
#  <br/>
#  <b>(LT) Нишевые компании «Длинного хвоста»</b>, ориентированные на удовлетворение персональных потребностей клиентов.<br/>
#  <br/>
#  <b>(A) Инфо-агенты</b> — компании-посредники между потребителями и поставщиками, сфокусированные на интересах потребителей, снижающие их издержки на поиск продуктов и услуг. Их пока практически нет.<br/>
#  <br/>
#  <b>(P) Платформы</b> — операторы масштаба, стимулирующие развитие компаний «длинного хвоста», снижающие затраты цепочки формирования ценностей за счет экономии на масштабе и коммодитизации зрелых компонентов.<br/>
#  <br/>
#  <b>(IN) Инфраструктура</b> — компании, занятые производством коммодитизированных продуктов и услуг, обеспечивающих деятельность компаний «длинного хвоста» под курированием и поддержкой платформ.<br/>
#  </img></div>
#  <a class="btn btn_x-large btn_outline_blue post__habracut-btn" href="https://habr.com/ru/post/514686/#habracut">Читать дальше →</a>
#  </div>
#  <footer class="post__footer">
#  <ul class="post-stats js-user_" data-post-type="publish_ugc_ru,h_20752,h_22014,f_management,f_popsci" id="infopanel_post_514686">
#  <li class="post-stats__item">
#  <div class="post-stats__result">
#  <span class="post-stats__result-icon">
#  <svg class="icon-svg_votes" height="16" width="10"><use xlink:href="https://habr.com/5f324012/images/common-svg-sprite.svg#counter-rating"></use></svg>
#  </span>
#  <span class="post-stats__result-counter" title="Всего голосов 0: ↑0 и ↓0">0</span>
#  </div>
#  </li>
#  <li class="post-stats__item post-stats__item_bookmark">
#  <button class="btn bookmark-btn bookmark-btn_post" data-action="add" data-id="514686" data-post-type="publish_ugc_ru,h_20752,h_22014,f_management,f_popsci" data-type="2" disabled="" onclick="posts_add_to_favorite(this);" title="Только зарегистрированные пользователи могут добавлять публикации в закладки" type="button">
#  <span class="btn_inner"><svg class="icon-svg_bookmark" height="16" width="10"><use xlink:href="https://habr.com/5f324012/images/common-svg-sprite.svg#book"></use></svg><span class="bookmark__counter js-favs_count" title="Количество пользователей, добавивших публикацию в закладки">0</span></span>
#  </button>
#  </li>
#  <li class="post-stats__item post-stats__item_views">
#  <div class="post-stats__views" title="Количество просмотров">
#  <svg class="icon-svg_views-count" height="12" width="21"><use xlink:href="https://habr.com/5f324012/images/common-svg-sprite.svg#eye"></use></svg><span class="post-stats__views-count">35</span>
#  </div>
#  </li>
#  <li class="post-stats__item post-stats__item_comments">
#  <a class="post-stats__comments-link" href="https://habr.com/ru/post/514686/#comments" rel="nofollow">
#  <svg class="icon-svg_post-comments" height="16" width="16"><use xlink:href="https://habr.com/5f324012/images/common-svg-sprite.svg#comment"></use></svg><span class="post-stats__comments-text" title="Добавить комментарий">Комментировать</span>
#  </a>
#  </li>
#  </ul>
#  </footer>
#  </article>,
#  <article class="post post_preview" lang="ru">
#  <header class="post__meta">
#  <a class="post__user-info user-info" href="https://habr.com/ru/users/limmm/" title="Автор публикации">
#  <img class="user-info__image-pic user-info__image-pic_small" height="24" src="//habrastorage.org/getpro/habr/avatars/289/b87/784/289b87784568e9daf99dd03d3afb7a3b.jpg" width="24"/>
#  <span class="user-info__nickname user-info__nickname_small">limmm</span>
#  </a>
#  <span class="post__time">сегодня в 11:35</span>
#  </header>
#  <h2 class="post__title">
#  <a class="post__title_link" href="https://habr.com/ru/company/tinkoff/blog/514612/">Поймут ли ваши иконки пользователи из других стран? Обзор научных исследований</a>
#  </h2>
#  <ul class="post__hubs inline-list">
#  <li class="inline-list__item inline-list__item_hub">
#  <a class="inline-list__item-link hub-link" href="https://habr.com/ru/company/tinkoff/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Блог компании Tinkoff'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Блог компании Tinkoff</a>,
#          </li>
#  <li class="inline-list__item inline-list__item_hub">
#  <a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/iconoskaz/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Работа с иконками'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Работа с иконками</a>,
#          </li>
#  <li class="inline-list__item inline-list__item_hub">
#  <a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/design/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Дизайн'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Дизайн</a>
#  </li>
#  </ul>
#  <ul class="post__marks inline-list"></ul>
#  <div class="post__body post__body_crop">
#  <div class="post__text post__text-html post__text_v1">
#  <img src="https://habrastorage.org/webt/xe/2u/-v/xe2u-vmtkxpyx9d2mlrnca-amr8.png"/><br/>
#  <br/>
#  Дизайнеры часто используют иконки для того, чтобы помочь пользователю быстрее находить нужные функции. Кажется, что иконки универсальнее, чем текст. Даже на браслете путешественника изображены иконки, потому что язык люди другой культуры не поймут, а в картинках разберутся. <br/>
#  </div>
#  <a class="btn btn_x-large btn_outline_blue post__habracut-btn" href="https://habr.com/ru/company/tinkoff/blog/514612/#habracut">Читать дальше →</a>
#  </div>
#  <footer class="post__footer">
#  <ul class="post-stats js-user_" data-post-type="publish_corp_ru,c_tinkoff,h_302,h_21892,f_design" id="infopanel_post_514612">
#  <li class="post-stats__item">
#  <div class="post-stats__result">
#  <span class="post-stats__result-icon">
#  <svg class="icon-svg_votes" height="16" width="10"><use xlink:href="https://habr.com/5f324012/images/common-svg-sprite.svg#counter-rating"></use></svg>
#  </span>
#  <span class="post-stats__result-counter voting-wjt__counter_positive" title="Всего голосов 3: ↑3 и ↓0">+3</span>
#  </div>
#  </li>
#  <li class="post-stats__item post-stats__item_bookmark">
#  <button class="btn bookmark-btn bookmark-btn_post" data-action="add" data-id="514612" data-post-type="publish_corp_ru,c_tinkoff,h_302,h_21892,f_design" data-type="2" disabled="" onclick="posts_add_to_favorite(this);" title="Только зарегистрированные пользователи могут добавлять публикации в закладки" type="button">
#  <span class="btn_inner"><svg class="icon-svg_bookmark" height="16" width="10"><use xlink:href="https://habr.com/5f324012/images/common-svg-sprite.svg#book"></use></svg><span class="bookmark__counter js-favs_count" title="Количество пользователей, добавивших публикацию в закладки">1</span></span>
#  </button>
#  </li>
#  <li class="post-stats__item post-stats__item_views">
#  <div class="post-stats__views" title="Количество просмотров">
#  <svg class="icon-svg_views-count" height="12" width="21"><use xlink:href="https://habr.com/5f324012/images/common-svg-sprite.svg#eye"></use></svg><span class="post-stats__views-count">96</span>
#  </div>
#  </li>
#  <li class="post-stats__item post-stats__item_comments">
#  <a class="post-stats__comments-link" href="https://habr.com/ru/company/tinkoff/blog/514612/#comments" rel="nofollow">
#  <svg class="icon-svg_post-comments" height="16" width="16"><use xlink:href="https://habr.com/5f324012/images/common-svg-sprite.svg#comment"></use></svg><span class="post-stats__comments-text" title="Добавить комментарий">Комментировать</span>
#  </a>
#  </li>
#  </ul>
#  </footer>
#  </article>,
#  <article class="post post_preview" lang="ru">
#  <header class="post__meta">
#  <a class="post__user-info user-info" href="https://habr.com/ru/users/aio350/" title="Автор публикации">
#  <img class="user-info__image-pic user-info__image-pic_small" height="24" src="//habrastorage.org/getpro/habr/avatars/076/1e1/2c6/0761e12c6ea091cb6170c185394fae64.jpg" width="24"/>
#  <span class="user-info__nickname user-info__nickname_small">aio350</span>
#  </a>
#  <span class="post__time">сегодня в 11:34</span>
#  </header>
#  <h2 class="post__title">
#  <a class="post__title_link" href="https://habr.com/ru/post/514684/">Политика общего происхождения и CORS: визуальное руководство</a>
#  </h2>
#  <ul class="post__hubs inline-list">
#  <li class="inline-list__item inline-list__item_hub">
#  <a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/webdev/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Разработка веб-сайтов'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Разработка веб-сайтов</a>,
#          </li>
#  <li class="inline-list__item inline-list__item_hub">
#  <a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/javascript/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'JavaScript'); }" rel="nofollow" title="Вы не подписаны на этот хаб">JavaScript</a>,
#          </li>
#  <li class="inline-list__item inline-list__item_hub">
#  <a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/programming/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Программирование'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Программирование</a>
#  </li>
#  </ul>
#  <ul class="post__marks inline-list"><li class="inline-list__item inline-list__item_post-type"><span class="post__type-label" title="Перевод">Перевод</span></li></ul>
#  <div class="post__body post__body_crop">
#  <div class="post__text post__text-html post__text_v1">
#  <img src="https://habrastorage.org/webt/-1/lg/uo/-1lguoh9dzp_-uxh-8_hy3zkx_k.png"/><br/>
#  <br/>
#  Доброго времени суток, друзья! <br/>
#  <br/>
#  Представляю вашему вниманию перевод статьи <a href="https://dev.to/lydiahallie/cs-visualized-cors-5b8h" rel="nofollow">«CS Visualized: CORS»</a> автора Lydia Hallie. <br/>
#  <br/>
#  Каждому разработчику приходилось сталкиваться с ошибкой <code>Access to fetched has been blocked by CORS policy</code>. Существует несколько способов быстрого решения данной проблемы. Однако, давайте не будем спешить и подробно рассмотрим, что из себя представляет политика CORS. <br/>
#  <br/>
#  У нас часто возникает необходимость отобразить данные, находящиеся в другом месте. Прежде чем мы сможем это сделать, браузер должен отправить запрос на сервер, чтобы получить эти данные. <br/>
#  </div>
#  <a class="btn btn_x-large btn_outline_blue post__habracut-btn" href="https://habr.com/ru/post/514684/#habracut">Читать дальше →</a>
#  </div>
#  <footer class="post__footer">
#  <ul class="post-stats js-user_" data-post-type="publish_ugc_ru,h_91,h_357,h_359,f_develop" id="infopanel_post_514684">
#  <li class="post-stats__item">
#  <div class="post-stats__result">
#  <span class="post-stats__result-icon">
#  <svg class="icon-svg_votes" height="16" width="10"><use xlink:href="https://habr.com/5f324012/images/common-svg-sprite.svg#counter-rating"></use></svg>
#  </span>
#  <span class="post-stats__result-counter" title="Всего голосов 0: ↑0 и ↓0">0</span>
#  </div>
#  </li>
#  <li class="post-stats__item post-stats__item_bookmark">
#  <button class="btn bookmark-btn bookmark-btn_post" data-action="add" data-id="514684" data-post-type="publish_ugc_ru,h_91,h_357,h_359,f_develop" data-type="2" disabled="" onclick="posts_add_to_favorite(this);" title="Только зарегистрированные пользователи могут добавлять публикации в закладки" type="button">
#  <span class="btn_inner"><svg class="icon-svg_bookmark" height="16" width="10"><use xlink:href="https://habr.com/5f324012/images/common-svg-sprite.svg#book"></use></svg><span class="bookmark__counter js-favs_count" title="Количество пользователей, добавивших публикацию в закладки">1</span></span>
#  </button>
#  </li>
#  <li class="post-stats__item post-stats__item_views">
#  <div class="post-stats__views" title="Количество просмотров">
#  <svg class="icon-svg_views-count" height="12" width="21"><use xlink:href="https://habr.com/5f324012/images/common-svg-sprite.svg#eye"></use></svg><span class="post-stats__views-count">72</span>
#  </div>
#  </li>
#  <li class="post-stats__item post-stats__item_comments">
#  <a class="post-stats__comments-link" href="https://habr.com/ru/post/514684/#comments" rel="nofollow">
#  <svg class="icon-svg_post-comments" height="16" width="16"><use xlink:href="https://habr.com/5f324012/images/common-svg-sprite.svg#comment"></use></svg><span class="post-stats__comments-text" title="Добавить комментарий">Комментировать</span>
#  </a>
#  </li>
#  </ul>
#  </footer>
#  </article>,
#  <article class="post post_preview" lang="ru">
#  <header class="post__meta">
#  <a class="post__user-info user-info" href="https://habr.com/ru/users/romas1982/" title="Автор публикации">
#  <span class="default-image_mini default-image_green">
#  <svg aria-hidden="true" class="icon-svg" height="24" role="img" version="1.1" viewbox="0 0 24 24" width="24"><path d="M21.5 24h-19c-1.379 0-2.5-1.122-2.5-2.5v-19c0-1.379 1.122-2.5 2.5-2.5h19c1.379 0 2.5 1.122 2.5 2.5v19c0 1.379-1.122 2.5-2.5 2.5zm-19-23c-.827 0-1.5.673-1.5 1.5v19c0 .827.673 1.5 1.5 1.5h19c.827 0 1.5-.673 1.5-1.5v-19c0-.827-.673-1.5-1.5-1.5h-19zM15.598 12.385zM19.438 15.417l-.002-.005v-.001c-.875-2.226-2.484-3.054-3.445-3.549l-.273-.143c.029-.497-.025-1.034-.167-1.599l-.128.032.123-.044c-.765-2.152-1.757-2.585-2.632-2.967l-.006-.003-.535-2.121c.357-.065.628-.375.628-.752.001-.423-.342-.765-.765-.765s-.766.342-.766.765c0 .358.248.657.581.74l-.825 1.654-.014-.003-.024-.003c-1.053-.033-1.842.369-2.5.947-.633-.322-1.515-.729-2.158-1.814.107-.12.174-.276.174-.45 0-.375-.303-.678-.678-.678s-.678.303-.678.678.303.678.678.678l.221-.04c.416.597 1.09 1.181 1.347 2.828l-.072.091.104.081-.112-.067c-1.157 1.914-.793 4.248.207 5.37-.998 2.546-1.035 4.681-.097 5.868l.002.002.003.003c.119.162.313.233.524.233.189 0 .39-.057.559-.154.312-.179.441-.459.326-.713l-.12.054.119-.056c-.581-1.243-.474-2.713.314-4.37.4.131.778.208 1.145.234l.139.73c.264 1.418.514 2.757 1.297 4.006.132.264.453.387.777.387.122 0 .245-.018.357-.051.385-.116.591-.399.537-.738l-.129.021.125-.042c-.204-.606-.431-1.146-.649-1.67-.373-.894-.725-1.742-.891-2.737.407-.042.797-.129 1.161-.261.825.692 1.661 1.492 2.743 3.406h.001c.072.14.224.215.41.215.105 0 .222-.024.339-.073.365-.155.652-.531.477-1.006v-.001c-.432-1.849-1.426-2.778-2.428-3.547.162-.175.311-.366.442-.576.75.399 1.878 1.005 3.127 2.766l.047.067.011-.008c.151.156.317.24.48.24.096 0 .191-.027.279-.084.306-.194.439-.662.29-1.005zm-8.878-2.493c-.947 0-1.713-.767-1.713-1.713s.767-1.713 1.713-1.713c.947 0 1.713.767 1.713 1.713s-.767 1.713-1.713 1.713zm6.587 4.648l-.084.021v-.001l.084-.02zm-2.007-5.312zm.022 1.006zM11.225 11.604c0 .385-.312.697-.697.697s-.697-.312-.697-.697c0-.385.312-.697.697-.697s.697.312.697.697z"></path></svg>
#  </span>
#  <span class="user-info__nickname user-info__nickname_small">romas1982</span>
#  </a>
#  <span class="post__time">сегодня в 11:22</span>
#  </header>
#  <h2 class="post__title">
#  <a class="post__title_link" href="https://habr.com/ru/company/oleg-bunin/blog/500628/">Нам нужно поговорить…</a>
#  </h2>
#  <ul class="post__hubs inline-list">
#  <li class="inline-list__item inline-list__item_hub">
#  <a class="inline-list__item-link hub-link" href="https://habr.com/ru/company/oleg-bunin/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Блог компании Конференции Олега Бунина (Онтико)'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Блог компании Конференции Олега Бунина (Онтико)</a>,
#          </li>
#  <li class="inline-list__item inline-list__item_hub">
#  <a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/dev_management/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Управление разработкой'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Управление разработкой</a>,
#          </li>
#  <li class="inline-list__item inline-list__item_hub">
#  <a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/pm/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Управление проектами'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Управление проектами</a>,
#          </li>
#  <li class="inline-list__item inline-list__item_hub">
#  <a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/hr_management/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Управление персоналом'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Управление персоналом</a>,
#          </li>
#  <li class="inline-list__item inline-list__item_hub">
#  <a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/career/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Карьера в IT-индустрии'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Карьера в IT-индустрии</a>
#  </li>
#  </ul>
#  <ul class="post__marks inline-list"></ul>
#  <div class="post__body post__body_crop">
#  <div class="post__text post__text-html post__text_v1">
#        Иногда инженеры теряют интерес к проектам, задачам и к компании — мотивация падает, а с ней и производительность. В итоге сотрудники выгорают и/или увольняются. Для этого много причин, но самая распространенная — отсутствие внимания к успехам и проблемам инженеров.<br/>
#  <br/>
#  <img src="https://habrastorage.org/webt/ej/vk/gg/ejvkggtdfqls4lojhhzov5rqj20.png"/><br/>
#  <br/>
#  В ЦФТ эту проблему решили регулярные встречи с инженерами один на один. Встречи помогают: вовремя выявить проблемы в работе, профессионально развиваться, повышать мотивацию и находить новые смыслы. О том, как готовиться ко встречам, какие вопросы задавать и как регулярно их проводить, расскажет <b>Михаил Емельянов</b>. Теперь вы будете знать, что делать, если инженер сказал: «Нам нужно поговорить...»<br/>
#  <br/>
#  <b>Михаил Емельянов</b> — Head of Android Department в ЦФТ. В IT-разработке 12 лет, с Android — 10, из которых 2 года руководит командой Android-разработки в ЦФТ. Разрабатывал проект мультимедиа, различные проекты в финтехе и запускал стартапы.<br/>
#  </div>
#  <a class="btn btn_x-large btn_outline_blue post__habracut-btn" href="https://habr.com/ru/company/oleg-bunin/blog/500628/#habracut">Читать дальше →</a>
#  </div>
#  <footer class="post__footer">
#  <ul class="post-stats js-user_" data-post-type="publish_corp_ru,c_oleg-bunin,h_19583,h_20682,h_20736,h_20740,f_management" id="infopanel_post_500628">
#  <li class="post-stats__item">
#  <div class="post-stats__result">
#  <span class="post-stats__result-icon">
#  <svg class="icon-svg_votes" height="16" width="10"><use xlink:href="https://habr.com/5f324012/images/common-svg-sprite.svg#counter-rating"></use></svg>
#  </span>
#  <span class="post-stats__result-counter voting-wjt__counter_positive" title="Всего голосов 6: ↑6 и ↓0">+6</span>
#  </div>
#  </li>
#  <li class="post-stats__item post-stats__item_bookmark">
#  <button class="btn bookmark-btn bookmark-btn_post" data-action="add" data-id="500628" data-post-type="publish_corp_ru,c_oleg-bunin,h_19583,h_20682,h_20736,h_20740,f_management" data-type="2" disabled="" onclick="posts_add_to_favorite(this);" title="Только зарегистрированные пользователи могут добавлять публикации в закладки" type="button">
#  <span class="btn_inner"><svg class="icon-svg_bookmark" height="16" width="10"><use xlink:href="https://habr.com/5f324012/images/common-svg-sprite.svg#book"></use></svg><span class="bookmark__counter js-favs_count" title="Количество пользователей, добавивших публикацию в закладки">3</span></span>
#  </button>
#  </li>
#  <li class="post-stats__item post-stats__item_views">
#  <div class="post-stats__views" title="Количество просмотров">
#  <svg class="icon-svg_views-count" height="12" width="21"><use xlink:href="https://habr.com/5f324012/images/common-svg-sprite.svg#eye"></use></svg><span class="post-stats__views-count">304</span>
#  </div>
#  </li>
#  <li class="post-stats__item post-stats__item_comments">
#  <a class="post-stats__comments-link" href="https://habr.com/ru/company/oleg-bunin/blog/500628/#comments" rel="nofollow">
#  <svg class="icon-svg_post-comments" height="16" width="16"><use xlink:href="https://habr.com/5f324012/images/common-svg-sprite.svg#comment"></use></svg><span class="post-stats__comments-count" title="Читать комментарии">1</span>
#  </a>
#  </li>
#  </ul>
#  </footer>
#  </article>,
#  <article class="post post_preview" lang="ru">
#  <header class="post__meta">
#  <a class="post__user-info user-info" href="https://habr.com/ru/users/KatePetrukhina/" title="Автор публикации">
#  <span class="default-image_mini default-image_pink">
#  <svg aria-hidden="true" class="icon-svg" height="24" role="img" version="1.1" viewbox="0 0 24 24" width="24"><path d="M21.5 24h-19c-1.379 0-2.5-1.122-2.5-2.5v-19c0-1.379 1.122-2.5 2.5-2.5h19c1.379 0 2.5 1.122 2.5 2.5v19c0 1.379-1.122 2.5-2.5 2.5zm-19-23c-.827 0-1.5.673-1.5 1.5v19c0 .827.673 1.5 1.5 1.5h19c.827 0 1.5-.673 1.5-1.5v-19c0-.827-.673-1.5-1.5-1.5h-19zM15.598 12.385zM19.438 15.417l-.002-.005v-.001c-.875-2.226-2.484-3.054-3.445-3.549l-.273-.143c.029-.497-.025-1.034-.167-1.599l-.128.032.123-.044c-.765-2.152-1.757-2.585-2.632-2.967l-.006-.003-.535-2.121c.357-.065.628-.375.628-.752.001-.423-.342-.765-.765-.765s-.766.342-.766.765c0 .358.248.657.581.74l-.825 1.654-.014-.003-.024-.003c-1.053-.033-1.842.369-2.5.947-.633-.322-1.515-.729-2.158-1.814.107-.12.174-.276.174-.45 0-.375-.303-.678-.678-.678s-.678.303-.678.678.303.678.678.678l.221-.04c.416.597 1.09 1.181 1.347 2.828l-.072.091.104.081-.112-.067c-1.157 1.914-.793 4.248.207 5.37-.998 2.546-1.035 4.681-.097 5.868l.002.002.003.003c.119.162.313.233.524.233.189 0 .39-.057.559-.154.312-.179.441-.459.326-.713l-.12.054.119-.056c-.581-1.243-.474-2.713.314-4.37.4.131.778.208 1.145.234l.139.73c.264 1.418.514 2.757 1.297 4.006.132.264.453.387.777.387.122 0 .245-.018.357-.051.385-.116.591-.399.537-.738l-.129.021.125-.042c-.204-.606-.431-1.146-.649-1.67-.373-.894-.725-1.742-.891-2.737.407-.042.797-.129 1.161-.261.825.692 1.661 1.492 2.743 3.406h.001c.072.14.224.215.41.215.105 0 .222-.024.339-.073.365-.155.652-.531.477-1.006v-.001c-.432-1.849-1.426-2.778-2.428-3.547.162-.175.311-.366.442-.576.75.399 1.878 1.005 3.127 2.766l.047.067.011-.008c.151.156.317.24.48.24.096 0 .191-.027.279-.084.306-.194.439-.662.29-1.005zm-8.878-2.493c-.947 0-1.713-.767-1.713-1.713s.767-1.713 1.713-1.713c.947 0 1.713.767 1.713 1.713s-.767 1.713-1.713 1.713zm6.587 4.648l-.084.021v-.001l.084-.02zm-2.007-5.312zm.022 1.006zM11.225 11.604c0 .385-.312.697-.697.697s-.697-.312-.697-.697c0-.385.312-.697.697-.697s.697.312.697.697z"></path></svg>
#  </span>
#  <span class="user-info__nickname user-info__nickname_small">KatePetrukhina</span>
#  </a>
#  <span class="post__time">сегодня в 11:12</span>
#  </header>
#  <h2 class="post__title">
#  <a class="post__title_link" href="https://habr.com/ru/company/zabbix/blog/514668/">Онлайн митап Zabbix об информационной безопасности | 28 августа</a>
#  </h2>
#  <ul class="post__hubs inline-list">
#  <li class="inline-list__item inline-list__item_hub">
#  <a class="inline-list__item-link hub-link" href="https://habr.com/ru/company/zabbix/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Блог компании Zabbix'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Блог компании Zabbix</a>,
#          </li>
#  <li class="inline-list__item inline-list__item_hub">
#  <a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/open_source/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Open source'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Open source</a>,
#          </li>
#  <li class="inline-list__item inline-list__item_hub">
#  <a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/sys_admin/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Системное администрирование'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Системное администрирование</a>,
#          </li>
#  <li class="inline-list__item inline-list__item_hub">
#  <a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/it-infrastructure/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'IT-инфраструктура'); }" rel="nofollow" title="Вы не подписаны на этот хаб">IT-инфраструктура</a>,
#          </li>
#  <li class="inline-list__item inline-list__item_hub">
#  <a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/tech_events/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Конференции'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Конференции</a>
#  </li>
#  </ul>
#  <ul class="post__marks inline-list"></ul>
#  <div class="post__body post__body_crop">
#  <div class="post__text post__text-html post__text_v1">
#        28 августа мы проведем уже третий по счету онлайн митап Zabbix, на котором поговорим об информационной безопасности.<br/>
#  <br/>
#  <a href="https://www.eventbrite.com/e/zabbix-meetup-online-tickets-116075642371" rel="nofollow"><img alt="image" src="https://habrastorage.org/webt/vl/2m/p7/vl2mp7gess3yobciej3gajogmmc.png"/></a><br/>
#  </div>
#  <a class="btn btn_x-large btn_outline_blue post__habracut-btn" href="https://habr.com/ru/company/zabbix/blog/514668/#habracut">Читать дальше →</a>
#  </div>
#  <footer class="post__footer">
#  <ul class="post-stats js-user_" data-post-type="publish_corp_ru,c_zabbix,h_144,h_221,h_6398,h_20754,f_develop,f_admin,f_marketing" id="infopanel_post_514668">
#  <li class="post-stats__item">
#  <div class="post-stats__result">
#  <span class="post-stats__result-icon">
#  <svg class="icon-svg_votes" height="16" width="10"><use xlink:href="https://habr.com/5f324012/images/common-svg-sprite.svg#counter-rating"></use></svg>
#  </span>
#  <span class="post-stats__result-counter" title="Всего голосов 0: ↑0 и ↓0">0</span>
#  </div>
#  </li>
#  <li class="post-stats__item post-stats__item_bookmark">
#  <button class="btn bookmark-btn bookmark-btn_post" data-action="add" data-id="514668" data-post-type="publish_corp_ru,c_zabbix,h_144,h_221,h_6398,h_20754,f_develop,f_admin,f_marketing" data-type="2" disabled="" onclick="posts_add_to_favorite(this);" title="Только зарегистрированные пользователи могут добавлять публикации в закладки" type="button">
#  <span class="btn_inner"><svg class="icon-svg_bookmark" height="16" width="10"><use xlink:href="https://habr.com/5f324012/images/common-svg-sprite.svg#book"></use></svg><span class="bookmark__counter js-favs_count" title="Количество пользователей, добавивших публикацию в закладки">0</span></span>
#  </button>
#  </li>
#  <li class="post-stats__item post-stats__item_views">
#  <div class="post-stats__views" title="Количество просмотров">
#  <svg class="icon-svg_views-count" height="12" width="21"><use xlink:href="https://habr.com/5f324012/images/common-svg-sprite.svg#eye"></use></svg><span class="post-stats__views-count">50</span>
#  </div>
#  </li>
#  <li class="post-stats__item post-stats__item_comments">
#  <a class="post-stats__comments-link" href="https://habr.com/ru/company/zabbix/blog/514668/#comments" rel="nofollow">
#  <svg class="icon-svg_post-comments" height="16" width="16"><use xlink:href="https://habr.com/5f324012/images/common-svg-sprite.svg#comment"></use></svg><span class="post-stats__comments-text" title="Добавить комментарий">Комментировать</span>
#  </a>
#  </li>
#  </ul>
#  </footer>
#  </article>,
#  <article class="post post_preview" lang="ru">
#  <header class="post__meta">
#  <a class="post__user-info user-info" href="https://habr.com/ru/users/Skyeng-Habr/" title="Автор публикации">
#  <img class="user-info__image-pic user-info__image-pic_small" height="24" src="//habrastorage.org/getpro/habr/avatars/ae0/bac/95b/ae0bac95b9373812af7b88f4ca0b4b54.png" width="24"/>
#  <span class="user-info__nickname user-info__nickname_small">Skyeng-Habr</span>
#  </a>
#  <span class="post__time">сегодня в 11:08</span>
#  </header>
#  <h2 class="post__title">
#  <a class="post__title_link" href="https://habr.com/ru/company/skyeng/blog/514674/">Мне кажется, дело не в языке, а в том, как на нем пишут</a>
#  </h2>
#  <ul class="post__hubs inline-list">
#  <li class="inline-list__item inline-list__item_hub">
#  <a class="inline-list__item-link hub-link" href="https://habr.com/ru/company/skyeng/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Блог компании Skyeng'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Блог компании Skyeng</a>,
#          </li>
#  <li class="inline-list__item inline-list__item_hub">
#  <a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/webdev/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Разработка веб-сайтов'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Разработка веб-сайтов</a>,
#          </li>
#  <li class="inline-list__item inline-list__item_hub">
#  <a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/php/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'PHP'); }" rel="nofollow" title="Вы не подписаны на этот хаб">PHP</a>,
#          </li>
#  <li class="inline-list__item inline-list__item_hub">
#  <a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/programming/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Программирование'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Программирование</a>,
#          </li>
#  <li class="inline-list__item inline-list__item_hub">
#  <a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/go/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Go'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Go</a>
#  </li>
#  </ul>
#  <ul class="post__marks inline-list"></ul>
#  <div class="post__body post__body_crop">
#  <div class="post__text post__text-html post__text_v1">
#        «Летом между 2 и 3 курсом я пошла искать работу — а в Новосибе того времени почти все вакансии для ребят без опыта были про PHP. Начинала с очень простых вещей — WordPress, Drupal… Потом писала бэкенды на Yii и много еще разного. Go впервые попробовала в 2014-м, вдохновившись докладом, и затем часто находила работу, связанную с разработкой на нем, через сообщество.<br/>
#  <br/>
#  Считается, что Go гораздо проще поддерживать, чем PHP. Я не согласна. Видела очень много чистого, легко читаемого и поддерживаемого кода на PHP, а сейчас время от времени встречаю много плохо написанного кода на Go. Проблемы начинаются тогда, когда мы не следуем лучшим практикам языков и систем, которые разрабатываем… Или когда выбираем для своих задач не тот инструмент», — Елена Граховац, руководитель ПК GolangConf 2019 и соведущая подкаста GolangShow.<br/>
#  <br/>
#  <div class="oembed"><div><div style="left: 0; width: 100%; height: 0; position: relative; padding-bottom: 56.25%;"><iframe allow="encrypted-media; accelerometer; gyroscope; picture-in-picture" allowfullscreen="" scrolling="no" src="https://www.youtube.com/embed/0Z-EU2jxjkA?rel=0&amp;showinfo=1&amp;hl=en-US" style="border: 0; top: 0; left: 0; width: 100%; height: 100%; position: absolute;"></iframe></div></div></div><br/>
#  <i>В эту субботу днем обсудим типичные ошибки выбора в стриме с Леной, Сашей Макаровым и другими замечательными людьми. Подключайтесь.</i><br/>
#  </div>
#  <a class="btn btn_x-large btn_outline_blue post__habracut-btn" href="https://habr.com/ru/company/skyeng/blog/514674/#habracut">Читать дальше →</a>
#  </div>
#  <footer class="post__footer">
#  <ul class="post-stats js-user_" data-post-type="publish_corp_ru,c_skyeng,h_91,h_260,h_359,h_17748,f_develop" id="infopanel_post_514674">
#  <li class="post-stats__item">
#  <div class="post-stats__result">
#  <span class="post-stats__result-icon">
#  <svg class="icon-svg_votes" height="16" width="10"><use xlink:href="https://habr.com/5f324012/images/common-svg-sprite.svg#counter-rating"></use></svg>
#  </span>
#  <span class="post-stats__result-counter voting-wjt__counter_positive" title="Всего голосов 14: ↑14 и ↓0">+14</span>
#  </div>
#  </li>
#  <li class="post-stats__item post-stats__item_bookmark">
#  <button class="btn bookmark-btn bookmark-btn_post" data-action="add" data-id="514674" data-post-type="publish_corp_ru,c_skyeng,h_91,h_260,h_359,h_17748,f_develop" data-type="2" disabled="" onclick="posts_add_to_favorite(this);" title="Только зарегистрированные пользователи могут добавлять публикации в закладки" type="button">
#  <span class="btn_inner"><svg class="icon-svg_bookmark" height="16" width="10"><use xlink:href="https://habr.com/5f324012/images/common-svg-sprite.svg#book"></use></svg><span class="bookmark__counter js-favs_count" title="Количество пользователей, добавивших публикацию в закладки">3</span></span>
#  </button>
#  </li>
#  <li class="post-stats__item post-stats__item_views">
#  <div class="post-stats__views" title="Количество просмотров">
#  <svg class="icon-svg_views-count" height="12" width="21"><use xlink:href="https://habr.com/5f324012/images/common-svg-sprite.svg#eye"></use></svg><span class="post-stats__views-count">486</span>
#  </div>
#  </li>
#  <li class="post-stats__item post-stats__item_comments">
#  <a class="post-stats__comments-link" href="https://habr.com/ru/company/skyeng/blog/514674/#comments" rel="nofollow">
#  <svg class="icon-svg_post-comments" height="16" width="16"><use xlink:href="https://habr.com/5f324012/images/common-svg-sprite.svg#comment"></use></svg><span class="post-stats__comments-text" title="Добавить комментарий">Комментировать</span>
#  </a>
#  </li>
#  </ul>
#  </footer>
#  </article>,
#  <article class="post post_preview" lang="ru">
#  <header class="post__meta">
#  <a class="post__user-info user-info" href="https://habr.com/ru/users/d2funlife/" title="Автор публикации">
#  <img class="user-info__image-pic user-info__image-pic_small" height="24" src="//habrastorage.org/getpro/habr/avatars/9d4/e1b/20b/9d4e1b20b4a4c36b701ba499e859244e.png" width="24"/>
#  <span class="user-info__nickname user-info__nickname_small">d2funlife</span>
#  </a>
#  <span class="post__time">сегодня в 11:02</span>
#  </header>
#  <h2 class="post__title">
#  <a class="post__title_link" href="https://habr.com/ru/company/arcadia/blog/514652/">Эволюция конфигурации .NET</a>
#  </h2>
#  <ul class="post__hubs inline-list">
#  <li class="inline-list__item inline-list__item_hub">
#  <a class="inline-list__item-link hub-link" href="https://habr.com/ru/company/arcadia/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Блог компании Аркадия'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Блог компании Аркадия</a>,
#          </li>
#  <li class="inline-list__item inline-list__item_hub">
#  <a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/programming/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Программирование'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Программирование</a>,
#          </li>
#  <li class="inline-list__item inline-list__item_hub">
#  <a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/net/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', '.NET'); }" rel="nofollow" title="Вы не подписаны на этот хаб">.NET</a>,
#          </li>
#  <li class="inline-list__item inline-list__item_hub">
#  <a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/csharp/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'C#'); }" rel="nofollow" title="Вы не подписаны на этот хаб">C#</a>
#  </li>
#  </ul>
#  <ul class="post__marks inline-list"><li class="inline-list__item inline-list__item_post-type"><span class="post__type-label" title="Обучающий материал">Tutorial</span></li></ul>
#  <div class="post__body post__body_crop">
#  <div class="post__text post__text-html post__text_v1">
#  <img src="https://habrastorage.org/webt/ia/d_/df/iad_dfhnyallm9cemtr4bktt_i0.jpeg"/><br/>
#  <br/>
#  Каждый программист представлял — ну или может хочет представить — себя пилотом самолета, когда у тебя есть огромный проект, к нему огромная панель датчиков, метрик и переключателей, с помощью которых можно легко настроить всё как надо. Ну, по крайней мере, не бежать самому поднимать шасси вручную. И метрики, и графики — это всё хорошо, но сегодня хочу рассказать про те самые тумблерочки и кнопочки, которые могут менять параметры поведения самолета, конфигурировать его.<br/>
#  </div>
#  <a class="btn btn_x-large btn_outline_blue post__habracut-btn" href="https://habr.com/ru/company/arcadia/blog/514652/#habracut">Читать дальше →</a>
#  </div>
#  <footer class="post__footer">
#  <ul class="post-stats js-user_" data-post-type="publish_corp_ru,c_arcadia,h_359,h_546,h_17718,f_develop" id="infopanel_post_514652">
#  <li class="post-stats__item">
#  <div class="post-stats__result">
#  <span class="post-stats__result-icon">
#  <svg class="icon-svg_votes" height="16" width="10"><use xlink:href="https://habr.com/5f324012/images/common-svg-sprite.svg#counter-rating"></use></svg>
#  </span>
#  <span class="post-stats__result-counter" title="Всего голосов 0: ↑0 и ↓0">0</span>
#  </div>
#  </li>
#  <li class="post-stats__item post-stats__item_bookmark">
#  <button class="btn bookmark-btn bookmark-btn_post" data-action="add" data-id="514652" data-post-type="publish_corp_ru,c_arcadia,h_359,h_546,h_17718,f_develop" data-type="2" disabled="" onclick="posts_add_to_favorite(this);" title="Только зарегистрированные пользователи могут добавлять публикации в закладки" type="button">
#  <span class="btn_inner"><svg class="icon-svg_bookmark" height="16" width="10"><use xlink:href="https://habr.com/5f324012/images/common-svg-sprite.svg#book"></use></svg><span class="bookmark__counter js-favs_count" title="Количество пользователей, добавивших публикацию в закладки">6</span></span>
#  </button>
#  </li>
#  <li class="post-stats__item post-stats__item_views">
#  <div class="post-stats__views" title="Количество просмотров">
#  <svg class="icon-svg_views-count" height="12" width="21"><use xlink:href="https://habr.com/5f324012/images/common-svg-sprite.svg#eye"></use></svg><span class="post-stats__views-count">237</span>
#  </div>
#  </li>
#  <li class="post-stats__item post-stats__item_comments">
#  <a class="post-stats__comments-link" href="https://habr.com/ru/company/arcadia/blog/514652/#comments" rel="nofollow">
#  <svg class="icon-svg_post-comments" height="16" width="16"><use xlink:href="https://habr.com/5f324012/images/common-svg-sprite.svg#comment"></use></svg><span class="post-stats__comments-text" title="Добавить комментарий">Комментировать</span>
#  </a>
#  </li>
#  </ul>
#  </footer>
#  </article>,
#  <article class="post post_preview" lang="ru">
#  <header class="post__meta">
#  <a class="post__user-info user-info" href="https://habr.com/ru/users/skryukov/" title="Автор публикации">
#  <img class="user-info__image-pic user-info__image-pic_small" height="24" src="//habrastorage.org/getpro/habr/avatars/201/081/e55/201081e55e29ddcdb19c6646b6032d29.jpg" width="24"/>
#  <span class="user-info__nickname user-info__nickname_small">skryukov</span>
#  </a>
#  <span class="post__time">сегодня в 11:00</span>
#  </header>
#  <h2 class="post__title">
#  <a class="post__title_link" href="https://habr.com/ru/company/domclick/blog/514506/">Неофициальный гайд по Active Admin</a>
#  </h2>
#  <ul class="post__hubs inline-list">
#  <li class="inline-list__item inline-list__item_hub">
#  <a class="inline-list__item-link hub-link" href="https://habr.com/ru/company/domclick/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Блог компании ДомКлик'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Блог компании ДомКлик</a>,
#          </li>
#  <li class="inline-list__item inline-list__item_hub">
#  <a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/ruby/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Ruby'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Ruby</a>,
#          </li>
#  <li class="inline-list__item inline-list__item_hub">
#  <a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/ror/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Ruby on Rails'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Ruby on Rails</a>
#  </li>
#  </ul>
#  <ul class="post__marks inline-list"><li class="inline-list__item inline-list__item_post-type"><span class="post__type-label" title="Обучающий материал">Tutorial</span></li></ul>
#  <div class="post__body post__body_crop">
#  <div class="post__text post__text-html post__text_v1">
#  <p>Статья про <strong>Ruby</strong> в блоге компании <strong>ДомКлик</strong>! Как так получилось, что в молодую компанию завезли <a href="https://isrubydead.com" rel="nofollow">мертвый язык</a>? Секрет в том, что на Ruby можно быстро написать и протестировать бизнес-идею. И делается это не без помощи <strong>Rails</strong> и <strong>Active Admin</strong> — библиотеки, которая позволяет быстро создать админку с минимальными затратами сил и времени.</p><br/>
#  <p><img src="https://habrastorage.org/webt/ie/kc/bb/iekcbbtkbtcqloumsmwxpigmtcw.jpeg"/></p><br/>
#  <p>Часто можно встретить мнение, что Active Admin хорош только для 15-минутного блога. Мы в ДомКлик считаем (и доказываем на практике), что из этой библиотеки можно выжать намного больше.</p><br/>
#  <p>Я расскажу про некоторые подходы, которые мы применяем при работе с Active Admin.</p>
#  </div>
#  <a class="btn btn_x-large btn_outline_blue post__habracut-btn" href="https://habr.com/ru/company/domclick/blog/514506/#habracut">Читать дальше →</a>
#  </div>
#  <footer class="post__footer">
#  <ul class="post-stats js-user_" data-post-type="publish_corp_ru,c_domclick,h_224,h_8279,f_develop" id="infopanel_post_514506">
#  <li class="post-stats__item">
#  <div class="post-stats__result">
#  <span class="post-stats__result-icon">
#  <svg class="icon-svg_votes" height="16" width="10"><use xlink:href="https://habr.com/5f324012/images/common-svg-sprite.svg#counter-rating"></use></svg>
#  </span>
#  <span class="post-stats__result-counter voting-wjt__counter_positive" title="Всего голосов 12: ↑11 и ↓1">+10</span>
#  </div>
#  </li>
#  <li class="post-stats__item post-stats__item_bookmark">
#  <button class="btn bookmark-btn bookmark-btn_post" data-action="add" data-id="514506" data-post-type="publish_corp_ru,c_domclick,h_224,h_8279,f_develop" data-type="2" disabled="" onclick="posts_add_to_favorite(this);" title="Только зарегистрированные пользователи могут добавлять публикации в закладки" type="button">
#  <span class="btn_inner"><svg class="icon-svg_bookmark" height="16" width="10"><use xlink:href="https://habr.com/5f324012/images/common-svg-sprite.svg#book"></use></svg><span class="bookmark__counter js-favs_count" title="Количество пользователей, добавивших публикацию в закладки">2</span></span>
#  </button>
#  </li>
#  <li class="post-stats__item post-stats__item_views">
#  <div class="post-stats__views" title="Количество просмотров">
#  <svg class="icon-svg_views-count" height="12" width="21"><use xlink:href="https://habr.com/5f324012/images/common-svg-sprite.svg#eye"></use></svg><span class="post-stats__views-count">302</span>
#  </div>
#  </li>
#  <li class="post-stats__item post-stats__item_comments">
#  <a class="post-stats__comments-link" href="https://habr.com/ru/company/domclick/blog/514506/#comments" rel="nofollow">
#  <svg class="icon-svg_post-comments" height="16" width="16"><use xlink:href="https://habr.com/5f324012/images/common-svg-sprite.svg#comment"></use></svg><span class="post-stats__comments-text" title="Добавить комментарий">Комментировать</span>
#  </a>
#  </li>
#  </ul>
#  </footer>
#  </article>,
#  <article class="post post_preview" lang="ru">
#  <header class="post__meta">
#  <a class="post__user-info user-info" href="https://habr.com/ru/users/habrauserK/" title="Автор публикации">
#  <img class="user-info__image-pic user-info__image-pic_small" height="24" src="//habrastorage.org/getpro/habr/avatars/2a9/016/47d/2a901647d70da1e4f987a73b4e274487.jpg" width="24"/>
#  <span class="user-info__nickname user-info__nickname_small">habrauserK</span>
#  </a>
#  <span class="post__time">сегодня в 10:52</span>
#  </header>
#  <h2 class="post__title">
#  <a class="post__title_link" href="https://habr.com/ru/post/513654/">Riak Cloud Storage. Часть 2. Настройка компонента Riak CS</a>
#  </h2>
#  <ul class="post__hubs inline-list">
#  <li class="inline-list__item inline-list__item_hub">
#  <a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/nosql/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'NoSQL'); }" rel="nofollow" title="Вы не подписаны на этот хаб">NoSQL</a>,
#          </li>
#  <li class="inline-list__item inline-list__item_hub">
#  <a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/db_admins/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Администрирование баз данных'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Администрирование баз данных</a>
#  </li>
#  </ul>
#  <ul class="post__marks inline-list"><li class="inline-list__item inline-list__item_post-type"><span class="post__type-label" title="Обучающий материал">Tutorial</span></li></ul>
#  <div class="post__body post__body_crop">
#  <div class="post__text post__text-html post__text_v1">
#        В этой статье мы продолжим настройку отдельных компонентов системы Riak Cloud Storage, а именно компонента Riak CS.<br/>
#  <div style="text-align:center;"><img alt="image" src="https://habrastorage.org/webt/__/mp/j8/__mpj8mqrxvzxcvunavnmlxjnbc.png"/></div><br/>
# ...
#  </span>
#  <span class="user-info__nickname user-info__nickname_small">hanagantig</span>
#  </a>
#  <span class="post__time">сегодня в 09:40</span>
#  </header>
#  <h2 class="post__title">
#  <a class="post__title_link" href="https://habr.com/ru/company/citymobil/blog/514596/">Как и почему в InnoDB появились индексы на основе В-дерева</a>
#  </h2>
#  <ul class="post__hubs inline-list">
#  <li class="inline-list__item inline-list__item_hub">
#  <a class="inline-list__item-link hub-link" href="https://habr.com/ru/company/citymobil/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Блог компании Ситимобил'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Блог компании Ситимобил</a>,
#          </li>
#  <li class="inline-list__item inline-list__item_hub">
#  <a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/mysql/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'MySQL'); }" rel="nofollow" title="Вы не подписаны на этот хаб">MySQL</a>
#  </li>
#  </ul>
#  <ul class="post__marks inline-list"></ul>
#  <div class="post__body post__body_crop">
#  <div class="post__text post__text-html post__text_v1">
#        Всем хорошо известно, что индексы на основе структуры данных В-дерево помогают нам быстрее читать и находить записи в таблицах. В сети можно найти огромное количество информации по этому поводу, но я постараюсь показать, с какими проблемами нам пришлось бы столкнуться без использования индексов на основе В-дерева, и почему выбрали эту структуру данных. И в качестве примера я возьму подсистему хранения InnoDB из MySQL.<br/>
#  <br/>
#  Чтобы разобраться, как появились индексы на основе В-дерева, давайте представим мир без них и попробуем решить типовую задачу. Попутно обсудим проблемы, с которыми столкнемся, и способы их решения.<br/>
#  <br/>
#  <img alt="image" src="https://habrastorage.org/webt/lk/z6/fz/lkz6fzdgkxvgungcgjfs4ol30qc.png"/><br/>
#  </div>
#  <a class="btn btn_x-large btn_outline_blue post__habracut-btn" href="https://habr.com/ru/company/citymobil/blog/514596/#habracut">Читать дальше →</a>
#  </div>
#  <footer class="post__footer">
#  <ul class="post-stats js-user_" data-post-type="publish_corp_ru,c_citymobil,h_306,f_develop" id="infopanel_post_514596">
#  <li class="post-stats__item">
#  <div class="post-stats__result">
#  <span class="post-stats__result-icon">
#  <svg class="icon-svg_votes" height="16" width="10"><use xlink:href="https://habr.com/5f324012/images/common-svg-sprite.svg#counter-rating"></use></svg>
#  </span>
#  <span class="post-stats__result-counter voting-wjt__counter_positive" title="Всего голосов 5: ↑5 и ↓0">+5</span>
#  </div>
#  </li>
#  <li class="post-stats__item post-stats__item_bookmark">
#  <button class="btn bookmark-btn bookmark-btn_post" data-action="add" data-id="514596" data-post-type="publish_corp_ru,c_citymobil,h_306,f_develop" data-type="2" disabled="" onclick="posts_add_to_favorite(this);" title="Только зарегистрированные пользователи могут добавлять публикации в закладки" type="button">
#  <span class="btn_inner"><svg class="icon-svg_bookmark" height="16" width="10"><use xlink:href="https://habr.com/5f324012/images/common-svg-sprite.svg#book"></use></svg><span class="bookmark__counter js-favs_count" title="Количество пользователей, добавивших публикацию в закладки">9</span></span>
#  </button>
#  </li>
#  <li class="post-stats__item post-stats__item_views">
#  <div class="post-stats__views" title="Количество просмотров">
#  <svg class="icon-svg_views-count" height="12" width="21"><use xlink:href="https://habr.com/5f324012/images/common-svg-sprite.svg#eye"></use></svg><span class="post-stats__views-count">421</span>
#  </div>
#  </li>
#  <li class="post-stats__item post-stats__item_comments">
#  <a class="post-stats__comments-link" href="https://habr.com/ru/company/citymobil/blog/514596/#comments" rel="nofollow">
#  <svg class="icon-svg_post-comments" height="16" width="16"><use xlink:href="https://habr.com/5f324012/images/common-svg-sprite.svg#comment"></use></svg><span class="post-stats__comments-count" title="Читать комментарии">1</span>
#  </a>
#  </li>
#  </ul>
#  </footer>
#  </article>,
#  <article class="post post_preview" lang="ru">
#  <header class="post__meta">
#  <a class="post__user-info user-info" href="https://habr.com/ru/users/n_bogdanov/" title="Автор публикации">
#  <img class="user-info__image-pic user-info__image-pic_small" height="24" src="//habrastorage.org/getpro/habr/avatars/8a0/03e/411/8a003e411ffed5e0297a16e2149ae3d5.jpg" width="24"/>
#  <span class="user-info__nickname user-info__nickname_small">n_bogdanov</span>
#  </a>
#  <span class="post__time">сегодня в 09:39</span>
#  </header>
#  <h2 class="post__title">
#  <a class="post__title_link" href="https://habr.com/ru/company/flant/blog/514216/">Цена tailing'а логов в Kubernetes</a>
#  </h2>
#  <ul class="post__hubs inline-list">
#  <li class="inline-list__item inline-list__item_hub">
#  <a class="inline-list__item-link hub-link" href="https://habr.com/ru/company/flant/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Блог компании Флант'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Блог компании Флант</a>,
#          </li>
#  <li class="inline-list__item inline-list__item_hub">
#  <a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/sys_admin/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Системное администрирование'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Системное администрирование</a>,
#          </li>
#  <li class="inline-list__item inline-list__item_hub">
#  <a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/devops/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'DevOps'); }" rel="nofollow" title="Вы не подписаны на этот хаб">DevOps</a>,
#          </li>
#  <li class="inline-list__item inline-list__item_hub">
#  <a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/kubernetes/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Kubernetes'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Kubernetes</a>
#  </li>
#  </ul>
#  <ul class="post__marks inline-list"><li class="inline-list__item inline-list__item_post-type"><span class="post__type-label" title="Перевод">Перевод</span></li></ul>
#  <div class="post__body post__body_crop">
#  <div class="post__text post__text-html post__text_v1">
#  <i><b>Прим. перев.</b>: эту статью написал старший DevOps-инженер американской компании Olark, главный продукт которой — live chat — используют тысячи организаций. Автор делится размышлениями о проблеме потребляемых ресуров при сборе логов и результатами своего эксперимента с fluentd, что позволил ему добиться лучшей производительности для некоторых сценариев.</i><br/>
#  <br/>
#  <img src="https://habrastorage.org/webt/ld/zh/dd/ldzhddzzu1_m5lzt3o1xrmljz8i.jpeg"/><br/>
#  <br/>
#  Журналирование – одна из тех вещей, о которых вспоминают только тогда, когда они ломаются. И это вовсе не критика. Дело в том, что логи как таковые не приносят денег. Они позволяют получать представление о том, что делают (или делали) программы, помогая поддерживать работу того, что приносит нам деньги. На малых масштабах (или при разработке) необходимую информацию можно получить, просто выводя сообщения в <code>stdout</code>. Но стоит перейти к распределенной системе, и сразу возникает потребность агрегировать эти сообщения и направлять в некое центральное хранилище, где они принесут наибольшую пользу. Это потребность еще более актуальна, если вы имеете дело с контейнерами на платформе вроде Kubernetes, где процессы и локальное хранилище эфемерны.
#      </div>
#  <a class="btn btn_x-large btn_outline_blue post__habracut-btn" href="https://habr.com/ru/company/flant/blog/514216/#habracut">Читать дальше →</a>
#  </div>
#  <footer class="post__footer">
#  <ul class="post-stats js-user_" data-post-type="publish_corp_ru,c_flant,h_221,h_20788,h_22196,f_admin,f_develop" id="infopanel_post_514216">
#  <li class="post-stats__item">
#  <div class="post-stats__result">
#  <span class="post-stats__result-icon">
#  <svg class="icon-svg_votes" height="16" width="10"><use xlink:href="https://habr.com/5f324012/images/common-svg-sprite.svg#counter-rating"></use></svg>
#  </span>
#  <span class="post-stats__result-counter voting-wjt__counter_positive" title="Всего голосов 20: ↑20 и ↓0">+20</span>
#  </div>
#  </li>
#  <li class="post-stats__item post-stats__item_bookmark">
#  <button class="btn bookmark-btn bookmark-btn_post" data-action="add" data-id="514216" data-post-type="publish_corp_ru,c_flant,h_221,h_20788,h_22196,f_admin,f_develop" data-type="2" disabled="" onclick="posts_add_to_favorite(this);" title="Только зарегистрированные пользователи могут добавлять публикации в закладки" type="button">
#  <span class="btn_inner"><svg class="icon-svg_bookmark" height="16" width="10"><use xlink:href="https://habr.com/5f324012/images/common-svg-sprite.svg#book"></use></svg><span class="bookmark__counter js-favs_count" title="Количество пользователей, добавивших публикацию в закладки">4</span></span>
#  </button>
#  </li>
#  <li class="post-stats__item post-stats__item_views">
#  <div class="post-stats__views" title="Количество просмотров">
#  <svg class="icon-svg_views-count" height="12" width="21"><use xlink:href="https://habr.com/5f324012/images/common-svg-sprite.svg#eye"></use></svg><span class="post-stats__views-count">453</span>
#  </div>
#  </li>
#  <li class="post-stats__item post-stats__item_comments">
#  <a class="post-stats__comments-link" href="https://habr.com/ru/company/flant/blog/514216/#comments" rel="nofollow">
#  <svg class="icon-svg_post-comments" height="16" width="16"><use xlink:href="https://habr.com/5f324012/images/common-svg-sprite.svg#comment"></use></svg><span class="post-stats__comments-text" title="Добавить комментарий">Комментировать</span>
#  </a>
#  </li>
#  </ul>
#  </footer>
#  </article>,
#  <article class="post post_preview" lang="ru">
#  <header class="post__meta">
#  <a class="post__user-info user-info" href="https://habr.com/ru/users/Refridgerator/" title="Автор публикации">
#  <img class="user-info__image-pic user-info__image-pic_small" height="24" src="//habrastorage.org/getpro/habr/avatars/47b/c63/a93/47bc63a93bedea659c9bb02b4c610267.jpg" width="24"/>
#  <span class="user-info__nickname user-info__nickname_small">Refridgerator</span>
#  </a>
#  <span class="post__time">сегодня в 09:38</span>
#  </header>
#  <h2 class="post__title">
#  <a class="post__title_link" href="https://habr.com/ru/post/514170/">Оконные функции своими руками</a>
#  </h2>
#  <ul class="post__hubs inline-list">
#  <li class="inline-list__item inline-list__item_hub">
#  <a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/maths/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Математика'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Математика</a>
#  </li>
#  </ul>
#  <ul class="post__marks inline-list"><li class="inline-list__item inline-list__item_post-type"><span class="post__type-label" title="Обучающий материал">Tutorial</span></li></ul>
#  <div class="post__body post__body_crop">
#  <div class="post__text post__text-html post__text_v1">
#        В цифровой обработке сигналов оконные функции широко используются для ограничения сигнала во времени и их названия хорошо известны всем, кто так или иначе сталкивался с дискретным преобразованием Фурье: Ханна, Хэмминга, Блэкмана, Харриса и прочие. Но являются ли они достаточными, можно ли придумать что-то новое и есть ли в этом смысл?<br/>
#  <br/>
#  В этой статье мы рассмотрим вывод оконной функции с новыми свойствами, используя Wolfram Mathematica. Предполагается также, что читатель имеет общие представления о цифровой обработке сигналов в контексте обсуждаемого вопроса и как минимум знаком со <a href="https://en.wikipedia.org/wiki/Window_function" rel="nofollow">статьёй из википедии</a>.<br/>
#  <br/>
#  <img src="https://habrastorage.org/webt/q1/am/2n/q1am2nkylp0a4_5bfbme3tgzigy.png"/><br/>
#  <br/>
#  </div>
#  <a class="btn btn_x-large btn_outline_blue post__habracut-btn" href="https://habr.com/ru/post/514170/#habracut">Читать дальше →</a>
#  </div>
#  <footer class="post__footer">
#  <ul class="post-stats js-user_" data-post-type="publish_ugc_ru,h_17812,f_develop" id="infopanel_post_514170">
#  <li class="post-stats__item">
#  <div class="post-stats__result">
#  <span class="post-stats__result-icon">
#  <svg class="icon-svg_votes" height="16" width="10"><use xlink:href="https://habr.com/5f324012/images/common-svg-sprite.svg#counter-rating"></use></svg>
#  </span>
#  <span class="post-stats__result-counter voting-wjt__counter_positive" title="Всего голосов 6: ↑6 и ↓0">+6</span>
#  </div>
#  </li>
#  <li class="post-stats__item post-stats__item_bookmark">
#  <button class="btn bookmark-btn bookmark-btn_post" data-action="add" data-id="514170" data-post-type="publish_ugc_ru,h_17812,f_develop" data-type="2" disabled="" onclick="posts_add_to_favorite(this);" title="Только зарегистрированные пользователи могут добавлять публикации в закладки" type="button">
#  <span class="btn_inner"><svg class="icon-svg_bookmark" height="16" width="10"><use xlink:href="https://habr.com/5f324012/images/common-svg-sprite.svg#book"></use></svg><span class="bookmark__counter js-favs_count" title="Количество пользователей, добавивших публикацию в закладки">7</span></span>
#  </button>
#  </li>
#  <li class="post-stats__item post-stats__item_views">
#  <div class="post-stats__views" title="Количество просмотров">
#  <svg class="icon-svg_views-count" height="12" width="21"><use xlink:href="https://habr.com/5f324012/images/common-svg-sprite.svg#eye"></use></svg><span class="post-stats__views-count">399</span>
#  </div>
#  </li>
#  <li class="post-stats__item post-stats__item_comments">
#  <a class="post-stats__comments-link" href="https://habr.com/ru/post/514170/#comments" rel="nofollow">
#  <svg class="icon-svg_post-comments" height="16" width="16"><use xlink:href="https://habr.com/5f324012/images/common-svg-sprite.svg#comment"></use></svg><span class="post-stats__comments-text" title="Добавить комментарий">Комментировать</span>
#  </a>
#  </li>
#  </ul>
#  </footer>
#  </article>]

# %%
titles = posts[0].find_all('a', class_ = 'post__title_link')[0].text
titles
# Out:
# 'Бизнес-ландшафт будущего'

# %%
bodies = soup.find_all('div', class_= 'post__body post__body_crop')
body_0= bodies[0]

# %%
body_0.text
# Out:
# '\n\n      В этой статье я хочу поделиться видением развития бизнеса в ближайшие 20 лет, ведь мы находимся в начале трансформации бизнес-ландшафта в новое равновесное состояние.\n\r\nПока эти изменения нечувствительны для многих, но вскоре это коснется абсолютно всех.\n\r\nДанная работа стала результатом анализа большого объема источников, с которыми мне посчастливилось познакомится в рамках работы над проектированием нескольких платформ. В конце статьи я даю ссылки на наиболее важные из этих источников. Так что, эта работа не столько мое творение, сколько обзор и анализ работ других авторов, а также моя трактовка и попытка визуализировать предстоящие трансформации в бизнесе.\n\r\nДля начала, давайте разберемся в бизнес-ландшафте настоящего. Упрощенно, текущий бизнес-ландшафт можно отобразить на следующей схеме:\n\n\n\n(Н) Компании хитов, ориентированные на удовлетворение массовых потребностей клиентов.\n\n(LT) Нишевые компании «Длинного хвоста», ориентированные на удовлетворение персональных потребностей клиентов.\n\n(A) Инфо-агенты — компании-посредники между потребителями и поставщиками, сфокусированные на интересах потребителей, снижающие их издержки на поиск продуктов и услуг. Их пока практически нет.\n\n(P) Платформы — операторы масштаба, стимулирующие развитие компаний «длинного хвоста», снижающие затраты цепочки формирования ценностей за счет экономии на масштабе и коммодитизации зрелых компонентов.\n\n(IN) Инфраструктура — компании, занятые производством коммодитизированных продуктов и услуг, обеспечивающих деятельность компаний «длинного хвоста» под курированием и поддержкой платформ.\n\nЧитать дальше →\n'

# %%
link = posts[0].find('a', class_ = 'btn btn_x-large btn_outline_blue post__habracut-btn').attrs.get('href')
link
# Out:
# 'https://habr.com/ru/post/514686/#habracut'

# %%
string_date = posts[0].find('span', class_= 'post__time').text
string_date
# Out:
# 'сегодня в 11:42'

# %%
def get_valid_date(string_date):
    today_pattern = r'^сегодня.+'
    yesterday_pattern = r'^вчера.+'
    monthes = {
        'января':'01',
        'февраля':'02',
        'марта':'03',
        'апреля':'04',
        'мая':'05',
        'июня':'06',
        'июля':'07',
        'августа':'08',
        'сентября':'09',
        'октября':'10',
        'ноября':'11',
        'декабря':'12'
    }
    if len(re.findall(today_pattern, string_date)) > 0 :
        today = datetime.now()
        date = today.strftime('%Y-%m-%d')
        
    elif len(re.findall(yesterday_pattern, string_date)) > 0:
        today = datetime.now()
        yesterday =  today - timedelta(days = 1)
        date = yesterday.strftime('%Y-%m-%d')
        
    else:
        string_date = string_date.split(' ')
        date = '-'.join([string_date[2], monthes[string_date[1]], string_date[0]])
        
    return date

# %%
test_dates = [
    'сегодня в 9:00',
    '21 июля 2020 в 16:09',
    '21 июля 2020 в 14:53',
    'сегодня в 14:03',
    'вчера в 13:21'
]

# %%
for test_date in test_dates:
    print(test_date, 'vs', get_valid_date(test_date))
# Out:
# сегодня в 9:00 vs 2020-08-11
# 21 июля 2020 в 16:09 vs 2020-07-21
# 21 июля 2020 в 14:53 vs 2020-07-21
# сегодня в 14:03 vs 2020-08-11
# вчера в 13:21 vs 2020-08-10

# %%
def is_word_found(keywords, fragment):
    pattern = r'(^\s*)(.+)(\s*$)'
    fragment = re.sub(pattern, r'\2', fragment)
    
    fragment = fragment.lower()
    
    m = Mystem()
    lemmas = m.lemmatize(fragment)
    fragment = ' '.join(lemmas)
    
    fragment = re.sub(r'\s{2,3}', r' ', fragment)
    fragment = fragment.strip().split(' ')
    
    flag = False
    for word in fragment:
        if word in keywords:
            flag = True
            break
    
    return flag

# %%
is_word_found(KEYWORDS, body_0.text)
# Out:
# True

# %%
habr_news = pd.DataFrame()

for post in posts:
    post_id = post.parent.attrs.get('id')
   # если идентификатор не найден, это что-то странное, пропускаем
    if not post_id:
        continue
    else:
        title = post.find('a', class_ = 'post__title_link').text
        preview = post.find('div', class_= 'post__body post__body_crop').text
        print(title)
        if (is_word_found(KEYWORDS, title)) | (is_word_found(KEYWORDS, preview)):
            date = get_valid_date(post.find('span', class_= 'post__time').text)
            link = post.find('a', class_ = 'btn btn_x-large btn_outline_blue post__habracut-btn')\
            .attrs.get('href')
            row = {'date': date, 'title': title, 'link': link}
            habr_news = pd.concat([habr_news, pd.DataFrame([row])])  
habr_news
# Out:
# Бизнес-ландшафт будущего
# Поймут ли ваши иконки пользователи из других стран? Обзор научных исследований
# Политика общего происхождения и CORS: визуальное руководство
# Нам нужно поговорить…
# Онлайн митап Zabbix об информационной безопасности | 28 августа
# Мне кажется, дело не в языке, а в том, как на нем пишут
# Эволюция конфигурации .NET
# Неофициальный гайд по Active Admin
# Riak Cloud Storage. Часть 2. Настройка компонента Riak CS
# Язык запросов для TSDB. Улучшаем PromQL (Александр Валялкин, VictoriaMetrics)
# Резервное хранение данных. Где, что и как?
# Оптимизация. Цикл рассказов «Свойство слоя»
# Продуманный front-end. Правильная архитектура для быстрых сайтов
# Как прекратить страдать и начать учиться
# Продвинутые поиск на NuGet.org
# Как правильно подготовить проект печатной платы, чтобы не пришлось его переделывать
# Самый мощный сервер Supermicro в Москве на основе AMD Epyc
# Как и почему в InnoDB появились индексы на основе В-дерева
# Цена tailing'а логов в Kubernetes
# Оконные функции своими руками
#          date                               title  \
# 0  2020-08-11            Бизнес-ландшафт будущего
# 0  2020-08-11  Неофициальный гайд по Active Admin
#
#                                                 link
# 0          https://habr.com/ru/post/514686/#habracut
# 0  https://habr.com/ru/company/domclick/blog/5145...

# %%
habr_news.reset_index()
# Out:
#    index        date                                              title  \
# 0      0  2020-08-11  Онлайн-Круглый стол «Как создать свой игровой ...
# 1      0  2020-08-11  Открытые и персональные данные. Анализ кейса «...
# 2      0  2020-08-11  Как монетизировать мобильное приложение в 2020...
# 3      0  2020-08-11                           Бизнес-ландшафт будущего
# 4      0  2020-08-11  Мне кажется, дело не в языке, а в том, как на ...
#
#                                                 link  \
# 0          https://habr.com/ru/post/514720/#habracut
# 1          https://habr.com/ru/post/514564/#habracut
# 2          https://habr.com/ru/post/514710/#habracut
# 3          https://habr.com/ru/post/514686/#habracut
# 4  https://habr.com/ru/company/skyeng/blog/514674...
#
#                                                 text
# 0  \n19 августа (Среда), в 19:00, состоится беспл...
# 1  \n\n\r\nДве недели назад, на форумах обнаружил...
# 2  \nВ этой статье я хочу рассказать о том, как и...
# 3  \nВ этой статье я хочу поделиться видением раз...
# 4  \n«Летом между 2 и 3 курсом я пошла искать раб...

# %% [markdown]
# ### Дополнительная часть (необязательная)

# %% [markdown]
# Улучшить скрипт так, чтобы он анализировал не только preview-информацию статьи, но и весь текст статьи целиком.
#
# Для этого потребуется получать страницы статей и искать по тексту внутри этой страницы.
#
# Итоговый датафрейм формировать со столбцами: <дата> - <заголовок> - <ссылка> - <текст статьи>

# %%
req = requests.get('https://habr.com/ru/all/')
soup = BeautifulSoup(req.text, 'html.parser')

# %%
posts = soup.find_all('article', class_='post')

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html class="no-js" lang="ru">
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
# <meta content="width=1024" name="viewport"/>
# <title>Как прекратить страдать и начать учиться / Блог компании ГК ЛАНИТ / Хабр</title>
# <meta content="Успели во время самоизоляции стать суперэффективными и освоить пару новых специальностей? Тоже нет? А ведь все вокруг трубили: «Используй это время с пользой! Кризис – всегда точка роста»...." name="description">
# <meta content="ланит, сетевая академия, сетевая академия ланит, обучение, онлайн обучение" name="keywords"/>
# <meta content="444736788986613" property="fb:app_id"/>
# <meta content="article" property="og:type"/>
# <meta content="472597926099084" property="fb:pages"/>
# <meta content="https://habr.com/ru/company/lanit/blog/511996/" property="og:url"/>
# <meta content="Как прекратить страдать и начать учиться" property="og:title"/>
# <meta content="https://habr.com/share/publication/511996/fe0fd04ec707c9b21e42d7d7893a6467/?v=1" property="og:image"/>
# <meta content="1200" property="og:image:width"/>
# <meta content="630" property="og:image:height"/>
# <link href="https://habr.com/share/publication/511996/fe0fd04ec707c9b21e42d7d7893a6467/?v=1" rel="image_src"/>
# <meta content="https://habr.com/share/publication/511996/fe0fd04ec707c9b21e42d7d7893a6467/?v=1" name="twitter:image"/>
# <meta content="https://habr.com/share/publication/511996/fe0fd04ec707c9b21e42d7d7893a6467/?format=vk&amp;v=1" property="vk:image">
# <meta content="https://habrastorage.org/getpro/habr/post_images/62e/cf7/094/62ecf709488ecfc58e8bdce1891728c0.png" property="og:image"/>
# <link href="https://habrastorage.org/getpro/habr/post_images/62e/cf7/094/62ecf709488ecfc58e8bdce1891728c0.png" rel="image_src"/>
# <meta content="https://habrastorage.org/getpro/habr/post_images/b7b/4a5/05f/b7b4a505f4bbc1d528648bb20be4c324.png" property="og:image"/>
# <link href="https://habrastorage.org/getpro/habr/post_images/b7b/4a5/05f/b7b4a505f4bbc1d528648bb20be4c324.png" rel="image_src"/>
# <meta content="https://habrastorage.org/getpro/habr/post_images/721/a20/574/721a205742e9f756c03f93cfee566f1c.png" property="og:image"/>
# <link href="https://habrastorage.org/getpro/habr/post_images/721/a20/574/721a205742e9f756c03f93cfee566f1c.png" rel="image_src"/>
# <meta content="https://habrastorage.org/getpro/habr/post_images/296/a78/0b5/296a780b5ac1b138f0492f73864774eb.png" property="og:image"/>
# <link href="https://habrastorage.org/getpro/habr/post_images/296/a78/0b5/296a780b5ac1b138f0492f73864774eb.png" rel="image_src"/>
# <meta content="https://habrastorage.org/getpro/habr/post_images/52f/f9d/368/52ff9d3689cd8392905b4f9969c095ea.png" property="og:image"/>
# <link href="https://habrastorage.org/getpro/habr/post_images/52f/f9d/368/52ff9d3689cd8392905b4f9969c095ea.png" rel="image_src"/>
# <meta content="https://habrastorage.org/getpro/habr/post_images/69e/1e4/514/69e1e4514a8a73b83ec676ef71ef6394.png" property="og:image"/>
# <link href="https://habrastorage.org/getpro/habr/post_images/69e/1e4/514/69e1e4514a8a73b83ec676ef71ef6394.png" rel="image_src"/>
# <meta content="Успели во время самоизоляции стать суперэффективными и освоить пару новых специальностей? Тоже нет? А ведь все вокруг трубили: «Используй это время с пользой! Кр..." property="og:description"/>
# <meta content="Успели во время самоизоляции стать суперэффективными и освоить пару новых специальностей? Тоже нет? А ведь все вокруг трубили: «Используй это время с пользой! Кр..." name="twitter:description"/>
# <meta content="Как прекратить страдать и начать учиться" name="twitter:title">
# <meta content="summary_large_image" name="twitter:card"/>
# <meta content="@habr_com" name="twitter:site"/>
# <meta content="habrahabr://post/511996" property="al:android:url"/>
# <meta content="Habrahabr" property="al:android:app_name"/>
# <meta content="ru.habrahabr" property="al:android:package"/>
# <meta content="habrahabr://post/511996" property="al:windows_phone:url"/>
# <meta content="Habrahabr" property="al:windows_phone:app_name"/>
# <meta content="460a6bd6-8955-470f-935e-9ea1726a6060" property="al:windows_phone:app_id"/>
# <link href="https://habr.com/ru/company/lanit/blog/511996/" rel="canonical"/>
# <link href="https://m.habr.com/ru/company/lanit/blog/511996/" media="only screen and (max-width: 640px)" rel="alternate"/>
# <link href="https://m.habr.com/ru/amp/post/511996/" rel="amphtml"/>
# <script type="application/ld+json">
#     {
#     "@context": "http:\/\/schema.org",
#     "@type": "Article",
#     "mainEntityOfPage": {
#         "@type": "WebPage",
#         "@id": "https:\/\/habr.com\/ru\/company\/lanit\/blog\/511996\/"
#     },
#     "headline": "Как прекратить страдать и начать учиться",
#     "datePublished": "2020-08-11T10:06:18+03:00",
#     "dateModified": "2020-08-11T11:36:14+03:00",
#     "author": {
#         "@type": "Person",
#         "name": "sheltata"
#     },
#     "publisher": {
#         "@type": "Organization",
#         "name": "Habr",
#         "logo": {
#             "@type": "ImageObject",
#             "url": "https:\/\/dr.habracdn.net\/habr\/images\/habr_google.png"
#         }
#     },
#     "description": "Успели во время самоизоляции стать суперэффективными и освоить пару новых специальностей? Тоже нет? А ведь все вокруг трубили: &laquo;Используй это время с пользой! Кр...",
#     "url": "https:\/\/habr.com\/ru\/company\/lanit\/blog\/511996\/#post-content-body",
#     "about": [
#         "c_lanit",
#         "h_study",
#         "h_hr_management",
#         "h_career",
#         "h_brain",
#         "f_management",
#         "f_popsci"
#     ],
#     "image": [
#         "https:\/\/habrastorage.org\/getpro\/habr\/post_images\/62e\/cf7\/094\/62ecf709488ecfc58e8bdce1891728c0.png",
#         "https:\/\/habrastorage.org\/getpro\/habr\/post_images\/b7b\/4a5\/05f\/b7b4a505f4bbc1d528648bb20be4c324.png",
#         "https:\/\/habrastorage.org\/getpro\/habr\/post_images\/721\/a20\/574\/721a205742e9f756c03f93cfee566f1c.png",
#         "https:\/\/habrastorage.org\/getpro\/habr\/post_images\/296\/a78\/0b5\/296a780b5ac1b138f0492f73864774eb.png",
#         "https:\/\/habrastorage.org\/getpro\/habr\/post_images\/52f\/f9d\/368\/52ff9d3689cd8392905b4f9969c095ea.png",
#         "https:\/\/habrastorage.org\/getpro\/habr\/post_images\/69e\/1e4\/514\/69e1e4514a8a73b83ec676ef71ef6394.png"
#     ]
# }
#   </script>
# <meta content="71593b225aeafc4e" name="yandex-verification"/>
# <meta content="unsafe-url" name="referrer"/>
# <meta content="ed24b2b9721edf0a282c5b4a3232c4" name="pocket-site-verification"/>
# <meta content="https://dr.habracdn.net/habr/5f324012/images/" name="biu"/>
# <style type="text/css">
#   @font-face{font-family:'Fira Sans';font-style:normal;font-weight:500;src:url(https://dr.habracdn.net/habr/5f324012/fonts/FiraSans/firaSans-medium.eot);src:local("Fira Sans Medium"),local("FiraSans-Medium"),url(https://dr.habracdn.net/habr/5f324012/fonts/FiraSans/firaSans-medium.eot?#iefix) format("embedded-opentype"),url(https://dr.habracdn.net/habr/5f324012/fonts/FiraSans/firaSans-medium.woff2) format("woff2"),url(https://dr.habracdn.net/habr/5f324012/fonts/FiraSans/firaSans-medium.woff) format("woff"),url(https://dr.habracdn.net/habr/5f324012/fonts/FiraSans/firaSans-medium.ttf) format("truetype")}
# </style>
# <link href="https://dr.habracdn.net/habr/5f324012/styles/main.bundle.css" media="all" rel="stylesheet">
# <meta content="67d46b975fa41645" name="yandex-verification">
# <link href="https://dr.habracdn.net/habr/5f324012/images/apple-touch-icon.png" rel="apple-touch-icon" sizes="180x180"/>
# <link href="https://dr.habracdn.net/habr/5f324012/images/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
# <link href="https://dr.habracdn.net/habr/5f324012/images/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
# <link href="https://dr.habracdn.net/habr/5f324012/site.webmanifest" rel="manifest"/>
# <link color="#77a2b6" href="https://dr.habracdn.net/habr/5f324012/images/safari-pinned-tab.svg" rel="mask-icon"/>
# <meta content="Хабр" name="application-name"/>
# <meta content="#77a2b6" name="msapplication-TileColor"/>
# <meta content="#77a2b6" name="theme-color"/>
# <link href="https://habr.com/ru/rss/post/511996/" rel="alternate" title="Комментарии к публикации «Как прекратить страдать и начать учиться»" type="application/rss+xml">
# <script>/* Font Face Observer v2.0.13 - © Bram Stein. License: BSD-3-Clause */(function(){'use strict';var f,g=[];function l(a){g.push(a);1==g.length&&f()}function m(){for(;g.length;)g[0](),g.shift()}f=function(){setTimeout(m)};function n(a){this.a=p;this.b=void 0;this.f=[];var b=this;try{a(function(a){q(b,a)},function(a){r(b,a)})}catch(c){r(b,c)}}var p=2;function t(a){return new n(function(b,c){c(a)})}function u(a){return new n(function(b){b(a)})}function q(a,b){if(a.a==p){if(b==a)throw new TypeError;var c=!1;try{var d=b&&b.then;if(null!=b&&"object"==typeof b&&"function"==typeof d){d.call(b,function(b){c||q(a,b);c=!0},function(b){c||r(a,b);c=!0});return}}catch(e){c||r(a,e);return}a.a=0;a.b=b;v(a)}}
# function r(a,b){if(a.a==p){if(b==a)throw new TypeError;a.a=1;a.b=b;v(a)}}function v(a){l(function(){if(a.a!=p)for(;a.f.length;){var b=a.f.shift(),c=b[0],d=b[1],e=b[2],b=b[3];try{0==a.a?"function"==typeof c?e(c.call(void 0,a.b)):e(a.b):1==a.a&&("function"==typeof d?e(d.call(void 0,a.b)):b(a.b))}catch(h){b(h)}}})}n.prototype.g=function(a){return this.c(void 0,a)};n.prototype.c=function(a,b){var c=this;return new n(function(d,e){c.f.push([a,b,d,e]);v(c)})};
# function w(a){return new n(function(b,c){function d(c){return function(d){h[c]=d;e+=1;e==a.length&&b(h)}}var e=0,h=[];0==a.length&&b(h);for(var k=0;k<a.length;k+=1)u(a[k]).c(d(k),c)})}function x(a){return new n(function(b,c){for(var d=0;d<a.length;d+=1)u(a[d]).c(b,c)})};window.Promise||(window.Promise=n,window.Promise.resolve=u,window.Promise.reject=t,window.Promise.race=x,window.Promise.all=w,window.Promise.prototype.then=n.prototype.c,window.Promise.prototype["catch"]=n.prototype.g);}());
#
# (function(){function l(a,b){document.addEventListener?a.addEventListener("scroll",b,!1):a.attachEvent("scroll",b)}function m(a){document.body?a():document.addEventListener?document.addEventListener("DOMContentLoaded",function c(){document.removeEventListener("DOMContentLoaded",c);a()}):document.attachEvent("onreadystatechange",function k(){if("interactive"==document.readyState||"complete"==document.readyState)document.detachEvent("onreadystatechange",k),a()})};function r(a){this.a=document.createElement("div");this.a.setAttribute("aria-hidden","true");this.a.appendChild(document.createTextNode(a));this.b=document.createElement("span");this.c=document.createElement("span");this.h=document.createElement("span");this.f=document.createElement("span");this.g=-1;this.b.style.cssText="max-width:none;display:inline-block;position:absolute;height:100%;width:100%;overflow:scroll;font-size:16px;";this.c.style.cssText="max-width:none;display:inline-block;position:absolute;height:100%;width:100%;overflow:scroll;font-size:16px;";
# this.f.style.cssText="max-width:none;display:inline-block;position:absolute;height:100%;width:100%;overflow:scroll;font-size:16px;";this.h.style.cssText="display:inline-block;width:200%;height:200%;font-size:16px;max-width:none;";this.b.appendChild(this.h);this.c.appendChild(this.f);this.a.appendChild(this.b);this.a.appendChild(this.c)}
# function t(a,b){a.a.style.cssText="max-width:none;min-width:20px;min-height:20px;display:inline-block;overflow:hidden;position:absolute;width:auto;margin:0;padding:0;top:-999px;white-space:nowrap;font-synthesis:none;font:"+b+";"}function y(a){var b=a.a.offsetWidth,c=b+100;a.f.style.width=c+"px";a.c.scrollLeft=c;a.b.scrollLeft=a.b.scrollWidth+100;return a.g!==b?(a.g=b,!0):!1}function z(a,b){function c(){var a=k;y(a)&&a.a.parentNode&&b(a.g)}var k=a;l(a.b,c);l(a.c,c);y(a)};function A(a,b){var c=b||{};this.family=a;this.style=c.style||"normal";this.weight=c.weight||"normal";this.stretch=c.stretch||"normal"}var B=null,C=null,E=null,F=null;function G(){if(null===C)if(J()&&/Apple/.test(window.navigator.vendor)){var a=/AppleWebKit\/([0-9]+)(?:\.([0-9]+))(?:\.([0-9]+))/.exec(window.navigator.userAgent);C=!!a&&603>parseInt(a[1],10)}else C=!1;return C}function J(){null===F&&(F=!!document.fonts);return F}
# function K(){if(null===E){var a=document.createElement("div");try{a.style.font="condensed 100px sans-serif"}catch(b){}E=""!==a.style.font}return E}function L(a,b){return[a.style,a.weight,K()?a.stretch:"","100px",b].join(" ")}
# A.prototype.load=function(a,b){var c=this,k=a||"BESbswy",q=0,D=b||3E3,H=(new Date).getTime();return new Promise(function(a,b){if(J()&&!G()){var M=new Promise(function(a,b){function e(){(new Date).getTime()-H>=D?b():document.fonts.load(L(c,'"'+c.family+'"'),k).then(function(c){1<=c.length?a():setTimeout(e,25)},function(){b()})}e()}),N=new Promise(function(a,c){q=setTimeout(c,D)});Promise.race([N,M]).then(function(){clearTimeout(q);a(c)},function(){b(c)})}else m(function(){function u(){var b;if(b=-1!=
# f&&-1!=g||-1!=f&&-1!=h||-1!=g&&-1!=h)(b=f!=g&&f!=h&&g!=h)||(null===B&&(b=/AppleWebKit\/([0-9]+)(?:\.([0-9]+))/.exec(window.navigator.userAgent),B=!!b&&(536>parseInt(b[1],10)||536===parseInt(b[1],10)&&11>=parseInt(b[2],10))),b=B&&(f==v&&g==v&&h==v||f==w&&g==w&&h==w||f==x&&g==x&&h==x)),b=!b;b&&(d.parentNode&&d.parentNode.removeChild(d),clearTimeout(q),a(c))}function I(){if((new Date).getTime()-H>=D)d.parentNode&&d.parentNode.removeChild(d),b(c);else{var a=document.hidden;if(!0===a||void 0===a)f=e.a.offsetWidth,
# g=n.a.offsetWidth,h=p.a.offsetWidth,u();q=setTimeout(I,50)}}var e=new r(k),n=new r(k),p=new r(k),f=-1,g=-1,h=-1,v=-1,w=-1,x=-1,d=document.createElement("div");d.dir="ltr";t(e,L(c,"sans-serif"));t(n,L(c,"serif"));t(p,L(c,"monospace"));d.appendChild(e.a);d.appendChild(n.a);d.appendChild(p.a);document.body.appendChild(d);v=e.a.offsetWidth;w=n.a.offsetWidth;x=p.a.offsetWidth;I();z(e,function(a){f=a;u()});t(e,L(c,'"'+c.family+'",sans-serif'));z(n,function(a){g=a;u()});t(n,L(c,'"'+c.family+'",serif'));
# z(p,function(a){h=a;u()});t(p,L(c,'"'+c.family+'",monospace'))})})};"object"===typeof module?module.exports=A:(window.FontFaceObserver=A,window.FontFaceObserver.prototype.load=A.prototype.load);}());
#
# (function( w ){
# if( w.document.documentElement.className.indexOf( "fonts-loaded" ) > -1 ){ return; }
#
# var html = document.documentElement;
# var FS500 = new w.FontFaceObserver("Fira Sans", { weight: 500 });
#
# FS500.load().then(function() {
# html.classList.add('fonts-loaded');
# sessionStorage.fontsLoaded = true;
# console.log('FS500-loaded');
# }).catch(function () {
# sessionStorage.fontsLoaded = false;
# console.log('FS500-unloaded');
# });
#
# if (sessionStorage.fontsLoaded) {
# html.classList.add('fonts-loaded');
# }
# }(this));
# </script>
# <script src="https://dr.habracdn.net/habr/5f324012/javascripts/libs/jquery-1.8.3.min.js"></script>
# <script src="https://dr.habracdn.net/habr/5f324012/javascripts/libs/chance.min.js"></script>
# <script src="https://dr.habracdn.net/habr/5f324012/javascripts/libs/html2canvas.min.js"></script>
# <script src="https://unpkg.com/pure-md5@latest/lib/index.js"></script>
# <script async="" src="https://cdn.onthe.io/io.js/Tn4LrERWU1qX"></script>
# <script>
#     window._io_config = window._io_config || {};
#     window._io_config["0.2.0"] = window._io_config["0.2.0"] || [];
#     window._io_config["0.2.0"].push({
#     "page_url": "https:\/\/habr.com\/ru\/company\/lanit\/blog\/511996\/",
#     "page_url_canonical": "https:\/\/habr.com\/ru\/company\/lanit\/blog\/511996\/",
#     "page_title": "Как прекратить страдать и начать учиться",
#     "page_type": "article",
#     "page_language": "ru",
#     "article_authors": [
#         "sheltata"
#     ],
#     "article_categories": [
#         "c_lanit",
#         "h_study",
#         "h_hr_management",
#         "h_career",
#         "h_brain",
#         "f_management",
#         "f_popsci"
#     ],
#     "article_type": "simple",
#     "article_publication_date": "Tue, 11 Aug 20 10:06:18 +0300"
# });
#   </script>
# <script>
#   window.create_callback_for_blocked = function(key) {
#     return function() {
#       googletag.cmd.push(function () {
#         googletag.display(key);
#       });
#     }
#   }
#
#   window.habr_blockers_checker = new function() {
#     var result;
#     var callbacksQueue = [];
#     var calledOnce = false;
#
#     function fireCallbacks() {
#       callbacksQueue.forEach(function(callback) {
#         callback(result);
#       });
#       callbacksQueue = [];
#     }
#
#     this.detect = function(imgUrl, callback) {
#       var checksRemain = 2;
#       var detected = false;
#       var error1 = false;
#       var error2 = false;
#
#       if (typeof callback !== 'function') {
#         return;
#       };
#
#       callbacksQueue.push(callback);
#
#       if (typeof result !== 'undefined') {
#         fireCallbacks();
#       };
#
#       if (calledOnce) {
#         return;
#       }
#       calledOnce = true;
#
#       imgUrl += '?ch=*&rn=*';
#
#       function beforeCheck(timeout) {
#         if (checksRemain === 0 || timeout > 1E3) {
#           result = checksRemain === 0 && detected;
#           fireCallbacks();
#         } else {
#           setTimeout(function() {
#             beforeCheck(timeout * 2)
#           }, timeout * 2);
#         }
#       }
#
#       function checkImages() {
#         if (--checksRemain) {
#           return;
#         };
#         detected = !error1 && error2;
#       }
#
#       var random = Math.random() * 11;
#
#       var img1 = new Image;
#       img1.onload = checkImages;
#       img1.onerror = function() {
#         error1 = true;
#         checkImages()
#       };
#       img1.src = imgUrl.replace(/\*/, 1).replace(/\*/, random);
#
#       var img2 = new Image;
#       img2.onload = checkImages;
#       img2.onerror = function() {
#         error2 = true;
#         checkImages()
#       };
#       img2.src = imgUrl.replace(/\*/, 2).replace(/\*/, random);
#
#       beforeCheck(250, callback)
#     };
#
#     this.detectWrapper = function(callback) {
#       return this.detect('/images/px.gif', callback);
#     };
#   };
#
#   window.display_dfp_slot = function(key) {
#     if (window.habr_blockers_checker) {
#       window.habr_blockers_checker.detectWrapper(window.create_callback_for_blocked(key));
#     } else {
#       window.create_callback_for_blocked(key)();
#     }
#   };
# </script>
# <script src="https://dr.habracdn.net/habr/5f324012/javascripts/libs/raven.min.js"></script>
# <script>Raven.config('https://830576edd4b7478086093f693a5a0df5@s.tmtm.ru/37', {
#   maxBreadcrumbs: 50,
#   sampleRate: 0.5,
#   whitelistUrls: [/https?:\/\/((www)\.)?(m\.)?habr\.com/],
# }).install()</script>
# <script src="https://dr.habracdn.net/habr/5f324012/javascripts/_parts/advertise.js"></script>
# <script src="https://dr.habracdn.net/habr/5f324012/javascripts/_parts/adriver.js"></script>
# <script type="text/javascript">
#   $(document).ready(function () {
#     if (!$.cookie('split201901')) {
#       $.cookie(
#         'split201901',
#         'A',
#         {
#           expires: 3 * 7,
#           domain: 'habr.com',
#           path: '/',
#           secure: true
#         }
#       );
#     }
#   });
# </script>
# </link></meta></link></meta></meta></meta></head>
# <body class="nl">
# <div class="layout">
# <div class="layout__row layout__row_services">
# <div id="TMpanel">
# <div class="container">
# <div class="logo-wrapper">
# <a class="logo" href="https://habr.com/ru/" title="">
# <svg height="24" viewbox="0 0 62 24" width="62" xmlns="http://www.w3.org/2000/svg">
# <path d="M16.875 19L11.075 10.225L16.825 1.4H12.6L8.75 7.4L4.94999 1.4H0.574994L6.32499 10.15L0.524994 19H4.79999L8.64999 12.975L12.525 19H16.875Z"></path>
# <path d="M24.2607 5.775C20.8857 5.775 18.9607 7.625 18.6107 9.85H22.0107C22.2107 9.175 22.8607 8.6 24.1107 8.6C25.3357 8.6 26.2357 9.225 26.2357 10.425V11.025H23.4107C20.1107 11.025 18.1107 12.55 18.1107 15.2C18.1107 17.8 20.1107 19.3 22.6107 19.3C24.2857 19.3 25.6357 18.65 26.4357 17.6V19H29.8107V10.55C29.8107 7.4 27.5857 5.775 24.2607 5.775ZM23.6107 16.475C22.4857 16.475 21.7607 15.925 21.7607 15.025C21.7607 14.1 22.5607 13.55 23.6857 13.55H26.2357V14.125C26.2357 15.625 25.0107 16.475 23.6107 16.475Z"></path>
# <path d="M39.925 6.3C38.125 6.3 36.65 6.95 35.7 8.275C35.95 5.85 36.925 4.65 39.375 4.275L44.3 3.55V0.375L39.025 1.25C33.925 2.1 32.35 5.5 32.35 11.175C32.35 16.275 34.825 19.3 39.2 19.3C43.125 19.3 45.55 16.3 45.55 12.7C45.55 8.825 43.3 6.3 39.925 6.3ZM39.025 16.25C37.125 16.25 36.075 14.725 36.075 12.675C36.075 10.7 37.175 9.275 39.05 9.275C40.875 9.275 41.9 10.75 41.9 12.7C41.9 14.65 40.9 16.25 39.025 16.25Z"></path>
# <path d="M55.2855 5.775C53.3855 5.775 52.1605 6.6 51.5105 7.575V6.075H48.0105V23.775H51.6605V17.75C52.3105 18.65 53.5355 19.3 55.1855 19.3C58.3605 19.3 60.8855 16.8 60.8855 12.55C60.8855 8.225 58.3605 5.775 55.2855 5.775ZM54.4105 16.15C52.7105 16.15 51.5855 14.775 51.5855 12.6V12.5C51.5855 10.325 52.7105 8.925 54.4105 8.925C56.1105 8.925 57.2105 10.35 57.2105 12.55C57.2105 14.75 56.1105 16.15 54.4105 16.15Z"></path>
# </svg>
# </a>
# <span class="projects-dropdown" id="dropdown-control">
# <svg fill="none" height="6" viewbox="0 0 10 6" width="10" xmlns="http://www.w3.org/2000/svg">
# <path clip-rule="evenodd" d="M5.70711 5.70711C5.31658 6.09763 4.68342 6.09763 4.29289 5.70711L0.292892 1.70711C-0.097632 1.31658 -0.0976319 0.683417 0.292892 0.292893C0.683417 -0.0976308 1.31658 -0.0976308 1.70711 0.292893L5 3.58579L8.29289 0.292894C8.68342 -0.0976301 9.31658 -0.0976301 9.70711 0.292894C10.0976 0.683418 10.0976 1.31658 9.70711 1.70711L5.70711 5.70711Z" fill-rule="evenodd"></path>
# </svg>
# </span>
# <div class="dropdown hidden" id="dropdown">
# <div class="dropdown-heading">
#             Все сервисы Хабра
#           </div>
# <a class="service" href="/">
# <div class="service-title">
# <svg fill="none" height="22" viewbox="0 0 52 22" width="52" xmlns="http://www.w3.org/2000/svg">
# <path d="M13.86 17.0001L8.514 9.23405L13.816 1.51205H11.528L7.26 7.76005L2.97 1.51205H0.659997L5.984 9.19005L0.615997 17.0001H2.926L7.194 10.6861L11.528 17.0001H13.86Z" fill="#333333"></path>
# <path d="M20.181 5.67005C17.651 5.67005 16.111 7.10005 15.759 8.81605H17.585C17.893 8.00205 18.685 7.34205 20.137 7.34205C21.567 7.34205 22.645 8.11205 22.645 9.65205V10.4001H19.697C16.991 10.4001 15.341 11.6981 15.341 13.8321C15.341 15.9441 17.013 17.2421 19.169 17.2421C20.577 17.2421 21.897 16.7141 22.733 15.6801V17.0001H24.515V9.65205C24.515 7.16605 22.777 5.67005 20.181 5.67005ZM19.411 15.5921C18.179 15.5921 17.255 14.9761 17.255 13.8101C17.255 12.6221 18.289 12.0061 19.807 12.0061H22.645V12.8201C22.645 14.5141 21.171 15.5921 19.411 15.5921Z" fill="#333333"></path>
# <path d="M32.9685 5.91205C31.2965 5.91205 29.9545 6.55005 29.1185 7.78205C29.3825 5.27405 30.3945 3.88805 32.9025 3.42605L36.9505 2.67805V0.852051L32.5065 1.75405C28.7665 2.52405 27.2045 4.96605 27.2045 10.5101C27.2045 14.8001 29.4045 17.2421 32.7925 17.2421C36.0265 17.2421 38.0505 14.7121 38.0505 11.5441C38.0505 7.91405 35.8285 5.91205 32.9685 5.91205ZM32.7045 15.5261C30.6145 15.5261 29.2065 13.9641 29.2065 11.4561C29.2065 8.97005 30.7685 7.60605 32.7265 7.60605C34.7725 7.60605 36.1145 9.23405 36.1145 11.5441C36.1145 13.8541 34.7945 15.5261 32.7045 15.5261Z" fill="#333333"></path>
# <path d="M46.1431 5.67005C44.2291 5.67005 43.0631 6.55005 42.5131 7.49605V5.91205H40.6871V21.2021H42.5791V15.6361C43.1071 16.4501 44.2951 17.2421 46.0771 17.2421C48.6291 17.2421 51.1371 15.3721 51.1371 11.4561C51.1371 7.56205 48.6511 5.67005 46.1431 5.67005ZM45.9011 15.5261C43.8551 15.5261 42.5131 13.9641 42.5131 11.5001V11.4121C42.5131 8.94805 43.8551 7.38605 45.9011 7.38605C47.8811 7.38605 49.2011 9.03605 49.2011 11.4561C49.2011 13.8761 47.8811 15.5261 45.9011 15.5261Z" fill="#333333"></path>
# </svg>
# </div>
# <p class="service-description">
#               Сообщество IT-специалистов
#             </p>
# </a>
# <a class="service" href="https://qna.habr.com?utm_source=habr&amp;utm_medium=habr_top_panel">
# <h4 class="service-title">
# <svg fill="none" height="18" viewbox="0 0 46 18" width="46" xmlns="http://www.w3.org/2000/svg">
# <path d="M14.4 8.25602C14.4 3.65802 11.606 0.27002 7.27201 0.27002C2.93801 0.27002 0.144012 3.65802 0.144012 8.25602C0.144012 12.854 2.93801 16.242 7.27201 16.242C8.41601 16.242 9.45001 16.022 10.352 15.604L11.518 17.342H13.696L11.848 14.614C13.476 13.184 14.4 10.918 14.4 8.25602ZM7.27201 14.416C4.10401 14.416 2.14601 11.864 2.14601 8.25602C2.14601 4.64802 4.10401 2.09602 7.27201 2.09602C10.44 2.09602 12.398 4.64802 12.398 8.25602C12.398 10.236 11.826 11.908 10.77 12.986L9.64801 11.314H7.47001L9.29601 14.02C8.70201 14.284 8.02001 14.416 7.27201 14.416Z" fill="#333333"></path>
# <path d="M30.965 16L27.973 12.766L30.921 9.11402H28.699L26.829 11.534L23.331 7.77202C25.377 6.80402 26.455 5.59402 26.455 3.85602C26.455 1.78802 24.871 0.27002 22.583 0.27002C20.207 0.27002 18.535 1.89802 18.535 3.87802C18.535 5.19802 19.305 6.12202 20.163 7.00202L20.427 7.26602C17.985 8.25602 16.753 9.73002 16.753 11.732C16.753 14.196 18.667 16.242 21.835 16.242C23.749 16.242 25.311 15.494 26.565 14.24L26.763 14.042L28.567 16H30.965ZM22.539 1.92002C23.705 1.92002 24.629 2.62402 24.629 3.83402C24.629 5.00002 23.793 5.90202 22.187 6.62802L21.571 6.01202C21.109 5.55002 20.405 4.82402 20.405 3.81202C20.405 2.66802 21.329 1.92002 22.539 1.92002ZM21.945 14.504C19.877 14.504 18.755 13.316 18.755 11.666C18.755 10.258 19.591 9.20202 21.593 8.43202L25.641 12.832L25.509 12.964C24.541 13.976 23.309 14.504 21.945 14.504Z" fill="#333333"></path>
# <path d="M43.5619 16H45.6739L39.8219 0.512019H37.7979L31.9459 16H34.0579L35.5539 11.908H42.0439L43.5619 16ZM38.7879 2.97602L41.3839 10.104H36.2139L38.7879 2.97602Z" fill="#333333"></path>
# </svg>
# </h4>
# <p class="service-description">
#               Ответы на любые вопросы об IT
#             </p>
# </a>
# <a class="service" href="https://career.habr.com?utm_source=habr&amp;utm_medium=habr_top_panel">
# <div class="service-title">
# <svg fill="none" height="21" viewbox="0 0 84 21" width="84" xmlns="http://www.w3.org/2000/svg">
# <path d="M12.442 16L4.96201 7.92596L12.31 0.511963H9.78001L2.894 7.41996V0.511963H0.936005V16H2.894V8.60796L9.84601 16H12.442Z" fill="#333333"></path>
# <path d="M18.3646 4.66996C15.8346 4.66996 14.2946 6.09996 13.9426 7.81596H15.7686C16.0766 7.00196 16.8686 6.34196 18.3206 6.34196C19.7506 6.34196 20.8286 7.11196 20.8286 8.65196V9.39996H17.8806C15.1746 9.39996 13.5246 10.698 13.5246 12.832C13.5246 14.944 15.1966 16.242 17.3526 16.242C18.7606 16.242 20.0806 15.714 20.9166 14.68V16H22.6986V8.65196C22.6986 6.16596 20.9606 4.66996 18.3646 4.66996ZM17.5946 14.592C16.3626 14.592 15.4386 13.976 15.4386 12.81C15.4386 11.622 16.4726 11.006 17.9906 11.006H20.8286V11.82C20.8286 13.514 19.3546 14.592 17.5946 14.592Z" fill="#333333"></path>
# <path d="M31.3501 4.66996C29.4361 4.66996 28.2701 5.54996 27.7201 6.49596V4.91196H25.8941V20.202H27.7861V14.636C28.3141 15.45 29.5021 16.242 31.2841 16.242C33.8361 16.242 36.3441 14.372 36.3441 10.456C36.3441 6.56196 33.8581 4.66996 31.3501 4.66996ZM31.1081 14.526C29.0621 14.526 27.7201 12.964 27.7201 10.5V10.412C27.7201 7.94796 29.0621 6.38596 31.1081 6.38596C33.0881 6.38596 34.4081 8.03596 34.4081 10.456C34.4081 12.876 33.0881 14.526 31.1081 14.526Z" fill="#333333"></path>
# <path d="M43.3561 8.49796H40.8701V4.91196H38.9781V16H43.3341C45.7101 16 47.2501 14.372 47.2501 12.216C47.2501 10.06 45.7101 8.49796 43.3561 8.49796ZM43.1141 14.328H40.8701V10.17H43.1141C44.5661 10.17 45.3581 11.028 45.3581 12.216C45.3581 13.404 44.5661 14.328 43.1141 14.328Z" fill="#333333"></path>
# <path d="M59.1788 11.028V10.06C59.1788 6.75996 57.2868 4.66996 54.3388 4.66996C51.3028 4.66996 49.1248 6.86996 49.1248 10.456C49.1248 14.02 51.2808 16.242 54.4928 16.242C57.3748 16.242 58.7608 14.438 59.0468 13.14H57.1328C56.9348 13.712 56.0548 14.548 54.5148 14.548C52.4688 14.548 51.1048 13.052 51.1048 11.072V11.028H59.1788ZM54.2948 6.36396C56.0768 6.36396 57.1768 7.50796 57.2648 9.42196H51.1268C51.2808 7.59596 52.4468 6.36396 54.2948 6.36396Z" fill="#333333"></path>
# <path d="M67.272 4.66996C65.358 4.66996 64.192 5.54996 63.642 6.49596V4.91196H61.816V20.202H63.708V14.636C64.236 15.45 65.424 16.242 67.206 16.242C69.758 16.242 72.266 14.372 72.266 10.456C72.266 6.56196 69.78 4.66996 67.272 4.66996ZM67.03 14.526C64.984 14.526 63.642 12.964 63.642 10.5V10.412C63.642 7.94796 64.984 6.38596 67.03 6.38596C69.01 6.38596 70.33 8.03596 70.33 10.456C70.33 12.876 69.01 14.526 67.03 14.526Z" fill="#333333"></path>
# <path d="M79.058 4.66996C76.528 4.66996 74.988 6.09996 74.636 7.81596H76.462C76.77 7.00196 77.562 6.34196 79.014 6.34196C80.444 6.34196 81.522 7.11196 81.522 8.65196V9.39996H78.574C75.868 9.39996 74.218 10.698 74.218 12.832C74.218 14.944 75.89 16.242 78.046 16.242C79.454 16.242 80.774 15.714 81.61 14.68V16H83.392V8.65196C83.392 6.16596 81.654 4.66996 79.058 4.66996ZM78.288 14.592C77.056 14.592 76.132 13.976 76.132 12.81C76.132 11.622 77.166 11.006 78.684 11.006H81.522V11.82C81.522 13.514 80.048 14.592 78.288 14.592Z" fill="#333333"></path>
# </svg>
# </div>
# <p class="service-description">
#               Профессиональное развитие в IT
#             </p>
# </a>
# <a class="service" href="https://freelance.habr.com?utm_source=habr&amp;utm_medium=habr_top_panel">
# <div class="service-title">
# <svg fill="none" height="21" viewbox="0 0 91 21" width="91" xmlns="http://www.w3.org/2000/svg">
# <path d="M9.032 1.65602V0.0720215H7.118V1.65602C3.268 1.72202 0.0339966 4.01002 0.0339966 8.16802C0.0339966 12.304 3.268 14.592 7.118 14.658V16.242H9.032V14.658C12.882 14.592 16.116 12.304 16.116 8.16802C16.116 4.01002 12.882 1.72202 9.032 1.65602ZM7.118 12.898C4.082 12.832 2.014 11.05 2.014 8.16802C2.014 5.26402 4.082 3.48202 7.118 3.41602V12.898ZM9.032 12.898V3.41602C12.068 3.48202 14.136 5.26402 14.136 8.16802C14.136 11.05 12.068 12.832 9.032 12.898Z" fill="#333333"></path>
# <path d="M24.2603 4.67002C22.3463 4.67002 21.1803 5.55002 20.6303 6.49602V4.91202H18.8043V20.202H20.6963V14.636C21.2243 15.45 22.4123 16.242 24.1943 16.242C26.7463 16.242 29.2543 14.372 29.2543 10.456C29.2543 6.56202 26.7683 4.67002 24.2603 4.67002ZM24.0183 14.526C21.9723 14.526 20.6303 12.964 20.6303 10.5V10.412C20.6303 7.94802 21.9723 6.38602 24.0183 6.38602C25.9983 6.38602 27.3183 8.03602 27.3183 10.456C27.3183 12.876 25.9983 14.526 24.0183 14.526Z" fill="#333333"></path>
# <path d="M39.4123 4.91202L33.7583 13.074V4.91202H31.8883V16H33.7583L39.4123 7.83802V16H41.2823V4.91202H39.4123Z" fill="#333333"></path>
# <path d="M46.0815 4.91202L45.5095 11.71C45.3555 13.624 44.9595 14.328 43.5735 14.328H43.2655V16.044H43.7935C46.0595 16.044 47.0935 14.856 47.3355 11.842L47.7755 6.60602H51.8455V16H53.7375V4.91202H46.0815Z" fill="#333333"></path>
# <path d="M61.2045 4.67002C58.6745 4.67002 57.1345 6.10002 56.7825 7.81602H58.6085C58.9165 7.00202 59.7085 6.34202 61.1605 6.34202C62.5905 6.34202 63.6685 7.11202 63.6685 8.65202V9.40002H60.7205C58.0145 9.40002 56.3645 10.698 56.3645 12.832C56.3645 14.944 58.0365 16.242 60.1925 16.242C61.6005 16.242 62.9205 15.714 63.7565 14.68V16H65.5385V8.65202C65.5385 6.16602 63.8005 4.67002 61.2045 4.67002ZM60.4345 14.592C59.2025 14.592 58.2785 13.976 58.2785 12.81C58.2785 11.622 59.3125 11.006 60.8305 11.006H63.6685V11.82C63.6685 13.514 62.1945 14.592 60.4345 14.592Z" fill="#333333"></path>
# <path d="M76.104 4.91202V9.37802H70.626V4.91202H68.734V16H70.626V11.094H76.104V16H77.996V4.91202H76.104Z" fill="#333333"></path>
# <path d="M85.9003 14.526C83.8983 14.526 82.5783 12.876 82.5783 10.456C82.5783 8.05802 83.8543 6.38602 85.8783 6.38602C87.6383 6.38602 88.4523 7.53002 88.7383 8.45402H90.6303C90.3443 6.69402 88.8263 4.67002 85.8783 4.67002C82.6883 4.67002 80.6423 7.13402 80.6423 10.456C80.6423 13.844 82.7323 16.242 85.8783 16.242C88.6283 16.242 90.3883 14.394 90.6303 12.414H88.7383C88.4963 13.36 87.7483 14.526 85.9003 14.526Z" fill="#333333"></path>
# </svg>
# </div>
# <p class="service-description">
#               Удаленная работа для IT-специалистов
#             </p>
# </a>
# </div>
# </div>
# <div class="bmenu">
# <a class="bmenu__conversion" href="https://habr.com/sandbox/start/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'habr_top_panel', 'become_an_author'); }">Как стать автором</a>
# </div>
# <div class="bmenu_inner" style="display:flex!important;visibility:visible!important;">
# <span class="bmenu slink">
# <a href="https://u.tmtm.ru/allsoft-pirate-top" onclick="if (typeof ga === 'function') { ga('send', 'event', 'habr_top_panel', 'megapost', 'https://u.tmtm.ru/allsoft-pirate-top'); }" rel="noopener" style="color: #FFAFAF" target="_blank">Почему люди отказываются от пиратства в сети</a>
# </span>
# </div>
# </div>
# </div>
# <script>
#   var dropdown = document.querySelector('#dropdown');
#   var dropdownControl = document.querySelector('#dropdown-control');
#   var logoWrapper = document.querySelector('.logo-wrapper');
#
#   document.addEventListener('click', function(e) {
#       if (dropdown) {
#         var isClickInside = logoWrapper.contains(e.target);
#         var dropdownClosed = dropdown.classList.contains('hidden');
#         if (!isClickInside && !dropdownClosed) {
#           dropdown.classList.add('hidden');
#           dropdownControl.classList.remove('reverted');
#         }
#       }
#   });
#   if (dropdownControl) {
#     dropdownControl.onclick = function () {
#       dropdown.classList.toggle('hidden');
#       dropdownControl.classList.toggle('reverted');
#     }
#   }
# </script>
# </div>
# <div class="layout__row layout__row_navbar">
# <div class="layout__cell">
# <div class="main-navbar">
# <div class="main-navbar__section main-navbar__section_left">
# <ul class="nav-links" id="navbar-links">
# <li class="nav-links__item">
# <a class="nav-links__item-link" href="https://habr.com/ru/top/">Все потоки</a>
# </li>
# <li class="nav-links__item">
# <a class="nav-links__item-link" href="https://habr.com/ru/flows/develop/">Разработка</a>
# </li>
# <li class="nav-links__item">
# <a class="nav-links__item-link" href="https://habr.com/ru/flows/admin/">Администрирование</a>
# </li>
# <li class="nav-links__item">
# <a class="nav-links__item-link" href="https://habr.com/ru/flows/design/">Дизайн</a>
# </li>
# <li class="nav-links__item">
# <a class="nav-links__item-link" href="https://habr.com/ru/flows/management/">Менеджмент</a>
# </li>
# <li class="nav-links__item">
# <a class="nav-links__item-link" href="https://habr.com/ru/flows/marketing/">Маркетинг</a>
# </li>
# <li class="nav-links__item">
# <a class="nav-links__item-link" href="https://habr.com/ru/flows/popsci/">Научпоп</a>
# </li>
# </ul>
# <form action="https://habr.com/ru/search/#h" class="search-form" id="search-form" method="get">
# <button class="btn btn_navbar_search icon-svg_search" id="search-form-btn" title="Поиск по сайту" type="button">
# <svg class="icon-svg" fill="none" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
# <path clip-rule="evenodd" d="M17 11C17 14.3137 14.3137 17 11 17C7.68629 17 5 14.3137 5 11C5 7.68629 7.68629 5 11 5C14.3137 5 17 7.68629 17 11ZM15.5838 17.5574C14.2857 18.4665 12.7051 19 11 19C6.58172 19 3 15.4183 3 11C3 6.58172 6.58172 3 11 3C15.4183 3 19 6.58172 19 11C19 12.9998 18.2662 14.8282 17.0533 16.2307C17.0767 16.2502 17.0994 16.2709 17.1214 16.2929L20.4143 19.5858C20.8048 19.9763 20.8048 20.6095 20.4143 21C20.0238 21.3905 19.3906 21.3905 19.0001 21L15.7072 17.7071C15.6605 17.6604 15.6194 17.6102 15.5838 17.5574Z" fill-rule="evenodd"></path>
# </svg>
# </button>
# <label class="search-form__field-wrapper">
# <input class="search-form__field" id="search-form-field" name="q" placeholder="Поиск" tabindex="-1" type="text"/>
# <button class="btn btn_search-close" id="search-form-clear" title="Закрыть" type="button">
# <svg aria-hidden="true" class="icon-svg icon-svg_navbar-close-search" height="32" role="img" version="1.1" viewbox="0 0 31 32" width="31"><path d="M26.67 0L15.217 11.448 3.77 0 0 3.77l11.447 11.45L0 26.666l3.77 3.77L15.218 18.99l11.45 11.448 3.772-3.77-11.448-11.45L30.44 3.772z"></path></svg>
# </button>
# </label>
# </form>
# </div>
# <div class="main-navbar__section main-navbar__section_right">
# <button class="btn btn_medium btn_navbar_lang js-show_lang_settings" type="button">
# <svg class="icon-svg" height="18" width="18">
# <use xlink:href="https://habr.com/5f324012/images/common-svg-sprite.svg#globus-v2"></use>
# </svg>
# </button>
# <a class="btn btn_medium btn_navbar_login" href="https://habr.com/ru/auth/login/" id="login">Войти</a>
# <a class="btn btn_medium btn_navbar_registration" href="https://habr.com/ru/auth/register/">Регистрация</a>
# </div>
# </div>
# </div>
# </div>
# <div class="layout__row layout__row_body">
# <div class="layout__cell layout__cell_body">
# <div class="page-header_bordered page-header_tall">
# <div class="page-header page-header_full" id="company_4628">
# <div class="page-header_wrapper">
# <div class="media-obj media-obj_page-header">
# <a class="media-obj__image page-header__image" href="/company/lanit/">
# <img class="company-info__image-pic" height="48" src="//habrastorage.org/getpro/habr/company/933/cc3/d68/933cc3d68881b38696957eead6f4de36.jpg" width="48"/>
# </a>
# <div class="media-obj__body media-obj__body_page-header">
# <div class="page-header__stats">
# <div class="page-header__stats-value">285,06</div>
# <div class="page-header__stats-label" title="Хабраиндекс - абстрактный показатель популярности компании на Хабре">Рейтинг</div>
# </div>
# </div>
# </div>
# </div>
# <div class="page-header__info">
# <a class="page-header__info-title" href="/company/lanit/">ГК ЛАНИТ</a>
# <div class="page-header__info-desc">Ведущая многопрофильная группа ИТ-компаний в РФ</div>
# </div>
# </div>
# </div>
# <div class="column-wrapper js-sticky-wrapper">
# <div class="content_left js-content_left">
# <div class="company_post">
# <article class="post post_full" id="post_511996" lang="ru">
# <div class="post__wrapper">
# <header class="post__meta">
# <a class="post__user-info user-info" href="https://habr.com/ru/users/sheltata/" title="Автор публикации">
# <span class="default-image_mini default-image_green">
# <svg aria-hidden="true" class="icon-svg" height="24" role="img" version="1.1" viewbox="0 0 24 24" width="24"><path d="M21.5 24h-19c-1.379 0-2.5-1.122-2.5-2.5v-19c0-1.379 1.122-2.5 2.5-2.5h19c1.379 0 2.5 1.122 2.5 2.5v19c0 1.379-1.122 2.5-2.5 2.5zm-19-23c-.827 0-1.5.673-1.5 1.5v19c0 .827.673 1.5 1.5 1.5h19c.827 0 1.5-.673 1.5-1.5v-19c0-.827-.673-1.5-1.5-1.5h-19zM15.598 12.385zM19.438 15.417l-.002-.005v-.001c-.875-2.226-2.484-3.054-3.445-3.549l-.273-.143c.029-.497-.025-1.034-.167-1.599l-.128.032.123-.044c-.765-2.152-1.757-2.585-2.632-2.967l-.006-.003-.535-2.121c.357-.065.628-.375.628-.752.001-.423-.342-.765-.765-.765s-.766.342-.766.765c0 .358.248.657.581.74l-.825 1.654-.014-.003-.024-.003c-1.053-.033-1.842.369-2.5.947-.633-.322-1.515-.729-2.158-1.814.107-.12.174-.276.174-.45 0-.375-.303-.678-.678-.678s-.678.303-.678.678.303.678.678.678l.221-.04c.416.597 1.09 1.181 1.347 2.828l-.072.091.104.081-.112-.067c-1.157 1.914-.793 4.248.207 5.37-.998 2.546-1.035 4.681-.097 5.868l.002.002.003.003c.119.162.313.233.524.233.189 0 .39-.057.559-.154.312-.179.441-.459.326-.713l-.12.054.119-.056c-.581-1.243-.474-2.713.314-4.37.4.131.778.208 1.145.234l.139.73c.264 1.418.514 2.757 1.297 4.006.132.264.453.387.777.387.122 0 .245-.018.357-.051.385-.116.591-.399.537-.738l-.129.021.125-.042c-.204-.606-.431-1.146-.649-1.67-.373-.894-.725-1.742-.891-2.737.407-.042.797-.129 1.161-.261.825.692 1.661 1.492 2.743 3.406h.001c.072.14.224.215.41.215.105 0 .222-.024.339-.073.365-.155.652-.531.477-1.006v-.001c-.432-1.849-1.426-2.778-2.428-3.547.162-.175.311-.366.442-.576.75.399 1.878 1.005 3.127 2.766l.047.067.011-.008c.151.156.317.24.48.24.096 0 .191-.027.279-.084.306-.194.439-.662.29-1.005zm-8.878-2.493c-.947 0-1.713-.767-1.713-1.713s.767-1.713 1.713-1.713c.947 0 1.713.767 1.713 1.713s-.767 1.713-1.713 1.713zm6.587 4.648l-.084.021v-.001l.084-.02zm-2.007-5.312zm.022 1.006zM11.225 11.604c0 .385-.312.697-.697.697s-.697-.312-.697-.697c0-.385.312-.697.697-.697s.697.312.697.697z"></path></svg>
# </span>
# <span class="user-info__nickname user-info__nickname_small">sheltata</span>
# </a>
# <span class="post__time" data-time_published="2020-08-11T07:06Z">сегодня в 10:06</span>
# </header>
# <h1 class="post__title post__title_full">
# <span class="post__title-text">Как прекратить страдать и начать учиться</span>
# </h1>
# <ul class="post__hubs post__hubs_full-post inline-list">
# <li class="inline-list__item inline-list__item_hub">
# <a class="inline-list__item-link hub-link" href="https://habr.com/ru/company/lanit/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'post page', 'Блог компании ГК ЛАНИТ'); }" title="Вы не подписаны на этот хаб">Блог компании ГК ЛАНИТ</a>,
#           </li>
# <li class="inline-list__item inline-list__item_hub">
# <a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/study/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'post page', 'Учебный процесс в IT'); }" title="Вы не подписаны на этот хаб">Учебный процесс в IT</a>,
#           </li>
# <li class="inline-list__item inline-list__item_hub">
# <a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/hr_management/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'post page', 'Управление персоналом'); }" title="Вы не подписаны на этот хаб">Управление персоналом</a>,
#           </li>
# <li class="inline-list__item inline-list__item_hub">
# <a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/career/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'post page', 'Карьера в IT-индустрии'); }" title="Вы не подписаны на этот хаб">Карьера в IT-индустрии</a>,
#           </li>
# <li class="inline-list__item inline-list__item_hub">
# <a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/brain/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'post page', 'Мозг'); }" title="Вы не подписаны на этот хаб">Мозг</a>
# </li>
# </ul>
# <ul class="post__marks inline-list"></ul>
# <div class="post__body post__body_full">
# <div class="post__text post__text-html post__text_v1" data-io-article-url="https://habr.com/ru/company/lanit/blog/511996/" id="post-content-body">Успели во время самоизоляции стать суперэффективными и освоить пару новых специальностей? Тоже нет? А ведь все вокруг трубили: «Используй это время с пользой! Кризис – всегда точка роста». Оказывается, это совершенно нормально, если вы не нашли в себе сил начать осваивать новый язык программирования или вышивание гладью. Психологи говорят, что сильный и продолжительный стресс вредит обучению, а мы все это время прожили в условии постоянно меняющихся правил. Однако хватит «выученной беспомощности», впереди еще много перемен, и суперэффективность нам может пригодиться. <br/>
# <br/>
# Я поговорила с преподавателями <a href="https://academy.ru/">«Сетевой Академии»</a> (кстати, нашему учебному центру 30 августа исполняется 25 лет!), чтобы узнать, что они думают про обучение дома, и собрала все мысли в этом посте: действительно ли это было время возможностей? Что поможет обучению, если всё вокруг мешает процессу? Чему и где учиться онлайн? Они дали свои рекомендации и рассказали о достойных образовательных платформах.<br/>
# <br/>
# Кстати, нашим преподавателям самим пришлось во время карантина срочно перестраивать учебный процесс, переформатируя его в онлайн. Так что они прекрасно знают, каково это – разрываться между работой, бытом, домочадцами и мониторингом новостей, при этом неотрывно следуя концепции непрерывного обучения.<br/>
# <br/>
# <div style="text-align:center;"><img src="https://habrastorage.org/getpro/habr/post_images/62e/cf7/094/62ecf709488ecfc58e8bdce1891728c0.png"/></div><a name="habracut"></a><br/>
# <h2>Не расстраивайтесь, что вы не так эффективны, как все, кто об этом рассказывает</h2><br/>
# <div style="text-align:center;"><img src="https://habrastorage.org/getpro/habr/post_images/b7b/4a5/05f/b7b4a505f4bbc1d528648bb20be4c324.png"/></div><a href="https://i.pinimg.com/originals/ea/61/16/ea61169cbddf93ff7b8f781bb7dd3bfd.jpg">Источник</a><br/>
# <br/>
# Нельзя сказать, что на карантине все ударились в саморазвитие. Конечно, кому-то пришлось срочно переучиваться, чтобы не остаться без куска хлеба. Но многим на обучение банально не хватало времени. По нашим внутренним опросам, только у одного из десяти сотрудников нагрузки стало меньше, остальные продолжили работать в прежнем или усиленном режиме. Свободное время на самоизоляции тоже оказалось приятной иллюзией. Время, сэкономленное на дороге в офис, у многих съели быт и дети. <br/>
# <br/>
# Однако это не значит, что учёбу стоит откладывать на потом. Отвечая на вопрос о преимуществах удаленного обучения, наши преподаватели отметили психологические и практические аспекты. О них стоит вспомнить, если нас действительно накроет вторая волна пандемии и снова придется самоизолироваться.<br/>
# <br/>
# <ul>
# <li>Обучение – это способ разнообразить свою жизнь, когда круглосуточно «в четырех стенах», способ не чувствовать себя «оторванным от мира». Это и полезно, и интересно, и может послужить источником положительных эмоций».</li>
# <li>«Переключение на учебу отвлекает от негативных мыслей во время карантина». </li>
# <li>«Во время весеннего карантина значительно увеличилось количество доступных курсов, причем бесплатных, их тематика расширилась, т.е. появилась возможность найти для себя что-то суперинтересное и полезное».</li>
# <li>Неважно, на карантине или в обычной жизни, – я предпочитаю удаленное самостоятельное обучение, потому что можно самостоятельно контролировать время на изучение темы. Я могу бегло пройти то, что мне уже знакомо и задержаться на том, что мне пока не известно. Столько, сколько нужно. При обучении в группе это невозможно».</li>
# <li>«Против обучения: <br/>
# <br/>
# 1. много работы (нет времени);<br/>
# 2. нет места, где бы не мешали домашние;<br/>
# 3. нет денег (хотя всегда можно найти бесплатные учебные ресурсы);<br/>
# 4. лень, апатия, депрессия, плохое самочувствие. <br/>
# <br/>
# <i>Преодолеть этот пункт помогут: </i><br/>
# <br/>
# • повышение своей квалификации, <br/>
# • чтение книг, <br/>
# • просмотр интересных, развивающих передач. <br/>
# <br/>
# <i>Если вы, выйдя на работу после длительного простоя, скажете своему руководителю или новому работодателю, что вы прошли дополнительное профессиональные обучение или подготовили новый проект, поверьте, к вам будут относиться с большим вниманием и уважением».</i></li>
# </ul><br/>
# <h2>Чему стоит поучиться</h2><br/>
# Допустим, вы уже готовы направить свою энергию на обучение. Направлений много, и все такое вкусное. Если нет острой потребности в конкретных знаниях и навыках, наши преподаватели рекомендуют приглядеться к курсам, обучающим тому, что:<br/>
# <br/>
# <ul>
# <li>может пригодиться на нынешней работе;</li>
# <li>потребуется в будущем (для дальнейшего профессионального и карьерного роста);</li>
# <li>интересно лично вам (например, компьютерная графика, дизайн, саморазвитие, здоровье и т.п.);</li>
# <li>только появилось (новые технологии).</li>
# </ul><br/>
# <div style="text-align:center;"><img src="https://habrastorage.org/getpro/habr/post_images/721/a20/574/721a205742e9f756c03f93cfee566f1c.png"/></div><br/>
# <i>«Важно, чтобы предмет изучения был нужен тебе лично. Никогда не поймешь удобство инструмента, если сам не попробовал его использовать. Так же, как иностранный язык лучше всего изучается, если на нем приходится говорить уже сегодня. То же самое с языками программирования, с администрированием серверов, с нейросетями и другими «новыми науками эпохи». Кстати, говорят, те же нейросети и машинное обучение отберут рабочие места и постепенно будут захватывать все больше и больше профессий и людям часто придётся переучиваться на новые профессии. Может, стоит начать учиться «переучиваться»?!»</i><br/>
# <br/>
# <h2>Если решили начать, ищите качественное обучение</h2><br/>
# Среди всего потока онлайн-курсов, тренингов и вебинаров бывает сложно найти что-то качественное, потому что многие решили сделать образовательный продукт на волне хайпа. Если у преподавателя мало опыта в проведении именно онлайн-занятий, вы в лучшем случае просто хорошо проведете время с приятным человеком. Если дистанционные курсы не удовлетворяют <strong>принципам педагогического дизайна, методологии и андрагогики</strong>, то вряд ли вы усвоите материал в полном объеме. И если в статье или учебнике много «воды», из такого материала сложно вычленить суть.<br/>
# <br/>
# ...
# <use xlink:href="https://habr.com/5f324012/images/common-svg-sprite.svg#globus-v2"></use>
# </svg>
# <a class="footer__link js-show_lang_settings" href="#">Настройка языка</a>
# </div>
# <div class="footer-grid__item footer-grid__item_link">
# <a class="footer__link" href="https://habr.com/ru/about/">О сайте</a>
# </div>
# <div class="footer-grid__item footer-grid__item_link">
# <a class="footer__link" href="https://habr.com/ru/feedback/">Служба поддержки</a>
# </div>
# <div class="footer-grid__item footer-grid__item_link">
# <a class="footer__link" href="https://m.habr.com/post/511996/?mobile=yes">Мобильная версия</a>
# </div>
# <div class="footer-grid__item footer-grid__item_social">
# <ul class="social-icons">
# <li class="social-icons__item">
# <a class="social-icons__item-link social-icons__item-link_normal social-icons__item-link_twitter" href="https://twitter.com/habr_com" onclick="if (typeof ga === 'function') { ga('send', 'event', 'footer', 'Social_icons', 'twitter'); }" target="_blank">
# <svg aria-hidden="true" aria-labelledby="title" class="icon-svg" height="24" role="img" version="1.1" viewbox="0 0 24 24" width="24"><path d="M17.414 8.642c-.398.177-.826.296-1.276.35.459-.275.811-.71.977-1.229-.43.254-.905.439-1.41.539-.405-.432-.982-.702-1.621-.702-1.227 0-2.222.994-2.222 2.222 0 .174.019.344.058.506-1.846-.093-3.484-.978-4.579-2.322-.191.328-.301.71-.301 1.117 0 .77.392 1.45.988 1.849-.363-.011-.706-.111-1.006-.278v.028c0 1.077.766 1.974 1.782 2.178-.187.051-.383.078-.586.078-.143 0-.282-.014-.418-.04.282.882 1.103 1.525 2.075 1.542-.76.596-1.718.951-2.759.951-.179 0-.356-.01-.53-.031.983.63 2.15.998 3.406.998 4.086 0 6.321-3.386 6.321-6.321l-.006-.287c.433-.314.81-.705 1.107-1.15z"></path></svg>
# </a>
# </li>
# <li class="social-icons__item">
# <a class="social-icons__item-link social-icons__item-link_normal social-icons__item-link_facebook" href="https://www.facebook.com/habrahabr.ru" onclick="if (typeof ga === 'function') { ga('send', 'event', 'footer', 'Social_icons', 'facebook'); }" target="_blank">
# <svg aria-hidden="true" aria-labelledby="title" class="icon-svg" height="24" role="img" version="1.1" viewbox="0 0 24 24" width="24"><path d="M14.889 8.608h-1.65c-.195 0-.413.257-.413.6v1.192h2.063v1.698h-2.063v5.102h-1.948v-5.102h-1.766v-1.698h1.766v-1c0-1.434.995-2.6 2.361-2.6h1.65v1.808z"></path></svg>
# </a>
# </li>
# <li class="social-icons__item">
# <a class="social-icons__item-link social-icons__item-link_normal social-icons__item-link_vkontakte" href="https://vk.com/habr" onclick="if (typeof ga === 'function') { ga('send', 'event', 'footer', 'Social_icons', 'vkontakte'); }" target="_blank">
# <svg aria-hidden="true" aria-labelledby="title" class="icon-svg" height="24" role="img" version="1.1" viewbox="0 0 24 24" width="24"><path d="M16.066 11.93s1.62-2.286 1.782-3.037c.054-.268-.064-.418-.343-.418h-1.406c-.322 0-.44.139-.537.343 0 0-.76 1.619-1.685 2.64-.297.33-.448.429-.612.429-.132 0-.193-.11-.193-.408v-2.607c0-.365-.043-.472-.343-.472h-2.254c-.172 0-.279.1-.279.236 0 .343.526.421.526 1.352v1.921c0 .386-.022.537-.204.537-.483 0-1.631-1.663-2.274-3.552-.129-.386-.268-.494-.633-.494h-1.406c-.204 0-.354.139-.354.343 0 .375.44 2.114 2.167 4.442 1.159 1.566 2.683 2.414 4.056 2.414.838 0 1.041-.139 1.041-.494v-1.202c0-.301.118-.429.29-.429.193 0 .534.062 1.33.848.945.901 1.01 1.276 1.525 1.276h1.578c.161 0 .311-.075.311-.343 0-.354-.462-.987-1.17-1.738-.29-.386-.762-.805-.912-.998-.215-.226-.151-.354-.001-.59z"></path></svg>
# </a>
# </li>
# <li class="social-icons__item">
# <a class="social-icons__item-link social-icons__item-link_normal social-icons__item-link_telegram" href="https://telegram.me/habr_com" onclick="if (typeof ga === 'function') { ga('send', 'event', 'footer', 'Social_icons', 'telegram'); }" target="_blank">
# <svg aria-hidden="true" aria-labelledby="title" class="icon-svg" height="24" role="img" version="1.1" viewbox="0 0 24 24" width="24"><path d="M17.17 7.621l-10.498 3.699c-.169.059-.206.205-.006.286l2.257.904 1.338.536 6.531-4.796s.189.057.125.126l-4.68 5.062-.27.299.356.192 2.962 1.594c.173.093.397.016.447-.199.058-.254 1.691-7.29 1.728-7.447.047-.204-.087-.328-.291-.256zm-6.922 8.637c0 .147.082.188.197.084l1.694-1.522-1.891-.978v2.416z"></path></svg>
# </a>
# </li>
# <li class="social-icons__item">
# <a class="social-icons__item-link social-icons__item-link_normal social-icons__item-link_youtube" href="https://www.youtube.com/channel/UCd_sTwKqVrweTt4oAKY5y4w" onclick="if (typeof ga === 'function') { ga('send', 'event', 'footer', 'Social_icons', 'youtube'); }" target="_blank">
# <svg aria-hidden="true" aria-labelledby="title" class="icon-svg" height="32" role="img" version="1.1" viewbox="0 0 32 32" width="32"><path d="M3.2 0h25.6c1.767 0 3.2 1.433 3.2 3.2v25.6c0 1.767-1.433 3.2-3.2 3.2h-25.6c-1.767 0-3.2-1.433-3.2-3.2v-25.6c0-1.767 1.433-3.2 3.2-3.2zm18.133 16l-10.667-5.333v10.667l10.667-5.333z"></path></svg>
# </a>
# </li>
# <li class="social-icons__item">
# <a class="social-icons__item-link social-icons__item-link_normal social-icons__item-link_zen" href="https://zen.yandex.ru/habr" onclick="if (typeof ga === 'function') { ga('send', 'event', 'footer', 'Social_icons', 'zen'); }" target="_blank">
# <svg fill="none" height="30" viewbox="0 0 30 30" width="30" xmlns="http://www.w3.org/2000/svg">
# <rect fill="#2C3036" height="30" rx="3" width="30"></rect>
# <path clip-rule="evenodd" d="M26.25 15.1241V14.9998V14.8759C21.2684 14.7252 18.9904 14.6009 17.1735 12.8263C15.3994 11.0098 15.2747 8.73179 15.1243 3.75H15H14.8757C14.7253 8.73179 14.6006 11.0098 12.8264 12.8263C11.0095 14.6009 8.73151 14.7252 3.75 14.8759V14.9998V15.1241C8.73151 15.2748 11.0095 15.3991 12.8264 17.1733C14.6006 18.9903 14.7253 21.2682 14.8757 26.25H15H15.1243C15.2747 21.2682 15.3994 18.9903 17.1735 17.1733C18.9904 15.3991 21.2684 15.2748 26.25 15.1241Z" fill="white" fill-rule="evenodd"></path>
# </svg>
# </a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# <a class="layout__elevator hidden" href="#" id="scroll_to_top" onclick="if (typeof ga === 'function') { ga('send', 'event', 'navigation_button', 'down'); }" title="Наверх">
# <svg aria-hidden="true" class="icon-svg icon-svg_scroll-up" height="32" role="img" version="1.1" viewbox="0 0 32 32" width="32"><path d="M16 0C7.164 0 0 7.164 0 16s7.164 16 16 16 16-7.164 16-16S24.836 0 16 0zm8.412 19.523c-.517.512-1.355.512-1.872 0L16 13.516l-6.54 6.01c-.518.51-1.356.51-1.873 0-.516-.513-.517-1.343 0-1.855l7.476-7.326c.517-.512 1.356-.512 1.873 0l7.476 7.327c.516.513.516 1.342 0 1.854z"></path></svg>
# </a>
# </div>
# <div class="overlay hidden" id="js-lang_settings">
# <div class="popup">
# <div class="popup__head popup__head_lang-settings">
# <span class="popup__head-title js-popup_title" data-section="1">Настройка языка</span>
# <button class="btn btn_small btn_popup-close js-hide_lang_settings" type="button">
# <svg class="icon-svg" height="12" width="12">
# <use xlink:href="https://habr.com/5f324012/images/common-svg-sprite.svg#close"></use>
# </svg>
# </button>
# </div>
# <div class="popup__body">
# <form action="/json/settings/i18n/" class="form form_lang-settings" id="lang-settings-form" method="post">
# <fieldset class="form__fieldset form__fieldset_thin" data-section="2">
# <legend class="form__legend form__legend_lang-settings js-popup_hl_legend">Интерфейс</legend>
# <div class="form-field form-field_lang-settings">
# <span class="radio radio_custom">
# <input checked="" class="radio__input js-hl_langs" id="hl_langs_ru" name="hl" type="radio" value="ru"/>
# <label class="radio__label radio__label_another" for="hl_langs_ru">Русский</label>
# </span>
# </div>
# <div class="form-field form-field_lang-settings">
# <span class="radio radio_custom">
# <input class="radio__input js-hl_langs" id="hl_langs_en" name="hl" type="radio" value="en"/>
# <label class="radio__label radio__label_another" for="hl_langs_en">English</label>
# </span>
# </div>
# </fieldset>
# <fieldset class="form__fieldset form__fieldset_thin">
# <legend class="form__legend form__legend_lang-settings js-popup_fl_legend" data-section="3">Язык публикаций</legend>
# <div class="form-field form-field_lang-settings">
# <span class="checkbox checkbox_custom">
# <input checked="" class="checkbox__input js-fl_langs" id="fl_langs_ru" name="fl[]" type="checkbox" value="ru"/>
# <label class="checkbox__label checkbox__label_another js-popup_feed_ru" for="fl_langs_ru">Русский</label>
# </span>
# </div>
# <div class="form-field form-field_lang-settings">
# <span class="checkbox checkbox_custom">
# <input class="checkbox__input js-fl_langs" id="fl_langs_en" name="fl[]" type="checkbox" value="en"/>
# <label class="checkbox__label checkbox__label_another js-popup_feed_en" for="fl_langs_en">Английский</label>
# </span>
# </div>
# </fieldset>
# <div class="form__footer form__footer_lang-settings">
# <button class="btn btn_blue btn_huge btn_full-width js-popup_save_btn" type="submit">Сохранить настройки</button>
# </div>
# </form>
# </div>
# </div>
# </div>
# <script type="text/javascript">
#   // global vars
#   var g_base_url = 'habr.com/ru';
#   var g_base_fullurl = 'https://habr.com/ru/';
#   var g_tmid_fullurl = 'https://account.habr.com/';
#   var g_is_guest = false;
#   var g_show_xpanel = false;
#   var g_is_enableShortcuts = '1';
#   var g_is_ugc_post = '';
#   var g_is_company_post = '1';
#     var g_current_hl = 'ru';
#     var g_current_fl = 'ru';
#
# </script>
# <script src="https://dr.habracdn.net/habr/5f324012/javascripts/vendors.bundle.js"></script>
# <script src="https://dr.habracdn.net/habr/5f324012/javascripts/main.bundle.js"></script>
# <script src="https://hsto.org/getpro/neuro-habr/1.0.0/neuro-habr.js"></script>
# <script>
# if (window.fetch) {
#   var nh = window.neuroHabr;
#     nh.init('https://habr.neuron.digital');
#
#   var articleId = 511996;
#
#   if (articleId) {
#     nh.send('view', articleId);
#   }
#
#   var nhState = {
#     viewTime: 0,
#     interval: null,
#     scrolledDown: false,
#     likeSent: false,
#   };
#
#   var hidden;
#   var visibilityChange;
#
#   if (typeof document.hidden !== 'undefined') { // Opera 12.10 and Firefox 18 and later support
#     hidden = 'hidden';
#     visibilityChange = 'visibilitychange';
#   } else if (typeof document.msHidden !== 'undefined') {
#     hidden = 'msHidden';
#     visibilityChange = 'msvisibilitychange';
#   } else if (typeof document.webkitHidden !== 'undefined') {
#     hidden = 'webkitHidden';
#     visibilityChange = 'webkitvisibilitychange';
#   }
#
#
#   var articleBody = document.querySelector('.post__body') || document.querySelector('.article__body');
#
#   if (articleBody) {
#     var MINIMUM_ARTICLE_READ_SECONDS = 10;
#
#     var isInViewport = function(e) {
#       var b = e.getBoundingClientRect();
#       return b.top <= window.innerHeight && b.top + b.height >= 0;
#     };
#
#     var isAtTheEnd = function(e) {
#       return e.getBoundingClientRect().bottom - window.innerHeight <= 0;
#     };
#
#     var hasReadArticle = function() {
#       return nhState.scrolledDown && nhState.viewTime >= MINIMUM_ARTICLE_READ_SECONDS;
#     };
#
#     function incrementViewTime(e) {
#       if (!nhState.likeSent && !nhState.interval) {
#         nhState.interval = setInterval(() => {
#           if (hasReadArticle()) {
#             if (!nhState.likeSent) {
#               nhState.likeSent = true;
#               nh.send('like', articleId);
#             }
#             clearInterval(nhState.interval);
#             nhState.interval = null;
#           } else if (isInViewport(e)) {
#             nhState.viewTime += 2;
#           }
#         }, 2000);
#       }
#     };
#
#     incrementViewTime(articleBody);
#
#     if (typeof document.addEventListener !== 'undefined' && hidden !== undefined) {
#       document.addEventListener(visibilityChange, () => {
#         if (!hasReadArticle() && !nhState.likeSent) {
#           if (document[hidden]) {
#             clearInterval(nhState.interval);
#             nhState.interval = null;
#           } else {
#             incrementViewTime(articleBody);
#           }
#         }
#       });
#
#       document.addEventListener('scroll', () => {
#         if (!nhState.scrolledDown) {
#           if (isAtTheEnd(articleBody)) {
#             nhState.scrolledDown = true;
#           }
#         }
#       });
#     } else {
#       nhState.scrolledDown = true;
#     }
#   }
# }
#
#
# </script>
# <script src="https://dr.habracdn.net/habr/5f324012/javascripts/check-login.js"></script>
# <script src="https://habr.com/ru/viewcount/post/511996/" type="text/javascript"></script>
# <!-- Yandex.Metrika counter -->
# <script type="text/javascript">
# (function(m,e,t,r,i,k,a){
#   m[i]=m[i]||function(){(m[i].a=m[i].a||[]).push(arguments)};
#   m[i].l=1*new Date();
#   k=e.createElement(t),a=e.getElementsByTagName(t)[0],k.async=1,k.src=r,a.parentNode.insertBefore(k,a)
# })(window, document, "script", "https://mc.yandex.ru/metrika/tag.js", "ym");
#
#     ym(24049213, "init", {
#       clickmap:true,
#       trackLinks:true,
#       accurateTrackBounce:true,
#       webvisor:true
#     });
# </script>
# <noscript>
# <div>
# <img alt="" src="https://mc.yandex.ru/watch/24049213" style="position:absolute; left:-9999px;">
# </img></div>
# </noscript>
# <!-- /Yandex.Metrika counter -->
# <script type="text/javascript">
#   function stripUrl(currentUrl, queryParam) {
#    return currentUrl.replace(/\?([^#]*)/, function(_, search) {
#       var result = search.split('&').map(function(param) {
#         var regexp = new RegExp(`^${queryParam}`);
#         if (regexp.test(param)) {
#           return '';
#         }
#         return param;
#       }).filter(Boolean).join('&');
#       return result ? '?' + result : '';
#     });
#   }
#
#   (function() {
#     if (location.search.indexOf('cv') != -1 && history.replaceState) {
#       var currentUrl = location.toString();
#       var strippedUrl = stripUrl(currentUrl, 'cv');
#       history.replaceState({}, '', strippedUrl);
#     }
#   })();
#
#   function callGA(usesABP) {
#     if (typeof window.adb1 === 'undefined') { window.adb1 = 'yes';}
#     if (usesABP) { window.adb1 = 'aa'; }
#
#     var user_type = 'guest';
#
#     var page_type = "publish_corp_ru,c_lanit,h_20696,h_20736,h_20740,h_21990,f_management,f_popsci";
#
#     (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#       (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#       m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#     })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
#         ga('create', 'UA-726094-1',  'auto');
#         ga('create', 'UA-726094-24', 'auto', {'name': 'HGM', 'allowLinker': true});
#
#     ga('HGM.require', 'linker');
#     ga('HGM.linker:autoLink', ['toster.ru', 'habr.com', 'account.habr.com', 'm.habr.com']);
#
#     ga('require', 'displayfeatures');
#     ga('set', 'dimension1', user_type); // user type - guest/readonly/habrauser
#     ga('set', 'dimension2', page_type);
#     ga('set', 'dimension3', 'na');
#     ga('set', 'dimension4', window.adb1);
#     ga('set', 'dimension6', 'ru');
#     ga('set', 'dimension7', 'A');
#
#               ga('create', 'UA-100552435-1', 'auto',  { 'name': 'company' });
#             ga('company.send', 'pageview');
#
#     (function() {
#       var removeUtms = function(){
#         var location = window.location;
#         if (location.search.indexOf('utm_') != -1 && history.replaceState) {
#           var currentUrl = location.toString();
#           var strippedUrl = stripUrl(currentUrl, 'utm_');
#           history.replaceState({}, '', strippedUrl);
#         }
#       };
#       ga('require', 'GTM-559GVC8');
#       ga('send', 'pageview', { 'hitCallback': removeUtms });
#     })();
#
#     ga('HGM.set', 'dimension1', user_type);
#     ga('HGM.set', 'dimension2', "habrahabr");
#     ga('HGM.set', 'dimension4', window.adb1);
#
#     ga('HGM.send', 'pageview');
#   }
#
#
#   if (window.habr_blockers_checker) {
#     window.habr_blockers_checker.detectWrapper(callGA);
#   } else {
#     callGA(false)
#   }
#
# </script>
# <!-- Facebook Pixel Code -->
# <img height="1" src="https://www.facebook.com/tr?id=317458588730613&amp;ev=PageView&amp;noscript=1" style="display:none" width="1">
# <!-- End Facebook Pixel Code -->
# <img alt="" src="https://vk.com/rtrg?p=VK-RTRG-421343-57vKE" style="position:fixed; left:-999px;">
# </img></img></body>
# </html>

# %%
article = soup.find_all('article', class_='post')

# %%
article
# Out:
# [<article class="post post_full" id="post_511996" lang="ru">
#  <div class="post__wrapper">
#  <header class="post__meta">
#  <a class="post__user-info user-info" href="https://habr.com/ru/users/sheltata/" title="Автор публикации">
#  <span class="default-image_mini default-image_green">
#  <svg aria-hidden="true" class="icon-svg" height="24" role="img" version="1.1" viewbox="0 0 24 24" width="24"><path d="M21.5 24h-19c-1.379 0-2.5-1.122-2.5-2.5v-19c0-1.379 1.122-2.5 2.5-2.5h19c1.379 0 2.5 1.122 2.5 2.5v19c0 1.379-1.122 2.5-2.5 2.5zm-19-23c-.827 0-1.5.673-1.5 1.5v19c0 .827.673 1.5 1.5 1.5h19c.827 0 1.5-.673 1.5-1.5v-19c0-.827-.673-1.5-1.5-1.5h-19zM15.598 12.385zM19.438 15.417l-.002-.005v-.001c-.875-2.226-2.484-3.054-3.445-3.549l-.273-.143c.029-.497-.025-1.034-.167-1.599l-.128.032.123-.044c-.765-2.152-1.757-2.585-2.632-2.967l-.006-.003-.535-2.121c.357-.065.628-.375.628-.752.001-.423-.342-.765-.765-.765s-.766.342-.766.765c0 .358.248.657.581.74l-.825 1.654-.014-.003-.024-.003c-1.053-.033-1.842.369-2.5.947-.633-.322-1.515-.729-2.158-1.814.107-.12.174-.276.174-.45 0-.375-.303-.678-.678-.678s-.678.303-.678.678.303.678.678.678l.221-.04c.416.597 1.09 1.181 1.347 2.828l-.072.091.104.081-.112-.067c-1.157 1.914-.793 4.248.207 5.37-.998 2.546-1.035 4.681-.097 5.868l.002.002.003.003c.119.162.313.233.524.233.189 0 .39-.057.559-.154.312-.179.441-.459.326-.713l-.12.054.119-.056c-.581-1.243-.474-2.713.314-4.37.4.131.778.208 1.145.234l.139.73c.264 1.418.514 2.757 1.297 4.006.132.264.453.387.777.387.122 0 .245-.018.357-.051.385-.116.591-.399.537-.738l-.129.021.125-.042c-.204-.606-.431-1.146-.649-1.67-.373-.894-.725-1.742-.891-2.737.407-.042.797-.129 1.161-.261.825.692 1.661 1.492 2.743 3.406h.001c.072.14.224.215.41.215.105 0 .222-.024.339-.073.365-.155.652-.531.477-1.006v-.001c-.432-1.849-1.426-2.778-2.428-3.547.162-.175.311-.366.442-.576.75.399 1.878 1.005 3.127 2.766l.047.067.011-.008c.151.156.317.24.48.24.096 0 .191-.027.279-.084.306-.194.439-.662.29-1.005zm-8.878-2.493c-.947 0-1.713-.767-1.713-1.713s.767-1.713 1.713-1.713c.947 0 1.713.767 1.713 1.713s-.767 1.713-1.713 1.713zm6.587 4.648l-.084.021v-.001l.084-.02zm-2.007-5.312zm.022 1.006zM11.225 11.604c0 .385-.312.697-.697.697s-.697-.312-.697-.697c0-.385.312-.697.697-.697s.697.312.697.697z"></path></svg>
#  </span>
#  <span class="user-info__nickname user-info__nickname_small">sheltata</span>
#  </a>
#  <span class="post__time" data-time_published="2020-08-11T07:06Z">сегодня в 10:06</span>
#  </header>
#  <h1 class="post__title post__title_full">
#  <span class="post__title-text">Как прекратить страдать и начать учиться</span>
#  </h1>
#  <ul class="post__hubs post__hubs_full-post inline-list">
#  <li class="inline-list__item inline-list__item_hub">
#  <a class="inline-list__item-link hub-link" href="https://habr.com/ru/company/lanit/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'post page', 'Блог компании ГК ЛАНИТ'); }" title="Вы не подписаны на этот хаб">Блог компании ГК ЛАНИТ</a>,
#            </li>
#  <li class="inline-list__item inline-list__item_hub">
#  <a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/study/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'post page', 'Учебный процесс в IT'); }" title="Вы не подписаны на этот хаб">Учебный процесс в IT</a>,
#            </li>
#  <li class="inline-list__item inline-list__item_hub">
#  <a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/hr_management/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'post page', 'Управление персоналом'); }" title="Вы не подписаны на этот хаб">Управление персоналом</a>,
#            </li>
#  <li class="inline-list__item inline-list__item_hub">
#  <a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/career/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'post page', 'Карьера в IT-индустрии'); }" title="Вы не подписаны на этот хаб">Карьера в IT-индустрии</a>,
#            </li>
#  <li class="inline-list__item inline-list__item_hub">
#  <a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/brain/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'post page', 'Мозг'); }" title="Вы не подписаны на этот хаб">Мозг</a>
#  </li>
#  </ul>
#  <ul class="post__marks inline-list"></ul>
#  <div class="post__body post__body_full">
#  <div class="post__text post__text-html post__text_v1" data-io-article-url="https://habr.com/ru/company/lanit/blog/511996/" id="post-content-body">Успели во время самоизоляции стать суперэффективными и освоить пару новых специальностей? Тоже нет? А ведь все вокруг трубили: «Используй это время с пользой! Кризис – всегда точка роста». Оказывается, это совершенно нормально, если вы не нашли в себе сил начать осваивать новый язык программирования или вышивание гладью. Психологи говорят, что сильный и продолжительный стресс вредит обучению, а мы все это время прожили в условии постоянно меняющихся правил. Однако хватит «выученной беспомощности», впереди еще много перемен, и суперэффективность нам может пригодиться. <br/>
#  <br/>
#  Я поговорила с преподавателями <a href="https://academy.ru/">«Сетевой Академии»</a> (кстати, нашему учебному центру 30 августа исполняется 25 лет!), чтобы узнать, что они думают про обучение дома, и собрала все мысли в этом посте: действительно ли это было время возможностей? Что поможет обучению, если всё вокруг мешает процессу? Чему и где учиться онлайн? Они дали свои рекомендации и рассказали о достойных образовательных платформах.<br/>
#  <br/>
#  Кстати, нашим преподавателям самим пришлось во время карантина срочно перестраивать учебный процесс, переформатируя его в онлайн. Так что они прекрасно знают, каково это – разрываться между работой, бытом, домочадцами и мониторингом новостей, при этом неотрывно следуя концепции непрерывного обучения.<br/>
#  <br/>
#  <div style="text-align:center;"><img src="https://habrastorage.org/getpro/habr/post_images/62e/cf7/094/62ecf709488ecfc58e8bdce1891728c0.png"/></div><a name="habracut"></a><br/>
#  <h2>Не расстраивайтесь, что вы не так эффективны, как все, кто об этом рассказывает</h2><br/>
#  <div style="text-align:center;"><img src="https://habrastorage.org/getpro/habr/post_images/b7b/4a5/05f/b7b4a505f4bbc1d528648bb20be4c324.png"/></div><a href="https://i.pinimg.com/originals/ea/61/16/ea61169cbddf93ff7b8f781bb7dd3bfd.jpg">Источник</a><br/>
#  <br/>
#  Нельзя сказать, что на карантине все ударились в саморазвитие. Конечно, кому-то пришлось срочно переучиваться, чтобы не остаться без куска хлеба. Но многим на обучение банально не хватало времени. По нашим внутренним опросам, только у одного из десяти сотрудников нагрузки стало меньше, остальные продолжили работать в прежнем или усиленном режиме. Свободное время на самоизоляции тоже оказалось приятной иллюзией. Время, сэкономленное на дороге в офис, у многих съели быт и дети. <br/>
#  <br/>
#  Однако это не значит, что учёбу стоит откладывать на потом. Отвечая на вопрос о преимуществах удаленного обучения, наши преподаватели отметили психологические и практические аспекты. О них стоит вспомнить, если нас действительно накроет вторая волна пандемии и снова придется самоизолироваться.<br/>
#  <br/>
#  <ul>
#  <li>Обучение – это способ разнообразить свою жизнь, когда круглосуточно «в четырех стенах», способ не чувствовать себя «оторванным от мира». Это и полезно, и интересно, и может послужить источником положительных эмоций».</li>
#  <li>«Переключение на учебу отвлекает от негативных мыслей во время карантина». </li>
#  <li>«Во время весеннего карантина значительно увеличилось количество доступных курсов, причем бесплатных, их тематика расширилась, т.е. появилась возможность найти для себя что-то суперинтересное и полезное».</li>
#  <li>Неважно, на карантине или в обычной жизни, – я предпочитаю удаленное самостоятельное обучение, потому что можно самостоятельно контролировать время на изучение темы. Я могу бегло пройти то, что мне уже знакомо и задержаться на том, что мне пока не известно. Столько, сколько нужно. При обучении в группе это невозможно».</li>
#  <li>«Против обучения: <br/>
#  <br/>
#  1. много работы (нет времени);<br/>
#  2. нет места, где бы не мешали домашние;<br/>
#  3. нет денег (хотя всегда можно найти бесплатные учебные ресурсы);<br/>
#  4. лень, апатия, депрессия, плохое самочувствие. <br/>
#  <br/>
#  <i>Преодолеть этот пункт помогут: </i><br/>
#  <br/>
#  • повышение своей квалификации, <br/>
#  • чтение книг, <br/>
#  • просмотр интересных, развивающих передач. <br/>
#  <br/>
#  <i>Если вы, выйдя на работу после длительного простоя, скажете своему руководителю или новому работодателю, что вы прошли дополнительное профессиональные обучение или подготовили новый проект, поверьте, к вам будут относиться с большим вниманием и уважением».</i></li>
#  </ul><br/>
#  <h2>Чему стоит поучиться</h2><br/>
#  Допустим, вы уже готовы направить свою энергию на обучение. Направлений много, и все такое вкусное. Если нет острой потребности в конкретных знаниях и навыках, наши преподаватели рекомендуют приглядеться к курсам, обучающим тому, что:<br/>
#  <br/>
#  <ul>
#  <li>может пригодиться на нынешней работе;</li>
#  <li>потребуется в будущем (для дальнейшего профессионального и карьерного роста);</li>
#  <li>интересно лично вам (например, компьютерная графика, дизайн, саморазвитие, здоровье и т.п.);</li>
#  <li>только появилось (новые технологии).</li>
#  </ul><br/>
#  <div style="text-align:center;"><img src="https://habrastorage.org/getpro/habr/post_images/721/a20/574/721a205742e9f756c03f93cfee566f1c.png"/></div><br/>
#  <i>«Важно, чтобы предмет изучения был нужен тебе лично. Никогда не поймешь удобство инструмента, если сам не попробовал его использовать. Так же, как иностранный язык лучше всего изучается, если на нем приходится говорить уже сегодня. То же самое с языками программирования, с администрированием серверов, с нейросетями и другими «новыми науками эпохи». Кстати, говорят, те же нейросети и машинное обучение отберут рабочие места и постепенно будут захватывать все больше и больше профессий и людям часто придётся переучиваться на новые профессии. Может, стоит начать учиться «переучиваться»?!»</i><br/>
#  <br/>
#  <h2>Если решили начать, ищите качественное обучение</h2><br/>
#  Среди всего потока онлайн-курсов, тренингов и вебинаров бывает сложно найти что-то качественное, потому что многие решили сделать образовательный продукт на волне хайпа. Если у преподавателя мало опыта в проведении именно онлайн-занятий, вы в лучшем случае просто хорошо проведете время с приятным человеком. Если дистанционные курсы не удовлетворяют <strong>принципам педагогического дизайна, методологии и андрагогики</strong>, то вряд ли вы усвоите материал в полном объеме. И если в статье или учебнике много «воды», из такого материала сложно вычленить суть.<br/>
#  <br/>
#  Тем не менее, в обучении все источники хороши: книги, статьи, онлайн-курсы, онлайн-мероприятия и общение с единомышленниками на форумах. Они не могут заменить друг друга, но отлично дополняют. Не стоит забывать и про <strong>обязательную отработку практических навыков.</strong><br/>
#  <br/>
#  <div style="text-align:center;"><img src="https://habrastorage.org/getpro/habr/post_images/296/a78/0b5/296a780b5ac1b138f0492f73864774eb.png"/></div><br/>
#  О том, как искать качественные источники дистанционного обучения, у наших преподавателей нет однозначного мнения. Большинство советует прислушаться к отзывам коллег и знакомых, присмотреться к репутации на рынке и, конечно, опираться на личные ощущения: если первые полчаса не захватило, то, наверное, не стоит продолжать. Вам должен нравиться <strong>стиль изложения материала</strong> конкретным автором – то, как он может сформулировать и донести информацию, темп его речи, отсутствие «воды» в изложении. Особенно хорошо, когда преподаватель позитивно подаёт учебный материал и открыт для любых вопросов.<br/>
#  <br/>
#  Интерактивность – тоже важная составляющая хорошего курса. Если у вас нет возможности проверить усвоенные знания на практике, получить обратную связь и признание от коллег и начальства, то просто слушать лекции в какой-то момент станет невыносимо. Поэтому в онлайн-обучении нужны «медальки» и новые уровни, как в компьютерной игре. Однако не стоит увлекаться излишне геймифицированными курсами: в погоне за медалями многие отклоняются от основной цели и работы. Поэтому выбирайте не игры с образовательными элементами, а <strong>обучение с элементами вовлечения</strong>.<br/>
#  <br/>
#  Онлайн-образование не стоит на месте, и эта идея находит свое отражение в развитии адаптивного обучения, когда система подстраивается под слушателя. Когда началась пандемия, мы проходили такой <a href="https://area9lyceum.com/course/how-to-successfully-work-from-home-rus/">курс по повышению эффективности удаленной работы</a> (кстати, его можно пройти и сейчас, а принципы его построения применимы к удаленной учебе). В нем система учитывает не только уровень знаний до курса и запоминание материала в процессе учебы, но даже степень уверенности в ответах и то, насколько она соответствует действительно верным ответам. Адаптивного обучения, к сожалению, пока еще мало, но если платформа умеет делать такие подстройки под пользователя, авторы курса обязательно на это указывают. <br/>
#  <br/>
#  <i>«Качественный материал – самый важный критерий!</i><i>Если это видео, то качественное видео и хороший звук. Если статья или книга, то качественные иллюстрации и оформление. Для курса важны наглядная структура, продуманная методическая составляющая (практическое закрепление материалов курса, промежуточный и итоговый контроль и т.п.)». </i><br/>
#  <br/>
#  <i>«Большим плюсом является нестандартное, запоминающееся преподнесение материала, отличающее этот курс, статью и т.д. от аналогичных».</i><br/>
#  <br/>
#  Какие же конкретные курсы и образовательные платформы порекомендовали наши преподаватели?<br/>
#  <br/>
#  <b>Онлайн-курсы и комплексные программы:</b><br/>
#  <br/>
#  <ul>
#  <li><a href="https://www.coursera.org/">Coursera</a> – более 4000 курсов и специализаций, включая бесплатные программы и высшее образование в ведущих вузах мира по выгодной цене, а также возможность получить профессиональную сертификацию или диплом. Одна из особенностей ресурса – перекрестные проверки, когда слушатели могут получать обратную связь от сокурсников и сами выступать в роли экспертов.</li>
#  <li><a href="https://www.udemy.com/">Udemy</a> – 100 000 онлайн-курсов от ИТ и бизнес-обучения до вокала и медитаций.</li>
#  <li><a href="https://www.udacity.com/">Udacity</a> – множество комплексных программ по различным ИТ-направлениям, большинство из которых разработано в сотрудничестве с ведущими вендорами. Обучение критически важным навыкам на реальных проектах позволяет приобрести опыт, требующийся в компаниях.</li>
#  <li>«<a href="http://lms.academy.ru">Сетевая академия ЛАНИТ</a>« – онлайн-курсы по освоению программ пакета MS Office от начального уровня до экспертного. Для широкого круга специалистов различных профилей, которым необходимо быстро и эффективно работать с документами и сводными таблицами, готовить наглядные отчеты и убедительные презентации, создавать инфографику без специальных приложений.</li>
#  <li><a href="https://www.planetaexcel.ru/">Планета Excel</a> – обширный онлайн-справочник по работе в MS Excel: уроки, курсы, тренинги, статьи, книги, обсуждения на форуме и многое другое. </li>
#  <li>«<a href="https://openedu.ru/">Открытое образование</a>« – бесплатные онлайн-курсы по базовым университетским дисциплинам, созданные ассоциацией ведущих вузов России. Прохождение любого курса может быть засчитано при освоении образовательной программы бакалавриата или специалитета в вузе при условии сдачи соответствующего экзамена.</li>
#  <li><a href="https://welcome.stepik.org/ru">Stepik</a> – тоже российская платформа с онлайн-курсами от ведущих вузов и компаний страны. Курсы как платные, так и бесплатные: в основном это ИТ-направления и программы для школьников, но есть и неожиданные варианты, например, онлайн-курс тотального диктанта по орфографии и пунктуации русского языка.</li>
#  <li><a href="http://www.intuit.ru/">Национальный открытый университет «ИНТУИТ»</a> – бесплатный доступ к более 800 учебным курсам по информационным технологиям, математике, физике, экономике, менеджменту и другим областям знаний.</li>
#  <li><a href="https://4brain.ru/">4brain</a> – на проекте собраны техники развития soft skills – ментальных навыков, необходимых каждому для достижения профессионального и личного успеха.</li>
#  <li><a href="https://www.edx.org/">edX</a> – более 2500 курсов от институтов всего мира, а также комплексные программы по освоению профессий, составленные экспертами ведущих компаний и университетов.</li>
#  <li><a href="https://www.lynda.com/">Lynda</a>, или LinkedIn Learning. Порядка 4000 курсов по бизнесу, разработке, дизайну, фотографии и музыке. </li>
#  </ul><br/>
#  <strong>Обучающие приложения на мобильном телефоне:</strong> <br/>
#  <br/>
#  <ul>
#  <li><a href="https://ru.duolingo.com/">DuoLingo</a> и <a href="https://lingualeo.com/">LinguaLeo</a> по английскому языку – уроки английского в игровой форме.</li>
#  <li><a href="https://www.sololearn.com/">SoloLearn</a> по ИТ – интерактивные уроки программирования.</li>
#  </ul><br/>
#  <strong>Статьи:</strong><br/>
#  <br/>
#  <ul>
#  <li><a href="http://theoryandpractice.ru">«Теории и практики»</a> – просветительское медиа о личностном и профессиональном развитии.</li>
#  </ul><br/>
#  Кстати, много полезного о подборе ресурсов и выстраивании стратегии самообучения в свое время написал Дмитрий Шарабин в статье <a href="https://habr.com/ru/company/lanit/blog/458708/">“Хочешь <s>похудеть</s> учиться ИТ самостоятельно? Спроси меня как”</a>. Кому нужно подробное руководство к действию – рекомендую прочесть.<br/>
#  <br/>
#  <h2>Как же начать? Просто начните. Как продолжить? Вспомните о цели</h2><br/>
#  <div style="text-align:center;"><img src="https://habrastorage.org/getpro/habr/post_images/52f/f9d/368/52ff9d3689cd8392905b4f9969c095ea.png"/></div><a href="https://pbs.twimg.com/media/Dhgu_mOWAAYkxy-.jpg"><i>Источник</i></a><br/>
#  <br/>
#  Начинать любое новое дело всегда сложно, даже с понедельника. А уж тем более начинать учиться, когда для этого нет нормальных условий. На самоизоляции мешало абсолютно всё – работа, домочадцы, животные, нарушенный режим дня и куча приятных отвлекающих факторов (соцсети, фильмы и прочее). Если вы по-прежнему остаетесь дома, не пренебрегайте строгой организацией и планированием.<br/>
#  <br/>
#  <ol>
#  <li>Поставьте перед собой цель и задачу. Именно они будут спасать вас, когда первый запал пройдет. Будете спрашивать себя, стал ли я ближе к цели? <i>С какого я района? Почему такой дерзкий?</i></li>
#  <li>Выделите время на обучение каждый день и строго придерживайтесь графика.<br/>
#  <br/>
#  Это может быть час-полтора каждый день перед началом рабочего времени, или полчаса каждый день в середине рабочего времени, или три часа через день в конце рабочего времени, или как-то еще… Все индивидуально. Важно не нарушать временные рамки и регулярность. И не менее важно – это время только для обучения:  никаких чатов, писем и параллельных задач.</li>
#  <li>Создайте обстановку, благоприятствующую обучению.<br/>
#  <br/>
#  <i>«Справиться с помехами поможет, в первую очередь, договоренность с родными и близкими: «Я учусь (час-полтора-два), пожалуйста, не мешайте». Найти место для обучения, организовать его, чтобы было комфортно, удобно. В крайнем случае изолироваться от шума наушниками. Убрать из поля зрения все отвлекающее, выключить телевизор, закрыть лишние окна/программы/сайты на компьютере, выйти из соцсетей, убрать животных, убрать телефон, или отключить звук. Сделать себе чек-лист, где ставить отметки о прохождении обучения».</i></li>
#  <li>Поощряйте себя за пройденный материал и сданный тест. Наградой может быть просмотр фильма вечером, звонок друзьям или что-то еще приятное, вроде <i>«</i>погладить кошку/собаку» и «съесть десерт».</li>
#  <li>Не забывайте практиковаться в том, чему научились.<br/>
#  <br/>
#  <i>«Очень важно, полученные знания обсуждать, например, с коллегами и друзьями и обязательно сразу же использовать на практике, чтобы закрепить и не забыть».</i></li>
#  </ol><br/>
#  Если чувствуете, что прокрастинация одолевает, попробуйте вызвать у себя спортивный азарт – «Я стану одним из 3,5%, кто проходит онлайн-курсы до конца!» Полезно сравнить эффект обучения и эффект развлечений – что для жизни ценнее? Новый фильм или новый учебный курс? Чтобы побороть минутную слабость, садитесь за учебу и не прекращайте, пока не пройдете запланированный объем материала. <br/>
#  <br/>
#  <h2>Что если вы руководитель и решили организовать обучение своих сотрудников</h2><br/>
#  <div style="text-align:center;"><img src="https://habrastorage.org/getpro/habr/post_images/69e/1e4/514/69e1e4514a8a73b83ec676ef71ef6394.png"/></div><br/>
#  Из-за карантина некоторые компании не успели осуществить свои планы по обучению сотрудников, кто-то от них временно отказался. К примеру, 15% давних клиентов «Сетевой Академии ЛАНИТ» отложили повышение квалификации сотрудников до возврата к очному формату и теперь пытаются наверстать упущенное. Кто-то перевел корпоративное обучение в онлайн либо изначально предпочитал именно такую форму. Часть организаций воспользовалась возможностью занять онлайн-курсами сотрудников, временно оставшихся без полной загрузки. Так, <a href="https://academy.ru/">в нашем учебном центре</a> спрос на дистанционное обучение вырос в 11 раз, при этом доля корпоративных заказчиков в этом всплеске активности составила около 20%.<br/>
#  <br/>
#  У любого формата есть свои плюсы и минусы. Главное – не забыть обсудить с сотрудниками прошедшее обучение, услышать их оценку, узнать о планах по использованию результатов обучения на практике. Будет и обратная связь, и полезная информация на будущее, и +10 к лояльности. И конечно, повышать квалификацию онлайн намного лучше, чем не повышать ее вовсе.<br/>
#  <br/>
#  <i>«Кто-то этой возможностью воспользуется, будет потом благодарен работодателю и продолжит работу. Ну, а кто не воспользуется, того и заставлять бесполезно — не факт что он и работать-то хотел в этой сфере».</i><br/>
#  <br/>
#  <i>«В любом случае, у сотрудников есть либо то, в чем им не хватает знаний/умений, либо то, чему они хотели бы научиться дополнительно. А тут появляется возможность для профессионального и личного саморазвития. Даже если это навыки коммуникации, стрессоустойчивости, сохранения и улучшения здоровья, скорочтения, развития памяти и внимания. Ну, еще одна идея – организовать коммуникацию сотрудников, чтобы обсуждали, что они узнали, можно даже сделать своего рода соревнование — кто продвинулся дальше».</i><br/>
#  <br/>
#  Что в итоге?<br/>
#  <br/>
#  Всё уже поменялось. Да, мы постепенно выходим обратно в офисы и в большой мир, но не все, не сразу и не полностью. Мы не знаем, какие сюрпризы ждут нас осенью, а потому должны быть готовы как к возврату к прошлой жизни, так и к новой самоизоляции. Лично я для себя на карантине сделала открытие: оказалось, что заниматься йогой по скайпу вполне возможно, довольно удобно и весьма эффективно, хотя раньше я верила только в очные занятия, на которые больше года не могла добраться по разным причинам.<br/>
#  <br/>
#  Попробуйте – быть может, и вам учиться онлайн покажется проще и удобнее, чем вечно ждать удачного момента для записи на очные курсы.<br/>
#  <br/>
#  <div class="spoiler" role="button" tabindex="0">
#  <b class="spoiler_title">Приходите учиться к нам!</b>
#  <div class="spoiler_text"><ul>
#  <li><a href="https://lms.academy.ru/local/crw/index.php?cid=5">Онлайн-курсы MS Office</a></li>
#  <li><a href="https://academy.ru/catalog/microsoft/">Курсы Microsoft</a></li>
#  <li><a href="https://academy.ru/catalog/unix%20linux/">Курсы Linux</a></li>
#  </ul><br/>
#  Больше курсов Сетевой Академии <a href="https://academy.ru">здесь</a>.<br/>
#  </div>
#  </div></div>
#  </div>
#  <dl class="post__tags">
#  <dt class="post__tags-label">Теги:</dt>
#  <dd class="post__tags-list"> <ul class="inline-list inline-list_fav-tags js-post-tags">
#  <li class="inline-list__item inline-list__item_tag"><a class="inline-list__item-link post__tag" href="https://habr.com/ru/search/?q=%5B%D0%BB%D0%B0%D0%BD%D0%B8%D1%82%5D&amp;target_type=posts" rel="tag">ланит</a></li>
#  <li class="inline-list__item inline-list__item_tag"><a class="inline-list__item-link post__tag" href="https://habr.com/ru/search/?q=%5B%D1%81%D0%B5%D1%82%D0%B5%D0%B2%D0%B0%D1%8F%20%D0%B0%D0%BA%D0%B0%D0%B4%D0%B5%D0%BC%D0%B8%D1%8F%5D&amp;target_type=posts" rel="tag">сетевая академия</a></li>
#  <li class="inline-list__item inline-list__item_tag"><a class="inline-list__item-link post__tag" href="https://habr.com/ru/search/?q=%5B%D1%81%D0%B5%D1%82%D0%B5%D0%B2%D0%B0%D1%8F%20%D0%B0%D0%BA%D0%B0%D0%B4%D0%B5%D0%BC%D0%B8%D1%8F%20%D0%BB%D0%B0%D0%BD%D0%B8%D1%82%5D&amp;target_type=posts" rel="tag">сетевая академия ланит</a></li>
#  <li class="inline-list__item inline-list__item_tag"><a class="inline-list__item-link post__tag" href="https://habr.com/ru/search/?q=%5B%D0%BE%D0%B1%D1%83%D1%87%D0%B5%D0%BD%D0%B8%D0%B5%5D&amp;target_type=posts" rel="tag">обучение</a></li>
#  <li class="inline-list__item inline-list__item_tag"><a class="inline-list__item-link post__tag" href="https://habr.com/ru/search/?q=%5B%D0%BE%D0%BD%D0%BB%D0%B0%D0%B9%D0%BD%20%D0%BE%D0%B1%D1%83%D1%87%D0%B5%D0%BD%D0%B8%D0%B5%5D&amp;target_type=posts" rel="tag">онлайн обучение</a></li>
#  </ul>
#  <button class="btn btn_outline_grey btn_mini hidden js-fav-edit-link" data-id="511996" data-type="2" onclick="show_edit_tags(this)" type="button">Добавить метки</button>
#  </dd>
#  </dl>
#  <dl class="post__tags">
#  <dt class="post__tags-label">Хабы:</dt>
#  <dd class="post__tags-list">
#  <ul class="inline-list inline-list_fav-tags js-post-hubs">
#  <li class="inline-list__item inline-list__item_tag">
#  <a class="inline-list__item-link post__tag" href="https://habr.com/ru/company/lanit/" rel="tag">
#                    Блог компании ГК ЛАНИТ
#                  </a>
#  </li>
#  <li class="inline-list__item inline-list__item_tag">
#  <a class="inline-list__item-link post__tag" href="https://habr.com/ru/hub/study/" rel="tag">
#                    Учебный процесс в IT
#                  </a>
#  </li>
#  <li class="inline-list__item inline-list__item_tag">
#  <a class="inline-list__item-link post__tag" href="https://habr.com/ru/hub/hr_management/" rel="tag">
#                    Управление персоналом
#                  </a>
#  </li>
#  <li class="inline-list__item inline-list__item_tag">
#  <a class="inline-list__item-link post__tag" href="https://habr.com/ru/hub/career/" rel="tag">
#                    Карьера в IT-индустрии
#                  </a>
#  </li>
#  <li class="inline-list__item inline-list__item_tag">
#  <a class="inline-list__item-link post__tag" href="https://habr.com/ru/hub/brain/" rel="tag">
#                    Мозг
#                  </a>
#  </li>
#  </ul>
#  </dd>
#  </dl>
#  </div>
#  <div class="overlay hidden" id="js-vote-reason">
#  <div class="popup popup_reasons">
#  <div class="popup__head popup__head_lang-settings">
#  <span class="popup__head-title">Укажите причину минуса, чтобы автор поработал над ошибками</span>
#  <button class="btn btn_small btn_popup-close js-hide_vote-reason" type="button">
#  <svg class="icon-svg" height="12" width="12">
#  <use xlink:href="https://habr.com/5f324012/images/common-svg-sprite.svg#close"></use>
#  </svg>
#  </button>
#  </div>
#  <div class="popup__body">
#  <span class="radio radio_custom reasons-vote__item js-vote-popup_list-item">
#  <input class="radio__input js-vote_radio" id="reasonList" name="reasonList" type="radio" value=""/>
#  <label class="radio__label radio__label_another js-vote_title" for="reasonList"></label>
#  </span>
#  <div id="js-vote-popup_list"></div>
#  <button class="btn btn_blue btn_huge js-vote_send" disabled="" type="button">Отправить анонимно</button>
#  </div>
#  </div>
#  </div>
#  </article>]

# %%
article_text = article[0].find('div', class_= 'post__body post__body_full').text

# %%
article_text
# Out:
# '\nУспели во время самоизоляции стать суперэффективными и освоить пару новых специальностей? Тоже нет? А ведь все вокруг трубили: «Используй это время с пользой! Кризис – всегда точка роста». Оказывается, это совершенно нормально, если вы не нашли в себе сил начать осваивать новый язык программирования или вышивание гладью. Психологи говорят, что сильный и продолжительный стресс вредит обучению, а мы все это время прожили в условии постоянно меняющихся правил. Однако хватит «выученной беспомощности», впереди еще много перемен, и суперэффективность нам может пригодиться.\xa0\n\r\nЯ поговорила с преподавателями «Сетевой Академии» (кстати, нашему учебному центру 30 августа исполняется 25 лет!), чтобы узнать, что они думают про обучение дома, и собрала все мысли в этом посте: действительно ли это было время возможностей? Что поможет обучению, если всё вокруг мешает процессу? Чему и где учиться онлайн? Они дали свои рекомендации и рассказали о достойных образовательных платформах.\n\r\nКстати, нашим преподавателям самим пришлось во время карантина срочно перестраивать учебный процесс, переформатируя его в онлайн. Так что они прекрасно знают, каково это – разрываться между работой, бытом, домочадцами и мониторингом новостей, при этом неотрывно следуя концепции непрерывного обучения.\n\n\nНе расстраивайтесь, что вы не так эффективны, как все, кто об этом рассказывает\nИсточник\n\r\nНельзя сказать, что на карантине все ударились в саморазвитие. Конечно, кому-то пришлось срочно переучиваться, чтобы не остаться без куска хлеба. Но многим на обучение банально не хватало времени. По нашим внутренним опросам, только у одного из десяти сотрудников нагрузки стало меньше, остальные продолжили работать в прежнем или усиленном режиме. Свободное время на самоизоляции тоже оказалось приятной иллюзией. Время, сэкономленное на дороге в офис, у многих съели быт и дети.\xa0\n\r\nОднако это не значит, что учёбу стоит откладывать на потом. Отвечая на вопрос о преимуществах удаленного обучения, наши преподаватели отметили психологические и практические аспекты. О них стоит вспомнить, если нас действительно накроет вторая волна пандемии и снова придется самоизолироваться.\n\n\nОбучение – это способ разнообразить свою жизнь, когда круглосуточно «в четырех стенах», способ не чувствовать себя «оторванным от мира». Это и полезно, и интересно, и может послужить источником положительных эмоций».\n«Переключение на учебу отвлекает от негативных мыслей во время карантина».\xa0\n«Во время весеннего карантина значительно увеличилось количество доступных курсов, причем бесплатных, их тематика расширилась, т.е. появилась возможность найти для себя что-то суперинтересное и полезное».\nНеважно, на карантине или в обычной жизни, – я предпочитаю удаленное самостоятельное обучение, потому что можно самостоятельно контролировать время на изучение темы. Я могу бегло пройти то, что мне уже знакомо и задержаться на том, что мне пока не известно. Столько, сколько нужно. При обучении в группе это невозможно».\n«Против обучения:\xa0\n\r\n1. много работы (нет времени);\r\n2. нет места, где бы не мешали домашние;\r\n3. нет денег (хотя всегда можно найти бесплатные учебные ресурсы);\r\n4. лень, апатия, депрессия, плохое самочувствие.\xa0\n\nПреодолеть этот пункт помогут:\xa0\n\r\n• повышение своей квалификации,\xa0\r\n• чтение книг,\xa0\r\n• просмотр интересных, развивающих передач.\xa0\n\nЕсли вы, выйдя на работу после длительного простоя, скажете своему руководителю или новому работодателю, что вы прошли дополнительное профессиональные обучение или подготовили новый проект, поверьте, к вам будут относиться с большим вниманием и уважением».\n\nЧему стоит поучиться\r\nДопустим, вы уже готовы направить свою энергию на обучение. Направлений много, и все такое вкусное. Если нет острой потребности в конкретных знаниях и навыках, наши преподаватели рекомендуют приглядеться к курсам, обучающим тому, что:\n\n\nможет пригодиться на нынешней работе;\nпотребуется в будущем (для дальнейшего п ...

# %%
# %%time
habr_news = pd.DataFrame()

for post in posts:
    post_id = post.parent.attrs.get('id')
   # если идентификатор не найден, это что-то странное, пропускаем
    if not post_id:
        continue
    else:
        title = post.find('a', class_ = 'post__title_link').text
        preview = post.find('div', class_= 'post__body post__body_crop').text
        link = post.find('a', class_ = 'btn btn_x-large btn_outline_blue post__habracut-btn')\
            .attrs.get('href')
        
        article_req = requests.get(link)
        soup = BeautifulSoup(article_req.text, 'html.parser')
        article = soup.find('article', class_='post')
        article_text = article.find('div', class_= 'post__body post__body_full').text
        
        print(title)
        
        print('Проверяю заголовок')
        is_found_flag = is_word_found(KEYWORDS, title)
        
        if is_found_flag:
            print('Слово найдено в заголовке')
        else:
            print('Проверяю превью')
            is_found_flag = is_word_found(KEYWORDS, preview)
            if is_found_flag:
                print('Слово найдено в превью')
            else:
                print('Проверяю текст')
                is_found_flag = is_word_found(KEYWORDS, article_text)
   
        if is_found_flag:
            date = get_valid_date(post.find('span', class_= 'post__time').text)
            row = {'date': date, 'title': title, 'link': link, 'text': article_text }
            habr_news = pd.concat([habr_news, pd.DataFrame([row])])  
habr_news
# Out:
# Онлайн-Круглый стол «Как создать свой игровой бизнес»
# Проверяю заголовок
# Слово найдено в заголовке
# Математические основы кодирования и шифрования
# Проверяю заголовок
# Проверяю превью
# Проверяю текст
# Миграция с Zimbra OSE 8.8.15 на Zimbra 9 Open Source от Zextras
# Проверяю заголовок
# Проверяю превью
# Проверяю текст
# Почему зарплаты в IT на територии ЕС и Восточной Европы так слабо отличаются?
# Проверяю заголовок
# Проверяю превью
# Проверяю текст
# Открытые и персональные данные. Анализ кейса «утечки данных» с Авито
# Проверяю заголовок
# Проверяю превью
# Проверяю текст
# В начале 2000-х экономика мира EverQuest по ВНД была между Россией и Болгарией (77-е место)
# Проверяю заголовок
# Проверяю превью
# Проверяю текст
# Как монетизировать мобильное приложение в 2020 году?
# Проверяю заголовок
# Проверяю превью
# Проверяю текст
# Модульные телефоны — что стало с нашумевшими проектами? Часть 2
# Проверяю заголовок
# Проверяю превью
# Проверяю текст
# Делаем игру с управлением улыбкой
# Проверяю заголовок
# Проверяю превью
# Проверяю текст
# В Parallels Desktop 16 для Mac появилась поддержка macOS Big Sur
# Проверяю заголовок
# Проверяю превью
# Проверяю текст
# Собираем медиацентр разной функциональности на коленке разной толщины
# Проверяю заголовок
# Проверяю превью
# Проверяю текст
# Суммаризация текста: подходы, алгоритмы, рекомендации и перспективы
# Проверяю заголовок
# Проверяю превью
# Проверяю текст
# Сервис на языке Dart: flutter web-страница
# Проверяю заголовок
# Проверяю превью
# Проверяю текст
# Бизнес-ландшафт будущего
# Проверяю заголовок
# Слово найдено в заголовке
# Поймут ли ваши иконки пользователи из других стран? Обзор научных исследований
# Проверяю заголовок
# Проверяю превью
# Проверяю текст
# Политика общего происхождения и CORS: визуальное руководство
# Проверяю заголовок
# Проверяю превью
# Проверяю текст
# Нам нужно поговорить…
# Проверяю заголовок
# Проверяю превью
# Проверяю текст
# Онлайн митап Zabbix об информационной безопасности | 28 августа
# Проверяю заголовок
# Проверяю превью
# Проверяю текст
# Мне кажется, дело не в языке, а в том, как на нем пишут
# Проверяю заголовок
# Проверяю превью
# Проверяю текст
# Wall time: 51min 45s
#          date                                              title  \
# 0  2020-08-11  Онлайн-Круглый стол «Как создать свой игровой ...
# 0  2020-08-11  Открытые и персональные данные. Анализ кейса «...
# 0  2020-08-11  Как монетизировать мобильное приложение в 2020...
# 0  2020-08-11                           Бизнес-ландшафт будущего
# 0  2020-08-11  Мне кажется, дело не в языке, а в том, как на ...
#
#                                                 link  \
# 0          https://habr.com/ru/post/514720/#habracut
# 0          https://habr.com/ru/post/514564/#habracut
# 0          https://habr.com/ru/post/514710/#habracut
# 0          https://habr.com/ru/post/514686/#habracut
# 0  https://habr.com/ru/company/skyeng/blog/514674...
#
#                                                 text
# 0  \n19 августа (Среда), в 19:00, состоится беспл...
# 0  \n\n\r\nДве недели назад, на форумах обнаружил...
# 0  \nВ этой статье я хочу рассказать о том, как и...
# 0  \nВ этой статье я хочу поделиться видением раз...
# 0  \n«Летом между 2 и 3 курсом я пошла искать раб...

# %%
habr_news.reset_index()
# Out:
#    index        date                                              title  \
# 0      0  2020-08-11  Онлайн-Круглый стол «Как создать свой игровой ...
# 1      0  2020-08-11  Открытые и персональные данные. Анализ кейса «...
# 2      0  2020-08-11  Как монетизировать мобильное приложение в 2020...
# 3      0  2020-08-11                           Бизнес-ландшафт будущего
# 4      0  2020-08-11  Мне кажется, дело не в языке, а в том, как на ...
#
#                                                 link  \
# 0          https://habr.com/ru/post/514720/#habracut
# 1          https://habr.com/ru/post/514564/#habracut
# 2          https://habr.com/ru/post/514710/#habracut
# 3          https://habr.com/ru/post/514686/#habracut
# 4  https://habr.com/ru/company/skyeng/blog/514674...
#
#                                                 text
# 0  \n19 августа (Среда), в 19:00, состоится беспл...
# 1  \n\n\r\nДве недели назад, на форумах обнаружил...
# 2  \nВ этой статье я хочу рассказать о том, как и...
# 3  \nВ этой статье я хочу поделиться видением раз...
# 4  \n«Летом между 2 и 3 курсом я пошла искать раб...

# %% [markdown]
# ## Задание 2.

# %% [markdown]
# ### Обязательная часть

# %% [markdown]
# Написать скрипт, который будет проверять список e-mail адресов на утечку при помощи сервиса [Avast Hack Ckeck](https://www.avast.com/hackcheck/).
# Список email-ов задаем переменной в начале кода:
# `EMAIL = [xxx@x.ru, yyy@y.com]`
#
# В итоге должен формироваться датафрейм со столбцами: <почта> - <дата утечки> - <источник утечки> - <описание утечки>.

# %%
emails = ['boiko_tatjana@mail.ru', 'boiko.andrew.1985@gmail.com', 'boiko_andrew@mail.ru']

# %%
avast = pd.DataFrame()
for email in emails:
    req = requests.post(url = 'https://digibody.avast.com/v1/web/leaks',
                    json = {'email':email})
    req_json = json.loads(req.text)
    value = req_json['value']
    for i, item in enumerate(value):
        date_unix = round((value[i]['leak_info']['date'])/1000)
        date = datetime.fromtimestamp(date_unix).strftime("%Y-%m-%d")
        domain = value[i]['domain']
        title = value[i]['leak_info']['title']
        description = value[i]['leak_info']['description']
        row = {'email': email,'date': date, 'domain' : domain, 'title': title, 'description': description}
        avast = pd.concat([avast, pd.DataFrame([row])]) 
avast.reset_index()
# Out:
#     index                        email        date         domain  \
# 0       0        boiko_tatjana@mail.ru  2019-06-13      canva.com
# 1       0  boiko.andrew.1985@gmail.com  2017-12-22
# 2       0  boiko.andrew.1985@gmail.com  2019-02-06
# 3       0  boiko.andrew.1985@gmail.com  2017-10-09
# 4       0  boiko.andrew.1985@gmail.com  2019-02-06
# 5       0  boiko.andrew.1985@gmail.com  2019-01-29
# 6       0  boiko.andrew.1985@gmail.com  2018-12-21
# 7       0  boiko.andrew.1985@gmail.com  2016-10-29         vk.com
# 8       0         boiko_andrew@mail.ru  2017-12-22
# 9       0         boiko_andrew@mail.ru  2018-08-24
# 10      0         boiko_andrew@mail.ru  2019-02-06
# 11      0         boiko_andrew@mail.ru  2017-10-09
# 12      0         boiko_andrew@mail.ru  2017-08-30  sprashivai.ru
# 13      0         boiko_andrew@mail.ru  2020-01-09
# 14      0         boiko_andrew@mail.ru  2019-02-06
# 15      0         boiko_andrew@mail.ru  2019-01-29
# 16      0         boiko_andrew@mail.ru  2019-12-13
# 17      0         boiko_andrew@mail.ru  2019-02-06
# 18      0         boiko_andrew@mail.ru  2016-10-29         vk.com
# 19      0         boiko_andrew@mail.ru  2017-04-10  sprashivai.ru
# 20      0         boiko_andrew@mail.ru  2019-12-05
# 21      0         boiko_andrew@mail.ru  2016-10-26
#
#                                    title  \
# 0                                  Canva
# 1   Combolist of 1.4 Billion Credentials
# 2               Collection #4 Combo List
# 3                   Exploit.in combolist
# 4             2019 Antipublic Combo List
# 5               Collection #2 Combo List
# 6                       Sensitive Source
# 7                                     VK
# 8   Combolist of 1.4 Billion Credentials
# 9          Jadid List from Pemiblanc.com
# 10              Collection #4 Combo List
# 11                  Exploit.in combolist
# 12                            Sprashivai
# 13                      Sensitive Source
# 14            2019 Antipublic Combo List
# 15              Collection #2 Combo List
# 16                      Sensitive Source
# 17         AP MYR and Zabugor Combo List
# 18                                    VK
# 19                                Ask RU
# 20                      Sensitive Source
# 21                      Sensitive Source
#
#                                           description
# 0   In May 2019, graphic-design site Canva's datab...
# 1   The proliferation of stolen or leaked database...
# 2   On January 7, 2019, an online user named Sanix...
# 3   The proliferation of stolen or leaked database...
# 4   On January 7, 2019, an online user named Sanix...
# 5   On January 7, 2019, an online user named Sanix...
# 6   This source has been marked as sensitive due t...
# 7   Popular Russian social networking platform VKo...
# 8   The proliferation of stolen or leaked database...
# 9   This combolist was compiled from a variety of ...
# 10  On January 7, 2019, an online user named Sanix...
# 11  The proliferation of stolen or leaked database...
# 12  In January 2015, Sprashivai.ru's user database...
# 13  This source has been marked as sensitive due t...
# 14  On January 7, 2019, an online user named Sanix...
# 15  On January 7, 2019, an online user named Sanix...
# 16  This source has been marked as sensitive due t...
# 17  On January 7, 2019, an online user named Sanix...
# 18  Popular Russian social networking platform VKo...
# 19  In May 2015, Ask RU's user database was leaked...
# 20  This source has been marked as sensitive due t...
# 21  This source has been marked as sensitive due t...

# %% [markdown]
# ### Дополнительная часть (необязательная)

# %% [markdown]
# Написать скрипт, который будет получать 50 последних постов указанной группы во Вконтакте.
# Документация к API VK: https://vk.com/dev/methods
# , вам поможет метод [wall.get](https://vk.com/dev/wall.get)```
# GROUP = 'netology'
# TOKEN = УДАЛЯЙТЕ В ВЕРСИИ ДЛЯ ПРОВЕРКИ, НА GITHUB НЕ ВЫКЛАДЫВАТЬ
# ```
#
# В итоге должен формироваться датафрейм со столбцами: <дата поста> - <текст поста>.

# %% [markdown]
# #### ПРИМЕЧАНИЕ
# Домашнее задание сдается ссылкой на репозиторий [GitHub](https://github.com/).
# Не сможем проверить или помочь, если вы пришлете:
# - файлы;
# - архивы;
# - скриншоты кода.
#
# Все обсуждения и консультации по выполнению домашнего задания ведутся только на соответствующем канале в slack.
#
# ##### Как правильно задавать вопросы аспирантам, преподавателям и коллегам?
# Прежде чем задать вопрос необходимо попробовать найти ответ самому в интернете. Навык самостоятельного поиска информации – один из важнейших, и каждый практикующий специалист любого уровня это делает каждый день.
#
# Любой вопрос должен быть сформулирован по алгоритму:
# 1) Что я делаю?
# 2) Какого результата я ожидаю?
# 3) Как фактический результат отличается от ожидаемого?
# 4) Что я уже попробовал сделать, чтобы исправить проблему?
#
# По возможности, прикрепляйте к вопросу скриншоты, либо ссылки на код. Оставляйте только проблемный и воспроизводимый участок кода, все решение выкладывать не допускается.
